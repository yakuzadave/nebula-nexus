# %% [markdown]
# # Working with Memgraph and Obsidian for Knowledge Graphs and RAG (Powered by LangChain)
#
# This notebook demonstrates how to use Memgraph and Obsidian for Knowledge Graphs and RAG (Powered by LangChain).  This is a work in progress and highly experimental, so the code you see here is subject to change as I refine (and sometimes on a whim when I want to try something new).  The goal is to create a seamless integration between Memgraph and Obsidian for creating and querying knowledge graphs.  The integration is powered by LangChain, which will be adding additional functionality with LLMs such as GPT-4o, Llama-3, and others.
#
# ## Introduction
#
# ### What is Memgraph?
# Memgraph is a high-performance, in-memory graph database that is designed to be fast, scalable, and easy to use.  It is a great tool for creating and querying knowledge graphs.  You can learn more about Memgraph at [https://memgraph.com/](https://memgraph.com/).
#
# ### What is Obsidian?
# Obsidian is a powerful knowledge management tool that allows you to create and organize your notes, ideas, and knowledge in a graph-like structure.  It is a great tool for creating and visualizing knowledge graphs.  You can learn more about Obsidian at [https://obsidian.md/](https://obsidian.md/).
#
# ### What is LangChain?
# LangChain is a framework for developing applications powered by large language models (LLMs).
#
# LangChain simplifies every stage of the LLM application lifecycle:
#
# - **Development**: Build your applications using LangChain's open-source [building blocks](https://python.langchain.com/v0.2/docs/concepts/#langchain-expression-language) and [components](https://python.langchain.com/v0.2/docs/concepts/). Hit the ground running using [third-party integrations(https://python.langchain.com/v0.2/docs/integrations/platforms/)] and [Templates](https://python.langchain.com/v0.2/docs/templates/).
# - **Productionization**: Use [LangSmith](https://docs.smith.langchain.com/) to inspect, monitor and evaluate your chains, so that you can continuously optimize and deploy with confidence.
# - Deployment: Turn any chain into an API with [LangServe](https://python.langchain.com/v0.2/docs/langserve/).
#
# ![](https://python.langchain.com/v0.2/svg/langchain_stack_dark.svg)
#
#
# Concretely, the framework consists of the following open-source libraries:
#
# - **langchain-core**: Base abstractions and LangChain Expression Language.
# - **langchain-community**: Third party integrations.
#   - Partner packages (e.g. **langchain-openai**, **langchain-anthropic**, etc.): Some integrations have been further split into their own lightweight packages that only depend on langchain-core.
# - langchain: Chains, agents, and retrieval strategies that make up an application's cognitive architecture.
# - langgraph: Build robust and stateful multi-actor applications with LLMs by modeling steps as edges and nodes in a graph.
# - langserve: Deploy LangChain chains as REST APIs.
# - LangSmith: A developer platform that lets you debug, test, evaluate, and monitor LLM applications.

# %% [markdown]
# ### Bor and ODIN

# %% [markdown]
# Much of this is based on **Bor** which is a backend that powers the **ODIN** or **RUNE** front-ends.  However, I am looking more than just extending Obsidian, so I will be adjusting and improving on this design for my own purposes.  I will be using the **Bor** backend as a starting point, but I will be making significant changes to it as I go along.
#
# For more information you can view the GitHub repositories at:
# - [Bor](https://github.com/memgraph/bor)
# - [ODIN](https://github.com/memgraph/odin)

# %%
# !git clone https://github.com/memgraph/odin.git
# !git clone https://github.com/memgraph/bor.git
# %pip install -r /Users/dcarmocan/Projects/Reports/report_notebooks/bor/requirements.txt
# %pip install langchain --upgrade
# %pip install langchain-openai --upgrade
# %pip install pandasai --upgrade
# # %pip install pandas --upgrade
# %pip install datasets --upgrade
# %pip install transformers --upgrade
# %pip install torch --upgrade
# %pip install torchtext --upgrade
# %pip install sentence-transformers --upgrade
# %pip install "fsspec[http]" --upgrade

# %pip install "gqlalchemy[all]"
# %pip install "gqlalchemy[all]" --upgrade
# %pip install "gqlalchemy[torch_pyg]"
# %pip install torch-scatter torch-sparse torch-cluster torch-spline-conv torch-geometric -f https://data.pyg.org/whl/torch-1.13.0+cpu.html"

# %% [markdown]
# # Imports and Config

# %% [markdown]
# ## Installing Memgraph

# %% [markdown]
# First things first, we need to install Memgraph.  You can download Memgraph from [https://memgraph.com/download](https://memgraph.com/download), however, for what we are doing, it is easier to run Memgraph Platform and Lab in a Docker compose environment.  You can find the instructions for this at [https://memgraph.com/docs/memgraph-lab/installation/docker-compose](https://memgraph.com/docs/memgraph-lab/installation/docker-compose).
#
# For my settings, I just followed the standard instructions for running Memgraph Platform and Lab in a Docker compose environment. and then added some adjustments.
#
# This is an example of the `docker-compose.yml` file I used:
#
# ```yaml
# version: "3.8"
# services:
#   memgraph:
#     image: memgraph/memgraph-mage:latest
#     container_name: memgraph-mage
#     pull_policy: always
#     ports:
#       - "7687:7687"
#       - "7444:7444"
#     command: ["--log-level=TRACE"]
#     networks:
#       - memgraph-network
#
#   memgraph-lab:
#     image: memgraph/lab:latest
#     container_name: memgraph-lab
#     pull_policy: always
#     ports:
#       - "3000:3000"
#     depends_on:
#       - memgraph
#     environment:
#       QUICK_CONNECT_MG_HOST: memgraph
#       QUICK_CONNECT_MG_PORT: 7687
#     networks:
#       - memgraph-network
#
# networks:
#   memgraph-network:
#     external: true
#     name: memgraph-platform_memgraph-network
#
# ```
#
# The main thing that I wanted to be sure of is that the Obsidian path would be mounted as a volume in the Memgraph Lab container.  This is the line that I added to the `memgraph-lab` service:
#
# ```yaml
#     volumes:
#       - /path/to/obsidian:/root/.config/obsidian
# ```

# %% [markdown]
# ## Imports

# %%
from __future__ import annotations
from typing import Optional, Dict, List, Any, Iterator
import os
import sys
import logging
import pandas as pd
import numpy as np

import requests
import json
import time
from pathlib import Path
from gqlalchemy import Memgraph


import os
import re
from typing import List
from gqlalchemy import Memgraph
from langchain.agents import Tool, initialize_agent, AgentType
from langchain.chat_models import ChatOpenAI
from langchain.prompts import MessagesPlaceholder, PromptTemplate
from langchain.memory import ConversationBufferMemory
from langchain.schema import SystemMessage


# notes_dir = Path("/Users/dcarmocan/Projects/mind-cave")
notes_dir = "/Users/dcarmocan/Projects/mind-cave"

# %%
notes_dir

# %% [markdown]
# ## Our Components
#
# In order to rebuild this, we need to understand the components that we are working with.  The main components are:
#
# - **MemgraphManager**
# - **Constants**
# - **CollectionManager**
# - **CollectionManager**
# - **CypherQueryHandler**
# - **VaultManager**
# - **GeneralQueryAgent**

# %% [markdown]
# ### The `MemgraphManager` Class

# %%
# import os
# import mgclient
# from markdown import Markdown
# from markdown.treeprocessors import Treeprocessor
# from markdown.extensions import Extension
# import re
# import datetime

# # Initialize the MemgraphManager
# class MemgraphManager:
#     def __init__(self):
#         try:
#             self.connection = mgclient.connect(host='localhost', port=7687, lazy=False)
#             self.connection.autocommit = True
#         except Exception as e:
#             print(f"Failed to connect to Memgraph: {e}")
#             raise

#     def execute_query(self, query: str):
#         print(f"Executing query: {query}")
#         try:
#             cursor = self.connection.cursor()
#             cursor.execute(query)
#             results = cursor.fetchall()
#             cursor.close()
#             print("Query executed successfully.")
#             return results
#         except Exception as e:
#             print(f"Failed to execute query: {e}")
#             if cursor:
#                 cursor.close()
#             raise

#     def create_node(self, label: str, properties: dict):
#         props = ", ".join([f"{k}: '{v}'" for k, v in properties.items()])
#         query = f"CREATE (n:{label} {{{props}}})"
#         self.execute_query(query)

#     def create_edge(self, from_node: str, to_node: str, relationship: str):
#         query = f"""
#         MATCH (a), (b)
#         WHERE a.name = '{from_node}' AND b.name = '{to_node}'
#         CREATE (a)-[r:{relationship}]->(b)
#         """
#         self.execute_query(query)

# # Custom Markdown extension to extract headings
# class HeadingExtractor(Treeprocessor):
#     def __init__(self, md):
#         super().__init__(md)
#         self.headings = []

#     def run(self, root):
#         for element in root:
#             if element.tag.startswith('h'):
#                 self.headings.append((element.tag, element.text))
#         return root

# class ExtractHeadings(Extension):
#     def extendMarkdown(self, md):
#         heading_extractor = HeadingExtractor(md)
#         md.treeprocessors.register(heading_extractor, 'extract_headings', 10)
#         md.heading_extractor = heading_extractor

# # Function to parse a markdown file and extract headings and links
# def parse_markdown(file_path):
#     md = Markdown(extensions=[ExtractHeadings()])
#     with open(file_path, 'r', encoding='utf-8') as f:
#         content = f.read()
#     md.convert(content)
#     links = re.findall(r'\[.*?\]\((.*?)\)', content)
#     return md.heading_extractor.headings, links

# # Function to sanitize heading text for Cypher queries
# def sanitize_text(text):
#     if text is None:
#         return "None"
#     sanitized = text.replace("'", "\\'").replace("#", "").replace("?", "")
#     return sanitized

# # Path to the directory containing markdown files (Obsidian vault)
# notes_dir = '/Users/dcarmocan/Projects/mind-cave'

# # Initialize the MemgraphManager
# mg_manager = MemgraphManager()

# # Process each markdown file in the directory
# for root, dirs, files in os.walk(notes_dir):
#     for file in files:
#         if file.endswith('.md'):
#             file_path = os.path.join(root, file)
#             print(f"Processing file: {file_path}")
            
#             try:
#                 # Extract headings and links
#                 headings, links = parse_markdown(file_path)
#                 file_name = os.path.basename(file_path)
                
#                 # Create a node for the file
#                 mg_manager.create_node('File', {'name': file_name})
                
#                 # Create nodes and edges for each heading
#                 previous_heading = file_name
#                 for tag, heading in headings:
#                     sanitized_heading = sanitize_text(heading)
#                     heading_node = f"{file_name}_{sanitized_heading}"
#                     mg_manager.create_node(tag, {'name': heading_node})
#                     mg_manager.create_edge(previous_heading, heading_node, 'CONTAINS')
#                     previous_heading = heading_node

#                 # Create edges for links to other files
#                 for link in links:
#                     linked_file = os.path.basename(link)
#                     mg_manager.create_edge(file_name, linked_file, 'LINKS_TO')
#             except Exception as e:
#                 print(f"Error processing file {file_path}: {e}")

# %%
# import os
# import mgclient
# from markdown import Markdown
# from markdown.treeprocessors import Treeprocessor
# from markdown.extensions import Extension
# import re
# import datetime

# # Initialize the MemgraphManager
# class MemgraphManager:
#     def __init__(self):
#         try:
#             self.connection = mgclient.connect(host='localhost', port=7687, lazy=False)
#             self.connection.autocommit = True
#         except Exception as e:
#             print(f"Failed to connect to Memgraph: {e}")
#             raise

#     def execute_query(self, query: str):
#         print(f"Executing query: {query}")
#         try:
#             cursor = self.connection.cursor()
#             cursor.execute(query)
#             results = cursor.fetchall()
#             cursor.close()
#             print("Query executed successfully.")
#             return results
#         except Exception as e:
#             print(f"Failed to execute query: {e}")
#             if cursor:
#                 cursor.close()
#             raise

#     def find_duplicates(self):
#         query = """
#         MATCH (n)
#         WITH n.name AS name, collect(n) AS nodes
#         WHERE size(nodes) > 1
#         RETURN name, nodes
#         """
#         return self.execute_query(query)

#     def merge_nodes(self, name):
#         merge_query_corrected = f"""
#         CALL merge.node(
#             ['File'], 
#             {{name: '{name}'}},
#             {{}},
#             {{}}
#         ) YIELD node
#         RETURN node
#         """
#         self.execute_query(merge_query_corrected)

#     def merge_duplicates(self):
#         duplicates = self.find_duplicates()
#         for name, _ in duplicates:
#             self.merge_nodes(name)

#     def create_node(self, label: str, properties: dict):
#         props = ", ".join([f"{k}: '{v}'" for k, v in properties.items()])
#         query = f"CREATE (n:{label} {{{props}}})"
#         self.execute_query(query)

#     def create_edge(self, from_node: str, to_node: str, relationship: str):
#         query = f"""
#         MATCH (a), (b)
#         WHERE a.name = '{from_node}' AND b.name = '{to_node}'
#         CREATE (a)-[r:{relationship}]->(b)
#         """
#         self.execute_query(query)

#     def search_nodes(self, label: str, property_name: str, property_value: str):
#         query = f"MATCH (n:{label} {{{property_name}: '{property_value}'}}) RETURN n"
#         return self.execute_query(query)

#     def search_relationships(self, relationship: str):
#         query = f"MATCH ()-[r:{relationship}]->() RETURN r"
#         return self.execute_query(query)


# # Custom Markdown extension to extract headings
# class HeadingExtractor(Treeprocessor):
#     def __init__(self, md):
#         super().__init__(md)
#         self.headings = []

#     def run(self, root):
#         for element in root:
#             if element.tag.startswith('h'):
#                 self.headings.append((element.tag, element.text))
#         return root

# class ExtractHeadings(Extension):
#     def extendMarkdown(self, md):
#         heading_extractor = HeadingExtractor(md)
#         md.treeprocessors.register(heading_extractor, 'extract_headings', 10)
#         md.heading_extractor = heading_extractor

# # Function to parse a markdown file and extract headings and links
# def parse_markdown(file_path):
#     md = Markdown(extensions=[ExtractHeadings()])
#     with open(file_path, 'r', encoding='utf-8') as f:
#         content = f.read()
#     md.convert(content)
#     links = re.findall(r'\[.*?\]\((.*?)\)', content)
#     return md.heading_extractor.headings, links

# # Function to sanitize heading text for Cypher queries
# def sanitize_text(text):
#     if text is None:
#         return "None"
#     sanitized = text.replace("'", "\\'").replace("#", "").replace("?", "")
#     return sanitized

# # Path to the directory containing markdown files (Obsidian vault)
# notes_dir = '/Users/dcarmocan/Projects/mind-cave'

# %%
import os
import mgclient
from markdown import Markdown
from markdown.treeprocessors import Treeprocessor
from markdown.extensions import Extension
import re

# Initialize the MemgraphManager
class MemgraphManager:
    def __init__(self):
        try:
            self.connection = mgclient.connect(host='localhost', port=7687, lazy=False)
            self.connection.autocommit = True
        except Exception as e:
            print(f"Failed to connect to Memgraph: {e}")
            raise

    def execute_query(self, query: str):
        print(f"Executing query: {query}")
        try:
            cursor = self.connection.cursor()
            cursor.execute(query)
            results = cursor.fetchall()
            cursor.close()
            print("Query executed successfully.")
            return results
        except Exception as e:
            print(f"Failed to execute query: {e}")
            if cursor:
                cursor.close()
            raise

    def find_duplicates(self):
        query = """
        MATCH (n)
        WITH n.name AS name, collect(n) AS nodes
        WHERE size(nodes) > 1
        RETURN name, nodes
        """
        return self.execute_query(query)

    def merge_nodes(self, name):
        sanitized_name = sanitize_text(name)
        merge_query_corrected = f"""
        CALL merge.node(
            ['File'], 
            {{name: '{sanitized_name}'}},
            {{}},
            {{}}
        ) YIELD node
        RETURN node
        """
        self.execute_query(merge_query_corrected)

    def merge_duplicates(self):
        duplicates = self.find_duplicates()
        for name, _ in duplicates:
            try:
                self.merge_nodes(name)
            except Exception as e:
                print(f"Failed to merge nodes with name '{name}': {e}")

    def create_node(self, label: str, properties: dict):
        props = ", ".join([f"{k}: '{sanitize_text(v)}'" for k, v in properties.items()])
        query = f"CREATE (n:{label} {{{props}}})"
        self.execute_query(query)

    def create_edge(self, from_node: str, to_node: str, relationship: str):
        query = f"""
        MATCH (a), (b)
        WHERE a.name = '{sanitize_text(from_node)}' AND b.name = '{sanitize_text(to_node)}'
        CREATE (a)-[r:{relationship}]->(b)
        """
        self.execute_query(query)

    def search_nodes(self, label: str, property_name: str, property_value: str):
        query = f"MATCH (n:{label} {{{property_name}: '{property_value}'}}) RETURN n"
        return self.execute_query(query)

    def search_relationships(self, relationship: str):
        query = f"MATCH ()-[r:{relationship}]->() RETURN r"
        return self.execute_query(query)

# Custom Markdown extension to extract headings
class HeadingExtractor(Treeprocessor):
    def __init__(self, md):
        super().__init__(md)
        self.headings = []

    def run(self, root):
        for element in root:
            if element.tag.startswith('h'):
                self.headings.append((element.tag, element.text))
        return root

class ExtractHeadings(Extension):
    def extendMarkdown(self, md):
        heading_extractor = HeadingExtractor(md)
        md.treeprocessors.register(heading_extractor, 'extract_headings', 10)
        md.heading_extractor = heading_extractor

# Function to parse a markdown file and extract headings and links
def parse_markdown(file_path):
    md = Markdown(extensions=[ExtractHeadings()])
    with open(file_path, 'r', encoding='utf-8') as f:
        content = f.read()
    md.convert(content)
    links = re.findall(r'\[.*?\]\((.*?)\)', content)
    return md.heading_extractor.headings, links

# Function to sanitize text for Cypher queries
def sanitize_text(text):
    if text is None:
        return "None"
    sanitized = re.sub(r"[^a-zA-Z0-9_\s]", "", text.replace("'", "\\'").replace("#", "").replace("?", ""))
    return sanitized

# %%
# Path to the directory containing markdown files (Obsidian vault)
notes_dir = '/Users/dcarmocan/Projects/mind-cave'

# Initialize the MemgraphManager
mg_manager = MemgraphManager()

# Process each markdown file in the directory
for root, dirs, files in os.walk(notes_dir):
    for file in files:
        if file.endswith('.md'):
            file_path = os.path.join(root, file)
            print(f"Processing file: {file_path}")
            
            # Extract headings and links
            headings, links = parse_markdown(file_path)
            file_name = os.path.basename(file_path)
            
            # Create a node for the file
            mg_manager.create_node('File', {'name': file_name})
            
            # Create nodes and edges for each heading
            previous_heading = file_name
            for tag, heading in headings:
                sanitized_heading = sanitize_text(heading)
                heading_node = f"{file_name}_{sanitized_heading}"
                mg_manager.create_node(tag, {'name': heading_node})
                mg_manager.create_edge(previous_heading, heading_node, 'CONTAINS')
                previous_heading = heading_node

            # Create edges for links to other files
            for link in links:
                link_file_name = os.path.basename(link)
                mg_manager.create_edge(file_name, link_file_name, 'LINKS_TO')

# Merge duplicate nodes
mg_manager.merge_duplicates()
# Out:
# Processing file: /Users/dcarmocan/Projects/mind-cave/SPOG.md
# Executing query: CREATE (n:File {name: 'SPOG.md'})
# Query executed successfully.
# Executing query: CREATE (n:hr {name: 'SPOG.md_None'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'SPOG.md'}), (b:File {name: 'SPOG.md_None'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:hr {name: 'SPOG.md_None'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'SPOG.md_None'}), (b:File {name: 'SPOG.md_None'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h3 {name: 'SPOG.md_SPOG'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'SPOG.md_None'}), (b:File {name: 'SPOG.md_SPOG'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h4 {name: 'SPOG.md_Zoom SPOG'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'SPOG.md_SPOG'}), (b:File {name: 'SPOG.md_Zoom SPOG'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h2 {name: 'SPOG.md_- Carmine asked for a couple of things for the SPOG on [[2023-03-16]] .  I need to look and see if I can get these items completed in time for the meeting today.'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'SPOG.md_Zoom SPOG'}), (b:File {name: 'SPOG.md_- Carmine asked for a couple of things for the SPOG on [[2023-03-16]] .  I need to look and see if I can get these items completed in time for the meeting today.'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h4 {name: 'SPOG.md_VDI SPOG'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'SPOG.md_- Carmine asked for a couple of things for the SPOG on [[2023-03-16]] .  I need to look and see if I can get these items completed in time for the meeting today.'}), (b:File {name: 'SPOG.md_VDI SPOG'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Processing file: /Users/dcarmocan/Projects/mind-cave/Zoom Dashboard Documentation.md
# Executing query: CREATE (n:File {name: 'Zoom Dashboard Documentation.md'})
# Query executed successfully.
# Executing query: CREATE (n:hr {name: 'Zoom Dashboard Documentation.md_None'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Zoom Dashboard Documentation.md'}), (b:File {name: 'Zoom Dashboard Documentation.md_None'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:hr {name: 'Zoom Dashboard Documentation.md_None'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Zoom Dashboard Documentation.md_None'}), (b:File {name: 'Zoom Dashboard Documentation.md_None'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h1 {name: 'Zoom Dashboard Documentation.md_kb'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Zoom Dashboard Documentation.md_None'}), (b:File {name: 'Zoom Dashboard Documentation.md_kb'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h1 {name: 'Zoom Dashboard Documentation.md_Zoom API Integration Documentation'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Zoom Dashboard Documentation.md_kb'}), (b:File {name: 'Zoom Dashboard Documentation.md_Zoom API Integration Documentation'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h2 {name: 'Zoom Dashboard Documentation.md_Table of Contents'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Zoom Dashboard Documentation.md_Zoom API Integration Documentation'}), (b:File {name: 'Zoom Dashboard Documentation.md_Table of Contents'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h2 {name: 'Zoom Dashboard Documentation.md_1. Introduction'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Zoom Dashboard Documentation.md_Table of Contents'}), (b:File {name: 'Zoom Dashboard Documentation.md_1. Introduction'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h2 {name: 'Zoom Dashboard Documentation.md_2. Prerequisites'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Zoom Dashboard Documentation.md_1. Introduction'}), (b:File {name: 'Zoom Dashboard Documentation.md_2. Prerequisites'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h2 {name: 'Zoom Dashboard Documentation.md_3. Authentication'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Zoom Dashboard Documentation.md_2. Prerequisites'}), (b:File {name: 'Zoom Dashboard Documentation.md_3. Authentication'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h2 {name: 'Zoom Dashboard Documentation.md_4. Gathering Data from Zoom Meetings'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Zoom Dashboard Documentation.md_3. Authentication'}), (b:File {name: 'Zoom Dashboard Documentation.md_4. Gathering Data from Zoom Meetings'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h2 {name: 'Zoom Dashboard Documentation.md_5. Gathering Data from Zoom Webinars'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Zoom Dashboard Documentation.md_4. Gathering Data from Zoom Meetings'}), (b:File {name: 'Zoom Dashboard Documentation.md_5. Gathering Data from Zoom Webinars'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h2 {name: 'Zoom Dashboard Documentation.md_6. Generating Insights'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Zoom Dashboard Documentation.md_5. Gathering Data from Zoom Webinars'}), (b:File {name: 'Zoom Dashboard Documentation.md_6. Generating Insights'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h2 {name: 'Zoom Dashboard Documentation.md_7. High-Level Overview'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Zoom Dashboard Documentation.md_6. Generating Insights'}), (b:File {name: 'Zoom Dashboard Documentation.md_7. High-Level Overview'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h2 {name: 'Zoom Dashboard Documentation.md_8. Conclusion'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Zoom Dashboard Documentation.md_7. High-Level Overview'}), (b:File {name: 'Zoom Dashboard Documentation.md_8. Conclusion'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Processing file: /Users/dcarmocan/Projects/mind-cave/Summary Week - 20230915.md
# Executing query: CREATE (n:File {name: 'Summary Week - 20230915.md'})
# Query executed successfully.
# Executing query: CREATE (n:hr {name: 'Summary Week - 20230915.md_None'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Summary Week - 20230915.md'}), (b:File {name: 'Summary Week - 20230915.md_None'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:hr {name: 'Summary Week - 20230915.md_None'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Summary Week - 20230915.md_None'}), (b:File {name: 'Summary Week - 20230915.md_None'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h1 {name: 'Summary Week - 20230915.md_weekly-status'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Summary Week - 20230915.md_None'}), (b:File {name: 'Summary Week - 20230915.md_weekly-status'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h1 {name: 'Summary Week - 20230915.md_Status Update'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Summary Week - 20230915.md_weekly-status'}), (b:File {name: 'Summary Week - 20230915.md_Status Update'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Processing file: /Users/dcarmocan/Projects/mind-cave/Project Plan Template.md
# Executing query: CREATE (n:File {name: 'Project Plan Template.md'})
# Query executed successfully.
# Executing query: CREATE (n:hr {name: 'Project Plan Template.md_None'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Project Plan Template.md'}), (b:File {name: 'Project Plan Template.md_None'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:hr {name: 'Project Plan Template.md_None'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Project Plan Template.md_None'}), (b:File {name: 'Project Plan Template.md_None'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h1 {name: 'Project Plan Template.md_templates'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Project Plan Template.md_None'}), (b:File {name: 'Project Plan Template.md_templates'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h1 {name: 'Project Plan Template.md_Project Summary'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Project Plan Template.md_templates'}), (b:File {name: 'Project Plan Template.md_Project Summary'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h1 {name: 'Project Plan Template.md_Project Team'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Project Plan Template.md_Project Summary'}), (b:File {name: 'Project Plan Template.md_Project Team'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h1 {name: 'Project Plan Template.md_In Scope'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Project Plan Template.md_Project Team'}), (b:File {name: 'Project Plan Template.md_In Scope'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h1 {name: 'Project Plan Template.md_Out-of-Scope'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Project Plan Template.md_In Scope'}), (b:File {name: 'Project Plan Template.md_Out-of-Scope'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h1 {name: 'Project Plan Template.md_Project Requirements'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Project Plan Template.md_Out-of-Scope'}), (b:File {name: 'Project Plan Template.md_Project Requirements'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h2 {name: 'Project Plan Template.md_Objectives'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Project Plan Template.md_Project Requirements'}), (b:File {name: 'Project Plan Template.md_Objectives'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h2 {name: 'Project Plan Template.md_Scopes'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Project Plan Template.md_Objectives'}), (b:File {name: 'Project Plan Template.md_Scopes'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h2 {name: 'Project Plan Template.md_Assumptions'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Project Plan Template.md_Scopes'}), (b:File {name: 'Project Plan Template.md_Assumptions'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h1 {name: 'Project Plan Template.md_Impact Analysis'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Project Plan Template.md_Assumptions'}), (b:File {name: 'Project Plan Template.md_Impact Analysis'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h2 {name: 'Project Plan Template.md_Key Business Areas'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Project Plan Template.md_Impact Analysis'}), (b:File {name: 'Project Plan Template.md_Key Business Areas'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h2 {name: 'Project Plan Template.md_Critical Functions'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Project Plan Template.md_Key Business Areas'}), (b:File {name: 'Project Plan Template.md_Critical Functions'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h2 {name: 'Project Plan Template.md_Dependencies'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Project Plan Template.md_Critical Functions'}), (b:File {name: 'Project Plan Template.md_Dependencies'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h2 {name: 'Project Plan Template.md_Determine Acceptable Downtime'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Project Plan Template.md_Dependencies'}), (b:File {name: 'Project Plan Template.md_Determine Acceptable Downtime'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h2 {name: 'Project Plan Template.md_Priority'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Project Plan Template.md_Determine Acceptable Downtime'}), (b:File {name: 'Project Plan Template.md_Priority'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h2 {name: 'Project Plan Template.md_Critical Applications & Downtime'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Project Plan Template.md_Priority'}), (b:File {name: 'Project Plan Template.md_Critical Applications & Downtime'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h1 {name: 'Project Plan Template.md_Test Plan'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Project Plan Template.md_Critical Applications & Downtime'}), (b:File {name: 'Project Plan Template.md_Test Plan'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h1 {name: 'Project Plan Template.md_Execution'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Project Plan Template.md_Test Plan'}), (b:File {name: 'Project Plan Template.md_Execution'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h2 {name: 'Project Plan Template.md_Execution Team'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Project Plan Template.md_Execution'}), (b:File {name: 'Project Plan Template.md_Execution Team'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h2 {name: 'Project Plan Template.md_Continuity Plan'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Project Plan Template.md_Execution Team'}), (b:File {name: 'Project Plan Template.md_Continuity Plan'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h3 {name: 'Project Plan Template.md_Checklist:'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Project Plan Template.md_Continuity Plan'}), (b:File {name: 'Project Plan Template.md_Checklist:'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h2 {name: 'Project Plan Template.md_Maintainer Plan'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Project Plan Template.md_Checklist:'}), (b:File {name: 'Project Plan Template.md_Maintainer Plan'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h2 {name: 'Project Plan Template.md_Communications Plan'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Project Plan Template.md_Maintainer Plan'}), (b:File {name: 'Project Plan Template.md_Communications Plan'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h1 {name: 'Project Plan Template.md_Training And Research'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Project Plan Template.md_Communications Plan'}), (b:File {name: 'Project Plan Template.md_Training And Research'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h1 {name: 'Project Plan Template.md_References'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Project Plan Template.md_Training And Research'}), (b:File {name: 'Project Plan Template.md_References'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Processing file: /Users/dcarmocan/Projects/mind-cave/Cap_Planning_Article.md
# Executing query: CREATE (n:File {name: 'Cap_Planning_Article.md'})
# Query executed successfully.
# Executing query: CREATE (n:hr {name: 'Cap_Planning_Article.md_None'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Cap_Planning_Article.md'}), (b:File {name: 'Cap_Planning_Article.md_None'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:hr {name: 'Cap_Planning_Article.md_None'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Cap_Planning_Article.md_None'}), (b:File {name: 'Cap_Planning_Article.md_None'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h1 {name: 'Cap_Planning_Article.md_process-docs'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Cap_Planning_Article.md_None'}), (b:File {name: 'Cap_Planning_Article.md_process-docs'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h1 {name: 'Cap_Planning_Article.md_Mastering Work Prioritization: Overcoming the Challenges of High-Priority Task Overload in Business and Technology Systems'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Cap_Planning_Article.md_process-docs'}), (b:File {name: 'Cap_Planning_Article.md_Mastering Work Prioritization: Overcoming the Challenges of High-Priority Task Overload in Business and Technology Systems'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h2 {name: 'Cap_Planning_Article.md_Navigating the Perils of Resource Saturation in Agile Sprints'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Cap_Planning_Article.md_Mastering Work Prioritization: Overcoming the Challenges of High-Priority Task Overload in Business and Technology Systems'}), (b:File {name: 'Cap_Planning_Article.md_Navigating the Perils of Resource Saturation in Agile Sprints'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h1 {name: 'Cap_Planning_Article.md_The Importance of Meaningful Prioritization in Agile Sprints'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Cap_Planning_Article.md_Navigating the Perils of Resource Saturation in Agile Sprints'}), (b:File {name: 'Cap_Planning_Article.md_The Importance of Meaningful Prioritization in Agile Sprints'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h3 {name: 'Cap_Planning_Article.md_None'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Cap_Planning_Article.md_The Importance of Meaningful Prioritization in Agile Sprints'}), (b:File {name: 'Cap_Planning_Article.md_None'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h3 {name: 'Cap_Planning_Article.md_None'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Cap_Planning_Article.md_None'}), (b:File {name: 'Cap_Planning_Article.md_None'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h1 {name: 'Cap_Planning_Article.md_Addressing the Impact of Stress on Decision-Making and Teamwork in Agile Environments'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Cap_Planning_Article.md_None'}), (b:File {name: 'Cap_Planning_Article.md_Addressing the Impact of Stress on Decision-Making and Teamwork in Agile Environments'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h2 {name: 'Cap_Planning_Article.md_None'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Cap_Planning_Article.md_Addressing the Impact of Stress on Decision-Making and Teamwork in Agile Environments'}), (b:File {name: 'Cap_Planning_Article.md_None'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h2 {name: 'Cap_Planning_Article.md_None'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Cap_Planning_Article.md_None'}), (b:File {name: 'Cap_Planning_Article.md_None'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h1 {name: 'Cap_Planning_Article.md_None'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Cap_Planning_Article.md_None'}), (b:File {name: 'Cap_Planning_Article.md_None'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Processing file: /Users/dcarmocan/Projects/mind-cave/Terminator_Doc.md
# Executing query: CREATE (n:File {name: 'Terminator_Doc.md'})
# Query executed successfully.
# Executing query: CREATE (n:hr {name: 'Terminator_Doc.md_None'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Terminator_Doc.md'}), (b:File {name: 'Terminator_Doc.md_None'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:hr {name: 'Terminator_Doc.md_None'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Terminator_Doc.md_None'}), (b:File {name: 'Terminator_Doc.md_None'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h1 {name: 'Terminator_Doc.md_process-docs'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Terminator_Doc.md_None'}), (b:File {name: 'Terminator_Doc.md_process-docs'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h2 {name: 'Terminator_Doc.md_Introduction'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Terminator_Doc.md_process-docs'}), (b:File {name: 'Terminator_Doc.md_Introduction'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h2 {name: 'Terminator_Doc.md_Addressing Off-boarding Needs'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Terminator_Doc.md_Introduction'}), (b:File {name: 'Terminator_Doc.md_Addressing Off-boarding Needs'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h3 {name: 'Terminator_Doc.md_Event-Driven Automation Through Google Workspace Admin'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Terminator_Doc.md_Addressing Off-boarding Needs'}), (b:File {name: 'Terminator_Doc.md_Event-Driven Automation Through Google Workspace Admin'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h4 {name: 'Terminator_Doc.md_Google Admin SDK and Cloud Logging Integration'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Terminator_Doc.md_Event-Driven Automation Through Google Workspace Admin'}), (b:File {name: 'Terminator_Doc.md_Google Admin SDK and Cloud Logging Integration'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h4 {name: 'Terminator_Doc.md_Event Filtering'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Terminator_Doc.md_Google Admin SDK and Cloud Logging Integration'}), (b:File {name: 'Terminator_Doc.md_Event Filtering'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h4 {name: 'Terminator_Doc.md_Domain-Wide Delegation and Service Account'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Terminator_Doc.md_Event Filtering'}), (b:File {name: 'Terminator_Doc.md_Domain-Wide Delegation and Service Account'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h2 {name: 'Terminator_Doc.md_The Tech Stack'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Terminator_Doc.md_Domain-Wide Delegation and Service Account'}), (b:File {name: 'Terminator_Doc.md_The Tech Stack'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h3 {name: 'Terminator_Doc.md_Google Admin SDK'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Terminator_Doc.md_The Tech Stack'}), (b:File {name: 'Terminator_Doc.md_Google Admin SDK'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h3 {name: 'Terminator_Doc.md_Google Cloud Logging'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Terminator_Doc.md_Google Admin SDK'}), (b:File {name: 'Terminator_Doc.md_Google Cloud Logging'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h3 {name: 'Terminator_Doc.md_Google Pub/Sub'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Terminator_Doc.md_Google Cloud Logging'}), (b:File {name: 'Terminator_Doc.md_Google Pub/Sub'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h3 {name: 'Terminator_Doc.md_Google Cloud Functions'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Terminator_Doc.md_Google Pub/Sub'}), (b:File {name: 'Terminator_Doc.md_Google Cloud Functions'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h3 {name: 'Terminator_Doc.md_Google Cloud Run'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Terminator_Doc.md_Google Cloud Functions'}), (b:File {name: 'Terminator_Doc.md_Google Cloud Run'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h3 {name: 'Terminator_Doc.md_Google Eventarc'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Terminator_Doc.md_Google Cloud Run'}), (b:File {name: 'Terminator_Doc.md_Google Eventarc'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h2 {name: 'Terminator_Doc.md_Benefits and Cost Savings of the Terminator Project'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Terminator_Doc.md_Google Eventarc'}), (b:File {name: 'Terminator_Doc.md_Benefits and Cost Savings of the Terminator Project'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h3 {name: 'Terminator_Doc.md_Financial Savings'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Terminator_Doc.md_Benefits and Cost Savings of the Terminator Project'}), (b:File {name: 'Terminator_Doc.md_Financial Savings'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h3 {name: 'Terminator_Doc.md_Customization and Flexibility'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Terminator_Doc.md_Financial Savings'}), (b:File {name: 'Terminator_Doc.md_Customization and Flexibility'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h3 {name: 'Terminator_Doc.md_Improved Security and Compliance'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Terminator_Doc.md_Customization and Flexibility'}), (b:File {name: 'Terminator_Doc.md_Improved Security and Compliance'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h3 {name: 'Terminator_Doc.md_Enhanced Integration'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Terminator_Doc.md_Improved Security and Compliance'}), (b:File {name: 'Terminator_Doc.md_Enhanced Integration'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h3 {name: 'Terminator_Doc.md_Scalability and Performance'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Terminator_Doc.md_Enhanced Integration'}), (b:File {name: 'Terminator_Doc.md_Scalability and Performance'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h3 {name: 'Terminator_Doc.md_Increased Control and Visibility'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Terminator_Doc.md_Scalability and Performance'}), (b:File {name: 'Terminator_Doc.md_Increased Control and Visibility'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h2 {name: 'Terminator_Doc.md_Integrating Google Workspace Admin with GCP Using Log Sinks: A High-Level Overview'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Terminator_Doc.md_Increased Control and Visibility'}), (b:File {name: 'Terminator_Doc.md_Integrating Google Workspace Admin with GCP Using Log Sinks: A High-Level Overview'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h3 {name: 'Terminator_Doc.md_What are Log Sinks'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Terminator_Doc.md_Integrating Google Workspace Admin with GCP Using Log Sinks: A High-Level Overview'}), (b:File {name: 'Terminator_Doc.md_What are Log Sinks'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h3 {name: 'Terminator_Doc.md_How do Log Sinks work with Google Workspace Admin'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Terminator_Doc.md_What are Log Sinks'}), (b:File {name: 'Terminator_Doc.md_How do Log Sinks work with Google Workspace Admin'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h3 {name: 'Terminator_Doc.md_Why use Log Sinks for off-boarding automation'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Terminator_Doc.md_How do Log Sinks work with Google Workspace Admin'}), (b:File {name: 'Terminator_Doc.md_Why use Log Sinks for off-boarding automation'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h1 {name: 'Terminator_Doc.md_!/bin/bash'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Terminator_Doc.md_Why use Log Sinks for off-boarding automation'}), (b:File {name: 'Terminator_Doc.md_!/bin/bash'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h1 {name: 'Terminator_Doc.md_Get the hostname'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Terminator_Doc.md_!/bin/bash'}), (b:File {name: 'Terminator_Doc.md_Get the hostname'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h1 {name: 'Terminator_Doc.md_Get the memory usage'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Terminator_Doc.md_Get the hostname'}), (b:File {name: 'Terminator_Doc.md_Get the memory usage'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h1 {name: 'Terminator_Doc.md_Get the CPU usage'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Terminator_Doc.md_Get the memory usage'}), (b:File {name: 'Terminator_Doc.md_Get the CPU usage'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Processing file: /Users/dcarmocan/Projects/mind-cave/SMART_GOALS_Format.md
# Executing query: CREATE (n:File {name: 'SMART_GOALS_Format.md'})
# Query executed successfully.
# Executing query: CREATE (n:hr {name: 'SMART_GOALS_Format.md_None'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'SMART_GOALS_Format.md'}), (b:File {name: 'SMART_GOALS_Format.md_None'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:hr {name: 'SMART_GOALS_Format.md_None'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'SMART_GOALS_Format.md_None'}), (b:File {name: 'SMART_GOALS_Format.md_None'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h1 {name: 'SMART_GOALS_Format.md_process-docs'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'SMART_GOALS_Format.md_None'}), (b:File {name: 'SMART_GOALS_Format.md_process-docs'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h2 {name: 'SMART_GOALS_Format.md_What are SMART goals'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'SMART_GOALS_Format.md_process-docs'}), (b:File {name: 'SMART_GOALS_Format.md_What are SMART goals'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h2 {name: 'SMART_GOALS_Format.md_How to write SMART goals'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'SMART_GOALS_Format.md_What are SMART goals'}), (b:File {name: 'SMART_GOALS_Format.md_How to write SMART goals'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h2 {name: 'SMART_GOALS_Format.md_S: Specific'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'SMART_GOALS_Format.md_How to write SMART goals'}), (b:File {name: 'SMART_GOALS_Format.md_S: Specific'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h6 {name: 'SMART_GOALS_Format.md_SPECIFIC'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'SMART_GOALS_Format.md_S: Specific'}), (b:File {name: 'SMART_GOALS_Format.md_SPECIFIC'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h2 {name: 'SMART_GOALS_Format.md_M: Measurable'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'SMART_GOALS_Format.md_SPECIFIC'}), (b:File {name: 'SMART_GOALS_Format.md_M: Measurable'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h6 {name: 'SMART_GOALS_Format.md_MEASURABLE'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'SMART_GOALS_Format.md_M: Measurable'}), (b:File {name: 'SMART_GOALS_Format.md_MEASURABLE'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h2 {name: 'SMART_GOALS_Format.md_A: Achievable'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'SMART_GOALS_Format.md_MEASURABLE'}), (b:File {name: 'SMART_GOALS_Format.md_A: Achievable'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h6 {name: 'SMART_GOALS_Format.md_ACHIEVABLE'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'SMART_GOALS_Format.md_A: Achievable'}), (b:File {name: 'SMART_GOALS_Format.md_ACHIEVABLE'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h2 {name: 'SMART_GOALS_Format.md_R: Relevant'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'SMART_GOALS_Format.md_ACHIEVABLE'}), (b:File {name: 'SMART_GOALS_Format.md_R: Relevant'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h6 {name: 'SMART_GOALS_Format.md_RELEVANT'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'SMART_GOALS_Format.md_R: Relevant'}), (b:File {name: 'SMART_GOALS_Format.md_RELEVANT'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h2 {name: 'SMART_GOALS_Format.md_T: Time-bound'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'SMART_GOALS_Format.md_RELEVANT'}), (b:File {name: 'SMART_GOALS_Format.md_T: Time-bound'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'SMART_GOALS_Format.md'}), (b:File {name: 'brand-4069-90-day-plan-template-blog-illustration-1120x545-@2x-v2-600x480.png'})
#         CREATE (a)-[r:LINKS_TO]->(b)
#
# Query executed successfully.
# Processing file: /Users/dcarmocan/Projects/mind-cave/Cap_planning_notes.md
# Executing query: CREATE (n:File {name: 'Cap_planning_notes.md'})
# Query executed successfully.
# Executing query: CREATE (n:hr {name: 'Cap_planning_notes.md_None'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Cap_planning_notes.md'}), (b:File {name: 'Cap_planning_notes.md_None'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:hr {name: 'Cap_planning_notes.md_None'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Cap_planning_notes.md_None'}), (b:File {name: 'Cap_planning_notes.md_None'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h1 {name: 'Cap_planning_notes.md_process-docs'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Cap_planning_notes.md_None'}), (b:File {name: 'Cap_planning_notes.md_process-docs'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Cap_planning_notes.md'}), (b:File {name: '%3e'})
#         CREATE (a)-[r:LINKS_TO]->(b)
#
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Cap_planning_notes.md'}), (b:File {name: 'image?url=https%3A%2F%2Flh3.googleusercontent.com%2Fa%2FAGNmyxYCaUfhW6asHZK6aGbE4KLSHPU82W5EUnBZe7M3%3Ds96-c&w=64&q=75'})
#         CREATE (a)-[r:LINKS_TO]->(b)
#
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Cap_planning_notes.md'}), (b:File {name: '%3e'})
#         CREATE (a)-[r:LINKS_TO]->(b)
#
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Cap_planning_notes.md'}), (b:File {name: 'image?url=https%3A%2F%2Flh3.googleusercontent.com%2Fa%2FAGNmyxYCaUfhW6asHZK6aGbE4KLSHPU82W5EUnBZe7M3%3Ds96-c&w=64&q=75'})
#         CREATE (a)-[r:LINKS_TO]->(b)
#
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Cap_planning_notes.md'}), (b:File {name: '%3e'})
#         CREATE (a)-[r:LINKS_TO]->(b)
#
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Cap_planning_notes.md'}), (b:File {name: 'image?url=https%3A%2F%2Flh3.googleusercontent.com%2Fa%2FAGNmyxYCaUfhW6asHZK6aGbE4KLSHPU82W5EUnBZe7M3%3Ds96-c&w=64&q=75'})
#         CREATE (a)-[r:LINKS_TO]->(b)
#
# Query executed successfully.
# Processing file: /Users/dcarmocan/Projects/mind-cave/slack_tasks.md
# Executing query: CREATE (n:File {name: 'slack_tasks.md'})
# Query executed successfully.
# Executing query: CREATE (n:hr {name: 'slack_tasks.md_None'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'slack_tasks.md'}), (b:File {name: 'slack_tasks.md_None'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:hr {name: 'slack_tasks.md_None'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'slack_tasks.md_None'}), (b:File {name: 'slack_tasks.md_None'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h1 {name: 'slack_tasks.md_'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'slack_tasks.md_None'}), (b:File {name: 'slack_tasks.md_'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Processing file: /Users/dcarmocan/Projects/mind-cave/DISP_Discussion.md
# Executing query: CREATE (n:File {name: 'DISP_Discussion.md'})
# Query executed successfully.
# Executing query: CREATE (n:hr {name: 'DISP_Discussion.md_None'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'DISP_Discussion.md'}), (b:File {name: 'DISP_Discussion.md_None'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:hr {name: 'DISP_Discussion.md_None'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'DISP_Discussion.md_None'}), (b:File {name: 'DISP_Discussion.md_None'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h1 {name: 'DISP_Discussion.md_DISP Project Discussion'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'DISP_Discussion.md_None'}), (b:File {name: 'DISP_Discussion.md_DISP Project Discussion'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'DISP_Discussion.md'}), (b:File {name: 'p1698185838579289'})
#         CREATE (a)-[r:LINKS_TO]->(b)
#
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'DISP_Discussion.md'}), (b:File {name: 'U05ND2K0BBR'})
#         CREATE (a)-[r:LINKS_TO]->(b)
#
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'DISP_Discussion.md'}), (b:File {name: 'W01918HTJHW'})
#         CREATE (a)-[r:LINKS_TO]->(b)
#
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'DISP_Discussion.md'}), (b:File {name: 'p1698197733807279'})
#         CREATE (a)-[r:LINKS_TO]->(b)
#
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'DISP_Discussion.md'}), (b:File {name: 'p1698199096522449'})
#         CREATE (a)-[r:LINKS_TO]->(b)
#
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'DISP_Discussion.md'}), (b:File {name: 'W01918HTJHW'})
#         CREATE (a)-[r:LINKS_TO]->(b)
#
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'DISP_Discussion.md'}), (b:File {name: 'U05ND2K0BBR'})
#         CREATE (a)-[r:LINKS_TO]->(b)
#
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'DISP_Discussion.md'}), (b:File {name: 'U05ND2K0BBR'})
#         CREATE (a)-[r:LINKS_TO]->(b)
#
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'DISP_Discussion.md'}), (b:File {name: 'p1698200655753679'})
#         CREATE (a)-[r:LINKS_TO]->(b)
#
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'DISP_Discussion.md'}), (b:File {name: 'p1698200959452739'})
#         CREATE (a)-[r:LINKS_TO]->(b)
#
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'DISP_Discussion.md'}), (b:File {name: 'U05ND2K0BBR'})
#         CREATE (a)-[r:LINKS_TO]->(b)
#
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'DISP_Discussion.md'}), (b:File {name: 'p1698201714016489'})
#         CREATE (a)-[r:LINKS_TO]->(b)
#
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'DISP_Discussion.md'}), (b:File {name: 'p1698251558809229'})
#         CREATE (a)-[r:LINKS_TO]->(b)
#
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'DISP_Discussion.md'}), (b:File {name: 'p1698251941675909'})
#         CREATE (a)-[r:LINKS_TO]->(b)
#
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'DISP_Discussion.md'}), (b:File {name: 'edit#slide=id.p1'})
#         CREATE (a)-[r:LINKS_TO]->(b)
#
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'DISP_Discussion.md'}), (b:File {name: 'Splunk+Australian+M365+Tenant+Project'})
#         CREATE (a)-[r:LINKS_TO]->(b)
#
# Query executed successfully.
# Processing file: /Users/dcarmocan/Projects/mind-cave/GCP_Data_Engineer_Exam_Prep_Notes.md
# Executing query: CREATE (n:File {name: 'GCP_Data_Engineer_Exam_Prep_Notes.md'})
# Query executed successfully.
# Executing query: CREATE (n:hr {name: 'GCP_Data_Engineer_Exam_Prep_Notes.md_None'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'GCP_Data_Engineer_Exam_Prep_Notes.md'}), (b:File {name: 'GCP_Data_Engineer_Exam_Prep_Notes.md_None'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:hr {name: 'GCP_Data_Engineer_Exam_Prep_Notes.md_None'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'GCP_Data_Engineer_Exam_Prep_Notes.md_None'}), (b:File {name: 'GCP_Data_Engineer_Exam_Prep_Notes.md_None'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'GCP_Data_Engineer_Exam_Prep_Notes.md'}), (b:File {name: 'store-query-data'})
#         CREATE (a)-[r:LINKS_TO]->(b)
#
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'GCP_Data_Engineer_Exam_Prep_Notes.md'}), (b:File {name: 'store-query-data'})
#         CREATE (a)-[r:LINKS_TO]->(b)
#
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'GCP_Data_Engineer_Exam_Prep_Notes.md'}), (b:File {name: 'create-database-server-client-library'})
#         CREATE (a)-[r:LINKS_TO]->(b)
#
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'GCP_Data_Engineer_Exam_Prep_Notes.md'}), (b:File {name: 'create-instance-gcloud'})
#         CREATE (a)-[r:LINKS_TO]->(b)
#
# Query executed successfully.
# Processing file: /Users/dcarmocan/Projects/mind-cave/2023-07-20_CD-CD-Status.md
# Executing query: CREATE (n:File {name: '2023-07-20_CD-CD-Status.md'})
# Query executed successfully.
# Executing query: CREATE (n:hr {name: '2023-07-20_CD-CD-Status.md_None'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: '2023-07-20_CD-CD-Status.md'}), (b:File {name: '2023-07-20_CD-CD-Status.md_None'})
#         CREATE (a)-[r:CONTAINS]->(b)
# ...
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h4 {name: 'AdminTasks_App_Documentation.md_App User Configuration'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'AdminTasks_App_Documentation.md_Configuration'}), (b:File {name: 'AdminTasks_App_Documentation.md_App User Configuration'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h4 {name: 'AdminTasks_App_Documentation.md_Bot User Configuration'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'AdminTasks_App_Documentation.md_App User Configuration'}), (b:File {name: 'AdminTasks_App_Documentation.md_Bot User Configuration'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h4 {name: 'AdminTasks_App_Documentation.md_Token Configuration and Storage'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'AdminTasks_App_Documentation.md_Bot User Configuration'}), (b:File {name: 'AdminTasks_App_Documentation.md_Token Configuration and Storage'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h2 {name: 'AdminTasks_App_Documentation.md_Authorized Use and Applications'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'AdminTasks_App_Documentation.md_Token Configuration and Storage'}), (b:File {name: 'AdminTasks_App_Documentation.md_Authorized Use and Applications'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h3 {name: 'AdminTasks_App_Documentation.md_Slack Channel Convert'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'AdminTasks_App_Documentation.md_Authorized Use and Applications'}), (b:File {name: 'AdminTasks_App_Documentation.md_Slack Channel Convert'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h3 {name: 'AdminTasks_App_Documentation.md_Slack Channel Archive'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'AdminTasks_App_Documentation.md_Slack Channel Convert'}), (b:File {name: 'AdminTasks_App_Documentation.md_Slack Channel Archive'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'AdminTasks_App_Documentation.md'}), (b:File {name: '#admintasks-app-documentation'})
#         CREATE (a)-[r:LINKS_TO]->(b)
#
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'AdminTasks_App_Documentation.md'}), (b:File {name: '#introduction'})
#         CREATE (a)-[r:LINKS_TO]->(b)
#
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'AdminTasks_App_Documentation.md'}), (b:File {name: '#objective'})
#         CREATE (a)-[r:LINKS_TO]->(b)
#
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'AdminTasks_App_Documentation.md'}), (b:File {name: '#configuration'})
#         CREATE (a)-[r:LINKS_TO]->(b)
#
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'AdminTasks_App_Documentation.md'}), (b:File {name: '#app-user-configuration'})
#         CREATE (a)-[r:LINKS_TO]->(b)
#
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'AdminTasks_App_Documentation.md'}), (b:File {name: '#bot-user-configuration'})
#         CREATE (a)-[r:LINKS_TO]->(b)
#
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'AdminTasks_App_Documentation.md'}), (b:File {name: '#token-configuration-and-storage'})
#         CREATE (a)-[r:LINKS_TO]->(b)
#
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'AdminTasks_App_Documentation.md'}), (b:File {name: '#authorized-use-and-applications'})
#         CREATE (a)-[r:LINKS_TO]->(b)
#
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'AdminTasks_App_Documentation.md'}), (b:File {name: '#slack-channel-convert'})
#         CREATE (a)-[r:LINKS_TO]->(b)
#
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'AdminTasks_App_Documentation.md'}), (b:File {name: '#slack-channel-archive'})
#         CREATE (a)-[r:LINKS_TO]->(b)
#
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'AdminTasks_App_Documentation.md'}), (b:File {name: 'A019F103RQQ'})
#         CREATE (a)-[r:LINKS_TO]->(b)
#
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'AdminTasks_App_Documentation.md'}), (b:File {name: ''})
#         CREATE (a)-[r:LINKS_TO]->(b)
#
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'AdminTasks_App_Documentation.md'}), (b:File {name: 'secure-env'})
#         CREATE (a)-[r:LINKS_TO]->(b)
#
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'AdminTasks_App_Documentation.md'}), (b:File {name: 'edit'})
#         CREATE (a)-[r:LINKS_TO]->(b)
#
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'AdminTasks_App_Documentation.md'}), (b:File {name: 'edit'})
#         CREATE (a)-[r:LINKS_TO]->(b)
#
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'AdminTasks_App_Documentation.md'}), (b:File {name: 'conversations.archive'})
#         CREATE (a)-[r:LINKS_TO]->(b)
#
# Query executed successfully.
# Processing file: /Users/dcarmocan/Projects/mind-cave/Services/Harshicorp/Hashicorp_Vault_Docs.md
# Executing query: CREATE (n:File {name: 'Hashicorp_Vault_Docs.md'})
# Query executed successfully.
# Executing query: CREATE (n:hr {name: 'Hashicorp_Vault_Docs.md_None'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Hashicorp_Vault_Docs.md'}), (b:File {name: 'Hashicorp_Vault_Docs.md_None'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:hr {name: 'Hashicorp_Vault_Docs.md_None'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Hashicorp_Vault_Docs.md_None'}), (b:File {name: 'Hashicorp_Vault_Docs.md_None'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h1 {name: 'Hashicorp_Vault_Docs.md_vault process-docs'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Hashicorp_Vault_Docs.md_None'}), (b:File {name: 'Hashicorp_Vault_Docs.md_vault process-docs'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h1 {name: 'Hashicorp_Vault_Docs.md_Vault Docs'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Hashicorp_Vault_Docs.md_vault process-docs'}), (b:File {name: 'Hashicorp_Vault_Docs.md_Vault Docs'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h2 {name: 'Hashicorp_Vault_Docs.md_Login'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Hashicorp_Vault_Docs.md_Vault Docs'}), (b:File {name: 'Hashicorp_Vault_Docs.md_Login'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Processing file: /Users/dcarmocan/Projects/mind-cave/Utility/Scripts.md
# Executing query: CREATE (n:File {name: 'Scripts.md'})
# Query executed successfully.
# Executing query: CREATE (n:h1 {name: 'Scripts.md_scripts'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Scripts.md'}), (b:File {name: 'Scripts.md_scripts'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h1 {name: 'Scripts.md_Scripts List'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Scripts.md_scripts'}), (b:File {name: 'Scripts.md_Scripts List'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h2 {name: 'Scripts.md_Excalidraw Scripts'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Scripts.md_Scripts List'}), (b:File {name: 'Scripts.md_Excalidraw Scripts'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h3 {name: 'Scripts.md_Excalidraw SVG Elements'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Scripts.md_Excalidraw Scripts'}), (b:File {name: 'Scripts.md_Excalidraw SVG Elements'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Processing file: /Users/dcarmocan/Projects/mind-cave/Utility/Query_Test.md
# Executing query: CREATE (n:File {name: 'Query_Test.md'})
# Query executed successfully.
# Executing query: CREATE (n:hr {name: 'Query_Test.md_None'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Query_Test.md'}), (b:File {name: 'Query_Test.md_None'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:hr {name: 'Query_Test.md_None'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Query_Test.md_None'}), (b:File {name: 'Query_Test.md_None'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Processing file: /Users/dcarmocan/Projects/mind-cave/Utility/General Blurbs.md
# Executing query: CREATE (n:File {name: 'General Blurbs.md'})
# Query executed successfully.
# Executing query: CREATE (n:hr {name: 'General Blurbs.md_None'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'General Blurbs.md'}), (b:File {name: 'General Blurbs.md_None'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:hr {name: 'General Blurbs.md_None'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'General Blurbs.md_None'}), (b:File {name: 'General Blurbs.md_None'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h3 {name: 'General Blurbs.md_Inactive SNOW'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'General Blurbs.md_None'}), (b:File {name: 'General Blurbs.md_Inactive SNOW'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Processing file: /Users/dcarmocan/Projects/mind-cave/Utility/Slack_App_Blurbs.md
# Executing query: CREATE (n:File {name: 'Slack_App_Blurbs.md'})
# Query executed successfully.
# Executing query: CREATE (n:hr {name: 'Slack_App_Blurbs.md_None'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Slack_App_Blurbs.md'}), (b:File {name: 'Slack_App_Blurbs.md_None'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:hr {name: 'Slack_App_Blurbs.md_None'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Slack_App_Blurbs.md_None'}), (b:File {name: 'Slack_App_Blurbs.md_None'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h1 {name: 'Slack_App_Blurbs.md_slack blurbs'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Slack_App_Blurbs.md_None'}), (b:File {name: 'Slack_App_Blurbs.md_slack blurbs'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h1 {name: 'Slack_App_Blurbs.md_Slack App Blurbs'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Slack_App_Blurbs.md_slack blurbs'}), (b:File {name: 'Slack_App_Blurbs.md_Slack App Blurbs'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h2 {name: 'Slack_App_Blurbs.md_When Someone Asks for the Onboarding Process'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Slack_App_Blurbs.md_Slack App Blurbs'}), (b:File {name: 'Slack_App_Blurbs.md_When Someone Asks for the Onboarding Process'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h2 {name: 'Slack_App_Blurbs.md_When someone has questions about developing their own app:'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Slack_App_Blurbs.md_When Someone Asks for the Onboarding Process'}), (b:File {name: 'Slack_App_Blurbs.md_When someone has questions about developing their own app:'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query:
#         MATCH (n:File)
#         WITH n.name AS name, COUNT(n) AS count
#         WHERE count > 1
#         RETURN name, count
#
# Query executed successfully.
# Executing query:
#         MATCH (n:File {name: 'Slack.md'})
#         WITH COLLECT(n) AS nodes
#         CALL {
#             WITH nodes
#             UNWIND nodes AS n
#             WITH n LIMIT 1
#             RETURN n
#         }
#         WITH nodes, n AS to_keep
#         UNWIND nodes AS n
#         WITH n, to_keep WHERE n <> to_keep
#         OPTIONAL MATCH (n)-[r]-()
#         DELETE r
#         DETACH DELETE n
#         RETURN to_keep
#
# Query executed successfully.
# Executing query:
#         MATCH (n:File {name: 'GCP.md'})
#         WITH COLLECT(n) AS nodes
#         CALL {
#             WITH nodes
#             UNWIND nodes AS n
#             WITH n LIMIT 1
#             RETURN n
#         }
#         WITH nodes, n AS to_keep
#         UNWIND nodes AS n
#         WITH n, to_keep WHERE n <> to_keep
#         OPTIONAL MATCH (n)-[r]-()
#         DELETE r
#         DETACH DELETE n
#         RETURN to_keep
#
# Query executed successfully.
# Executing query:
#         MATCH (n:File {name: 'Untitled.md'})
#         WITH COLLECT(n) AS nodes
#         CALL {
#             WITH nodes
#             UNWIND nodes AS n
#             WITH n LIMIT 1
#             RETURN n
#         }
#         WITH nodes, n AS to_keep
#         UNWIND nodes AS n
#         WITH n, to_keep WHERE n <> to_keep
#         OPTIONAL MATCH (n)-[r]-()
#         DELETE r
#         DETACH DELETE n
#         RETURN to_keep
#
# Query executed successfully.
# Executing query:
#         MATCH (n:File {name: 'GitLab.md'})
#         WITH COLLECT(n) AS nodes
#         CALL {
#             WITH nodes
#             UNWIND nodes AS n
#             WITH n LIMIT 1
#             RETURN n
#         }
#         WITH nodes, n AS to_keep
#         UNWIND nodes AS n
#         WITH n, to_keep WHERE n <> to_keep
#         OPTIONAL MATCH (n)-[r]-()
#         DELETE r
#         DETACH DELETE n
#         RETURN to_keep
#
# Query executed successfully.
# Executing query:
#         MATCH (n:File {name: 'Home.md'})
#         WITH COLLECT(n) AS nodes
#         CALL {
#             WITH nodes
#             UNWIND nodes AS n
#             WITH n LIMIT 1
#             RETURN n
#         }
#         WITH nodes, n AS to_keep
#         UNWIND nodes AS n
#         WITH n, to_keep WHERE n <> to_keep
#         OPTIONAL MATCH (n)-[r]-()
#         DELETE r
#         DETACH DELETE n
#         RETURN to_keep
#
# Query executed successfully.
# Executing query:
#         MATCH (n:File {name: '.md'})
#         WITH COLLECT(n) AS nodes
#         CALL {
#             WITH nodes
#             UNWIND nodes AS n
#             WITH n LIMIT 1
#             RETURN n
#         }
#         WITH nodes, n AS to_keep
#         UNWIND nodes AS n
#         WITH n, to_keep WHERE n <> to_keep
#         OPTIONAL MATCH (n)-[r]-()
#         DELETE r
#         DETACH DELETE n
#         RETURN to_keep
#
# Query executed successfully.
# Executing query:
#         MATCH (n:File {name: 'Daily Notes.md'})
#         WITH COLLECT(n) AS nodes
#         CALL {
#             WITH nodes
#             UNWIND nodes AS n
#             WITH n LIMIT 1
#             RETURN n
#         }
#         WITH nodes, n AS to_keep
#         UNWIND nodes AS n
#         WITH n, to_keep WHERE n <> to_keep
#         OPTIONAL MATCH (n)-[r]-()
#         DELETE r
#         DETACH DELETE n
#         RETURN to_keep
#
# Query executed successfully.

# %% [markdown]
# #### Adding More Methods for Indexes and Constraints

# %%
import mgclient
import re

class MemgraphManager:
    def __init__(self):
        try:
            self.connection = mgclient.connect(host='localhost', port=7687, lazy=False)
            self.connection.autocommit = True
        except Exception as e:
            print(f"Failed to connect to Memgraph: {e}")
            raise

    def execute_query(self, query: str):
        print(f"Executing query: {query}")
        try:
            cursor = self.connection.cursor()
            cursor.execute(query)
            results = cursor.fetchall()
            cursor.close()
            print("Query executed successfully.")
            return results
        except Exception as e:
            print(f"Failed to execute query: {e}")
            if cursor:
                cursor.close()
            raise

    def find_duplicates(self):
        query = """
        MATCH (n:File)
        WITH n.name AS name, COUNT(n) AS count
        WHERE count > 1
        RETURN name, count
        """
        return self.execute_query(query)

    def merge_nodes(self, name):
        merge_query = f"""
        MATCH (n:File {{name: '{name}'}})
        WITH COLLECT(n) AS nodes
        CALL {{
            WITH nodes
            UNWIND nodes AS n
            WITH n LIMIT 1
            RETURN n
        }}
        WITH nodes, n AS to_keep
        UNWIND nodes AS n
        WITH n, to_keep WHERE n <> to_keep
        OPTIONAL MATCH (n)-[r]-()
        DELETE r
        DETACH DELETE n
        RETURN to_keep
        """
        self.execute_query(merge_query)

    def merge_duplicates(self):
        duplicates = self.find_duplicates()
        for name, _ in duplicates:
            self.merge_nodes(name)

    def create_node(self, label: str, properties: dict):
        props = ", ".join([f"{k}: '{v}'" for k, v in properties.items()])
        query = f"CREATE (n:{label} {{{props}}})"
        self.execute_query(query)

    def create_edge(self, from_node: str, to_node: str, relationship: str):
        query = f"""
        MATCH (a:File {{name: '{from_node}'}}), (b:File {{name: '{to_node}'}})
        CREATE (a)-[r:{relationship}]->(b)
        """
        self.execute_query(query)

    def sanitize_text(self, text):
        if text is None:
            return "None"
        sanitized = text.replace("'", "\\'").replace("#", "").replace("?", "")
        return sanitized

# %%
import os
import mgclient
from markdown import Markdown
from markdown.treeprocessors import Treeprocessor
from markdown.extensions import Extension
import re

class MemgraphManager:
    def __init__(self):
        try:
            self.connection = mgclient.connect(host='localhost', port=7687, lazy=False)
            self.connection.autocommit = True
        except Exception as e:
            print(f"Failed to connect to Memgraph: {e}")
            raise

    def execute_query(self, query: str):
        print(f"Executing query: {query}")
        try:
            cursor = self.connection.cursor()
            cursor.execute(query)
            results = cursor.fetchall()
            cursor.close()
            print("Query executed successfully.")
            return results
        except Exception as e:
            print(f"Failed to execute query: {e}")
            if cursor:
                cursor.close()
            raise

    def find_duplicates(self):
        query = """
        MATCH (n:File)
        WITH n.name AS name, COUNT(n) AS count
        WHERE count > 1
        RETURN name, count
        """
        return self.execute_query(query)

    def merge_nodes(self, name):
        merge_query = f"""
        MATCH (n:File {{name: '{name}'}})
        WITH COLLECT(n) AS nodes
        CALL {{
            WITH nodes
            UNWIND nodes AS n
            WITH n LIMIT 1
            RETURN n
        }}
        WITH nodes, n AS to_keep
        UNWIND nodes AS n
        WITH n, to_keep WHERE n <> to_keep
        OPTIONAL MATCH (n)-[r]-()
        DELETE r
        DETACH DELETE n
        RETURN to_keep
        """
        self.execute_query(merge_query)

    def merge_duplicates(self):
        duplicates = self.find_duplicates()
        for name, _ in duplicates:
            self.merge_nodes(name)

    def create_node(self, label: str, properties: dict):
        props = ", ".join([f"{k}: '{v}'" for k, v in properties.items()])
        query = f"CREATE (n:{label} {{{props}}})"
        self.execute_query(query)

    def create_edge(self, from_node: str, to_node: str, relationship: str):
        query = f"""
        MATCH (a:File {{name: '{from_node}'}}), (b:File {{name: '{to_node}'}})
        CREATE (a)-[r:{relationship}]->(b)
        """
        self.execute_query(query)

    def sanitize_text(self, text):
        if text is None:
            return "None"
        sanitized = text.replace("'", "\\'").replace("#", "").replace("?", "")
        return sanitized

# Custom Markdown extension to extract headings
class HeadingExtractor(Treeprocessor):
    def __init__(self, md):
        super().__init__(md)
        self.headings = []

    def run(self, root):
        for element in root:
            if element.tag.startswith('h'):
                self.headings.append((element.tag, element.text))
        return root

class ExtractHeadings(Extension):
    def extendMarkdown(self, md):
        heading_extractor = HeadingExtractor(md)
        md.treeprocessors.register(heading_extractor, 'extract_headings', 10)
        md.heading_extractor = heading_extractor

# Function to parse a markdown file and extract headings and links
def parse_markdown(file_path):
    md = Markdown(extensions=[ExtractHeadings()])
    with open(file_path, 'r', encoding='utf-8') as f:
        content = f.read()
    md.convert(content)
    links = re.findall(r'\[.*?\]\((.*?)\)', content)
    return md.heading_extractor.headings, links

# Path to the directory containing markdown files (Obsidian vault)
notes_dir = '/Users/dcarmocan/Projects/mind-cave'

# Initialize the MemgraphManager
mg_manager = MemgraphManager()

# Process each markdown file in the directory
for root, dirs, files in os.walk(notes_dir):
    for file in files:
        if file.endswith('.md'):
            file_path = os.path.join(root, file)
            print(f"Processing file: {file_path}")
            
            # Extract headings and links
            headings, links = parse_markdown(file_path)
            file_name = os.path.basename(file_path)
            
            # Create a node for the file
            mg_manager.create_node('File', {'name': file_name})
            
            # Create nodes and edges for each heading
            previous_heading = file_name
            for tag, heading in headings:
                sanitized_heading = mg_manager.sanitize_text(heading)
                heading_node = f"{file_name}_{sanitized_heading}"
                mg_manager.create_node(tag, {'name': heading_node})
                mg_manager.create_edge(previous_heading, heading_node, 'CONTAINS')
                previous_heading = heading_node
            
            # Create edges for each link
            for link in links:
                link_file_name = os.path.basename(link)
                mg_manager.create_edge(file_name, link_file_name, 'LINKS_TO')

# Merge duplicate nodes
mg_manager.merge_duplicates()

# Add indexes and constraints
def add_indexes_and_constraints(mg_manager):
    index_query = "CREATE INDEX ON :File(name)"
    mg_manager.execute_query(index_query)

    # Handle duplicates before applying the unique constraint
    mg_manager.merge_duplicates()

    # Ensure 'name' property is unique for 'File' nodes
    constraint_query = "CREATE CONSTRAINT ON (f:File) ASSERT f.name IS UNIQUE"
    mg_manager.execute_query(constraint_query)

add_indexes_and_constraints(mg_manager)
# Out:
# Processing file: /Users/dcarmocan/Projects/mind-cave/SPOG.md
# Executing query: CREATE (n:File {name: 'SPOG.md'})
# Query executed successfully.
# Executing query: CREATE (n:hr {name: 'SPOG.md_None'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'SPOG.md'}), (b:File {name: 'SPOG.md_None'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:hr {name: 'SPOG.md_None'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'SPOG.md_None'}), (b:File {name: 'SPOG.md_None'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h3 {name: 'SPOG.md_SPOG'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'SPOG.md_None'}), (b:File {name: 'SPOG.md_SPOG'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h4 {name: 'SPOG.md_Zoom SPOG'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'SPOG.md_SPOG'}), (b:File {name: 'SPOG.md_Zoom SPOG'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h2 {name: 'SPOG.md_- Carmine asked for a couple of things for the SPOG on [[2023-03-16]] .  I need to look and see if I can get these items completed in time for the meeting today.'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'SPOG.md_Zoom SPOG'}), (b:File {name: 'SPOG.md_- Carmine asked for a couple of things for the SPOG on [[2023-03-16]] .  I need to look and see if I can get these items completed in time for the meeting today.'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h4 {name: 'SPOG.md_VDI SPOG'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'SPOG.md_- Carmine asked for a couple of things for the SPOG on [[2023-03-16]] .  I need to look and see if I can get these items completed in time for the meeting today.'}), (b:File {name: 'SPOG.md_VDI SPOG'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Processing file: /Users/dcarmocan/Projects/mind-cave/Zoom Dashboard Documentation.md
# Executing query: CREATE (n:File {name: 'Zoom Dashboard Documentation.md'})
# Query executed successfully.
# Executing query: CREATE (n:hr {name: 'Zoom Dashboard Documentation.md_None'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Zoom Dashboard Documentation.md'}), (b:File {name: 'Zoom Dashboard Documentation.md_None'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:hr {name: 'Zoom Dashboard Documentation.md_None'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Zoom Dashboard Documentation.md_None'}), (b:File {name: 'Zoom Dashboard Documentation.md_None'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h1 {name: 'Zoom Dashboard Documentation.md_kb'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Zoom Dashboard Documentation.md_None'}), (b:File {name: 'Zoom Dashboard Documentation.md_kb'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h1 {name: 'Zoom Dashboard Documentation.md_Zoom API Integration Documentation'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Zoom Dashboard Documentation.md_kb'}), (b:File {name: 'Zoom Dashboard Documentation.md_Zoom API Integration Documentation'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h2 {name: 'Zoom Dashboard Documentation.md_Table of Contents'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Zoom Dashboard Documentation.md_Zoom API Integration Documentation'}), (b:File {name: 'Zoom Dashboard Documentation.md_Table of Contents'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h2 {name: 'Zoom Dashboard Documentation.md_1. Introduction'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Zoom Dashboard Documentation.md_Table of Contents'}), (b:File {name: 'Zoom Dashboard Documentation.md_1. Introduction'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h2 {name: 'Zoom Dashboard Documentation.md_2. Prerequisites'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Zoom Dashboard Documentation.md_1. Introduction'}), (b:File {name: 'Zoom Dashboard Documentation.md_2. Prerequisites'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h2 {name: 'Zoom Dashboard Documentation.md_3. Authentication'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Zoom Dashboard Documentation.md_2. Prerequisites'}), (b:File {name: 'Zoom Dashboard Documentation.md_3. Authentication'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h2 {name: 'Zoom Dashboard Documentation.md_4. Gathering Data from Zoom Meetings'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Zoom Dashboard Documentation.md_3. Authentication'}), (b:File {name: 'Zoom Dashboard Documentation.md_4. Gathering Data from Zoom Meetings'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h2 {name: 'Zoom Dashboard Documentation.md_5. Gathering Data from Zoom Webinars'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Zoom Dashboard Documentation.md_4. Gathering Data from Zoom Meetings'}), (b:File {name: 'Zoom Dashboard Documentation.md_5. Gathering Data from Zoom Webinars'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h2 {name: 'Zoom Dashboard Documentation.md_6. Generating Insights'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Zoom Dashboard Documentation.md_5. Gathering Data from Zoom Webinars'}), (b:File {name: 'Zoom Dashboard Documentation.md_6. Generating Insights'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h2 {name: 'Zoom Dashboard Documentation.md_7. High-Level Overview'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Zoom Dashboard Documentation.md_6. Generating Insights'}), (b:File {name: 'Zoom Dashboard Documentation.md_7. High-Level Overview'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h2 {name: 'Zoom Dashboard Documentation.md_8. Conclusion'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Zoom Dashboard Documentation.md_7. High-Level Overview'}), (b:File {name: 'Zoom Dashboard Documentation.md_8. Conclusion'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Processing file: /Users/dcarmocan/Projects/mind-cave/Summary Week - 20230915.md
# Executing query: CREATE (n:File {name: 'Summary Week - 20230915.md'})
# Query executed successfully.
# Executing query: CREATE (n:hr {name: 'Summary Week - 20230915.md_None'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Summary Week - 20230915.md'}), (b:File {name: 'Summary Week - 20230915.md_None'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:hr {name: 'Summary Week - 20230915.md_None'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Summary Week - 20230915.md_None'}), (b:File {name: 'Summary Week - 20230915.md_None'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h1 {name: 'Summary Week - 20230915.md_weekly-status'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Summary Week - 20230915.md_None'}), (b:File {name: 'Summary Week - 20230915.md_weekly-status'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h1 {name: 'Summary Week - 20230915.md_Status Update'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Summary Week - 20230915.md_weekly-status'}), (b:File {name: 'Summary Week - 20230915.md_Status Update'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Processing file: /Users/dcarmocan/Projects/mind-cave/Project Plan Template.md
# Executing query: CREATE (n:File {name: 'Project Plan Template.md'})
# Query executed successfully.
# Executing query: CREATE (n:hr {name: 'Project Plan Template.md_None'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Project Plan Template.md'}), (b:File {name: 'Project Plan Template.md_None'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:hr {name: 'Project Plan Template.md_None'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Project Plan Template.md_None'}), (b:File {name: 'Project Plan Template.md_None'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h1 {name: 'Project Plan Template.md_templates'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Project Plan Template.md_None'}), (b:File {name: 'Project Plan Template.md_templates'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h1 {name: 'Project Plan Template.md_Project Summary'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Project Plan Template.md_templates'}), (b:File {name: 'Project Plan Template.md_Project Summary'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h1 {name: 'Project Plan Template.md_Project Team'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Project Plan Template.md_Project Summary'}), (b:File {name: 'Project Plan Template.md_Project Team'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h1 {name: 'Project Plan Template.md_In Scope'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Project Plan Template.md_Project Team'}), (b:File {name: 'Project Plan Template.md_In Scope'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h1 {name: 'Project Plan Template.md_Out-of-Scope'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Project Plan Template.md_In Scope'}), (b:File {name: 'Project Plan Template.md_Out-of-Scope'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h1 {name: 'Project Plan Template.md_Project Requirements'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Project Plan Template.md_Out-of-Scope'}), (b:File {name: 'Project Plan Template.md_Project Requirements'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h2 {name: 'Project Plan Template.md_Objectives'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Project Plan Template.md_Project Requirements'}), (b:File {name: 'Project Plan Template.md_Objectives'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h2 {name: 'Project Plan Template.md_Scopes'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Project Plan Template.md_Objectives'}), (b:File {name: 'Project Plan Template.md_Scopes'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h2 {name: 'Project Plan Template.md_Assumptions'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Project Plan Template.md_Scopes'}), (b:File {name: 'Project Plan Template.md_Assumptions'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h1 {name: 'Project Plan Template.md_Impact Analysis'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Project Plan Template.md_Assumptions'}), (b:File {name: 'Project Plan Template.md_Impact Analysis'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h2 {name: 'Project Plan Template.md_Key Business Areas'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Project Plan Template.md_Impact Analysis'}), (b:File {name: 'Project Plan Template.md_Key Business Areas'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h2 {name: 'Project Plan Template.md_Critical Functions'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Project Plan Template.md_Key Business Areas'}), (b:File {name: 'Project Plan Template.md_Critical Functions'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h2 {name: 'Project Plan Template.md_Dependencies'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Project Plan Template.md_Critical Functions'}), (b:File {name: 'Project Plan Template.md_Dependencies'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h2 {name: 'Project Plan Template.md_Determine Acceptable Downtime'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Project Plan Template.md_Dependencies'}), (b:File {name: 'Project Plan Template.md_Determine Acceptable Downtime'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h2 {name: 'Project Plan Template.md_Priority'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Project Plan Template.md_Determine Acceptable Downtime'}), (b:File {name: 'Project Plan Template.md_Priority'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h2 {name: 'Project Plan Template.md_Critical Applications & Downtime'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Project Plan Template.md_Priority'}), (b:File {name: 'Project Plan Template.md_Critical Applications & Downtime'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h1 {name: 'Project Plan Template.md_Test Plan'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Project Plan Template.md_Critical Applications & Downtime'}), (b:File {name: 'Project Plan Template.md_Test Plan'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h1 {name: 'Project Plan Template.md_Execution'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Project Plan Template.md_Test Plan'}), (b:File {name: 'Project Plan Template.md_Execution'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h2 {name: 'Project Plan Template.md_Execution Team'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Project Plan Template.md_Execution'}), (b:File {name: 'Project Plan Template.md_Execution Team'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h2 {name: 'Project Plan Template.md_Continuity Plan'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Project Plan Template.md_Execution Team'}), (b:File {name: 'Project Plan Template.md_Continuity Plan'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h3 {name: 'Project Plan Template.md_Checklist:'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Project Plan Template.md_Continuity Plan'}), (b:File {name: 'Project Plan Template.md_Checklist:'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h2 {name: 'Project Plan Template.md_Maintainer Plan'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Project Plan Template.md_Checklist:'}), (b:File {name: 'Project Plan Template.md_Maintainer Plan'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h2 {name: 'Project Plan Template.md_Communications Plan'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Project Plan Template.md_Maintainer Plan'}), (b:File {name: 'Project Plan Template.md_Communications Plan'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h1 {name: 'Project Plan Template.md_Training And Research'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Project Plan Template.md_Communications Plan'}), (b:File {name: 'Project Plan Template.md_Training And Research'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h1 {name: 'Project Plan Template.md_References'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Project Plan Template.md_Training And Research'}), (b:File {name: 'Project Plan Template.md_References'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Processing file: /Users/dcarmocan/Projects/mind-cave/Cap_Planning_Article.md
# Executing query: CREATE (n:File {name: 'Cap_Planning_Article.md'})
# Query executed successfully.
# Executing query: CREATE (n:hr {name: 'Cap_Planning_Article.md_None'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Cap_Planning_Article.md'}), (b:File {name: 'Cap_Planning_Article.md_None'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:hr {name: 'Cap_Planning_Article.md_None'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Cap_Planning_Article.md_None'}), (b:File {name: 'Cap_Planning_Article.md_None'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h1 {name: 'Cap_Planning_Article.md_process-docs'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Cap_Planning_Article.md_None'}), (b:File {name: 'Cap_Planning_Article.md_process-docs'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h1 {name: 'Cap_Planning_Article.md_Mastering Work Prioritization: Overcoming the Challenges of High-Priority Task Overload in Business and Technology Systems'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Cap_Planning_Article.md_process-docs'}), (b:File {name: 'Cap_Planning_Article.md_Mastering Work Prioritization: Overcoming the Challenges of High-Priority Task Overload in Business and Technology Systems'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h2 {name: 'Cap_Planning_Article.md_Navigating the Perils of Resource Saturation in Agile Sprints'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Cap_Planning_Article.md_Mastering Work Prioritization: Overcoming the Challenges of High-Priority Task Overload in Business and Technology Systems'}), (b:File {name: 'Cap_Planning_Article.md_Navigating the Perils of Resource Saturation in Agile Sprints'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h1 {name: 'Cap_Planning_Article.md_The Importance of Meaningful Prioritization in Agile Sprints'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Cap_Planning_Article.md_Navigating the Perils of Resource Saturation in Agile Sprints'}), (b:File {name: 'Cap_Planning_Article.md_The Importance of Meaningful Prioritization in Agile Sprints'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h3 {name: 'Cap_Planning_Article.md_None'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Cap_Planning_Article.md_The Importance of Meaningful Prioritization in Agile Sprints'}), (b:File {name: 'Cap_Planning_Article.md_None'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h3 {name: 'Cap_Planning_Article.md_None'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Cap_Planning_Article.md_None'}), (b:File {name: 'Cap_Planning_Article.md_None'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h1 {name: 'Cap_Planning_Article.md_Addressing the Impact of Stress on Decision-Making and Teamwork in Agile Environments'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Cap_Planning_Article.md_None'}), (b:File {name: 'Cap_Planning_Article.md_Addressing the Impact of Stress on Decision-Making and Teamwork in Agile Environments'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h2 {name: 'Cap_Planning_Article.md_None'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Cap_Planning_Article.md_Addressing the Impact of Stress on Decision-Making and Teamwork in Agile Environments'}), (b:File {name: 'Cap_Planning_Article.md_None'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h2 {name: 'Cap_Planning_Article.md_None'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Cap_Planning_Article.md_None'}), (b:File {name: 'Cap_Planning_Article.md_None'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h1 {name: 'Cap_Planning_Article.md_None'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Cap_Planning_Article.md_None'}), (b:File {name: 'Cap_Planning_Article.md_None'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Processing file: /Users/dcarmocan/Projects/mind-cave/Terminator_Doc.md
# Executing query: CREATE (n:File {name: 'Terminator_Doc.md'})
# Query executed successfully.
# Executing query: CREATE (n:hr {name: 'Terminator_Doc.md_None'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Terminator_Doc.md'}), (b:File {name: 'Terminator_Doc.md_None'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:hr {name: 'Terminator_Doc.md_None'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Terminator_Doc.md_None'}), (b:File {name: 'Terminator_Doc.md_None'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h1 {name: 'Terminator_Doc.md_process-docs'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Terminator_Doc.md_None'}), (b:File {name: 'Terminator_Doc.md_process-docs'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h2 {name: 'Terminator_Doc.md_Introduction'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Terminator_Doc.md_process-docs'}), (b:File {name: 'Terminator_Doc.md_Introduction'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h2 {name: 'Terminator_Doc.md_Addressing Off-boarding Needs'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Terminator_Doc.md_Introduction'}), (b:File {name: 'Terminator_Doc.md_Addressing Off-boarding Needs'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h3 {name: 'Terminator_Doc.md_Event-Driven Automation Through Google Workspace Admin'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Terminator_Doc.md_Addressing Off-boarding Needs'}), (b:File {name: 'Terminator_Doc.md_Event-Driven Automation Through Google Workspace Admin'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h4 {name: 'Terminator_Doc.md_Google Admin SDK and Cloud Logging Integration'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Terminator_Doc.md_Event-Driven Automation Through Google Workspace Admin'}), (b:File {name: 'Terminator_Doc.md_Google Admin SDK and Cloud Logging Integration'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h4 {name: 'Terminator_Doc.md_Event Filtering'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Terminator_Doc.md_Google Admin SDK and Cloud Logging Integration'}), (b:File {name: 'Terminator_Doc.md_Event Filtering'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h4 {name: 'Terminator_Doc.md_Domain-Wide Delegation and Service Account'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Terminator_Doc.md_Event Filtering'}), (b:File {name: 'Terminator_Doc.md_Domain-Wide Delegation and Service Account'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h2 {name: 'Terminator_Doc.md_The Tech Stack'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Terminator_Doc.md_Domain-Wide Delegation and Service Account'}), (b:File {name: 'Terminator_Doc.md_The Tech Stack'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h3 {name: 'Terminator_Doc.md_Google Admin SDK'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Terminator_Doc.md_The Tech Stack'}), (b:File {name: 'Terminator_Doc.md_Google Admin SDK'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h3 {name: 'Terminator_Doc.md_Google Cloud Logging'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Terminator_Doc.md_Google Admin SDK'}), (b:File {name: 'Terminator_Doc.md_Google Cloud Logging'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h3 {name: 'Terminator_Doc.md_Google Pub/Sub'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Terminator_Doc.md_Google Cloud Logging'}), (b:File {name: 'Terminator_Doc.md_Google Pub/Sub'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h3 {name: 'Terminator_Doc.md_Google Cloud Functions'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Terminator_Doc.md_Google Pub/Sub'}), (b:File {name: 'Terminator_Doc.md_Google Cloud Functions'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h3 {name: 'Terminator_Doc.md_Google Cloud Run'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Terminator_Doc.md_Google Cloud Functions'}), (b:File {name: 'Terminator_Doc.md_Google Cloud Run'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h3 {name: 'Terminator_Doc.md_Google Eventarc'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Terminator_Doc.md_Google Cloud Run'}), (b:File {name: 'Terminator_Doc.md_Google Eventarc'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h2 {name: 'Terminator_Doc.md_Benefits and Cost Savings of the Terminator Project'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Terminator_Doc.md_Google Eventarc'}), (b:File {name: 'Terminator_Doc.md_Benefits and Cost Savings of the Terminator Project'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h3 {name: 'Terminator_Doc.md_Financial Savings'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Terminator_Doc.md_Benefits and Cost Savings of the Terminator Project'}), (b:File {name: 'Terminator_Doc.md_Financial Savings'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h3 {name: 'Terminator_Doc.md_Customization and Flexibility'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Terminator_Doc.md_Financial Savings'}), (b:File {name: 'Terminator_Doc.md_Customization and Flexibility'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h3 {name: 'Terminator_Doc.md_Improved Security and Compliance'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Terminator_Doc.md_Customization and Flexibility'}), (b:File {name: 'Terminator_Doc.md_Improved Security and Compliance'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h3 {name: 'Terminator_Doc.md_Enhanced Integration'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Terminator_Doc.md_Improved Security and Compliance'}), (b:File {name: 'Terminator_Doc.md_Enhanced Integration'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h3 {name: 'Terminator_Doc.md_Scalability and Performance'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Terminator_Doc.md_Enhanced Integration'}), (b:File {name: 'Terminator_Doc.md_Scalability and Performance'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h3 {name: 'Terminator_Doc.md_Increased Control and Visibility'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Terminator_Doc.md_Scalability and Performance'}), (b:File {name: 'Terminator_Doc.md_Increased Control and Visibility'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h2 {name: 'Terminator_Doc.md_Integrating Google Workspace Admin with GCP Using Log Sinks: A High-Level Overview'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Terminator_Doc.md_Increased Control and Visibility'}), (b:File {name: 'Terminator_Doc.md_Integrating Google Workspace Admin with GCP Using Log Sinks: A High-Level Overview'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h3 {name: 'Terminator_Doc.md_What are Log Sinks'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Terminator_Doc.md_Integrating Google Workspace Admin with GCP Using Log Sinks: A High-Level Overview'}), (b:File {name: 'Terminator_Doc.md_What are Log Sinks'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h3 {name: 'Terminator_Doc.md_How do Log Sinks work with Google Workspace Admin'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Terminator_Doc.md_What are Log Sinks'}), (b:File {name: 'Terminator_Doc.md_How do Log Sinks work with Google Workspace Admin'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h3 {name: 'Terminator_Doc.md_Why use Log Sinks for off-boarding automation'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Terminator_Doc.md_How do Log Sinks work with Google Workspace Admin'}), (b:File {name: 'Terminator_Doc.md_Why use Log Sinks for off-boarding automation'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h1 {name: 'Terminator_Doc.md_!/bin/bash'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Terminator_Doc.md_Why use Log Sinks for off-boarding automation'}), (b:File {name: 'Terminator_Doc.md_!/bin/bash'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h1 {name: 'Terminator_Doc.md_Get the hostname'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Terminator_Doc.md_!/bin/bash'}), (b:File {name: 'Terminator_Doc.md_Get the hostname'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h1 {name: 'Terminator_Doc.md_Get the memory usage'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Terminator_Doc.md_Get the hostname'}), (b:File {name: 'Terminator_Doc.md_Get the memory usage'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h1 {name: 'Terminator_Doc.md_Get the CPU usage'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Terminator_Doc.md_Get the memory usage'}), (b:File {name: 'Terminator_Doc.md_Get the CPU usage'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Processing file: /Users/dcarmocan/Projects/mind-cave/SMART_GOALS_Format.md
# Executing query: CREATE (n:File {name: 'SMART_GOALS_Format.md'})
# Query executed successfully.
# Executing query: CREATE (n:hr {name: 'SMART_GOALS_Format.md_None'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'SMART_GOALS_Format.md'}), (b:File {name: 'SMART_GOALS_Format.md_None'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:hr {name: 'SMART_GOALS_Format.md_None'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'SMART_GOALS_Format.md_None'}), (b:File {name: 'SMART_GOALS_Format.md_None'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h1 {name: 'SMART_GOALS_Format.md_process-docs'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'SMART_GOALS_Format.md_None'}), (b:File {name: 'SMART_GOALS_Format.md_process-docs'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h2 {name: 'SMART_GOALS_Format.md_What are SMART goals'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'SMART_GOALS_Format.md_process-docs'}), (b:File {name: 'SMART_GOALS_Format.md_What are SMART goals'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h2 {name: 'SMART_GOALS_Format.md_How to write SMART goals'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'SMART_GOALS_Format.md_What are SMART goals'}), (b:File {name: 'SMART_GOALS_Format.md_How to write SMART goals'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h2 {name: 'SMART_GOALS_Format.md_S: Specific'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'SMART_GOALS_Format.md_How to write SMART goals'}), (b:File {name: 'SMART_GOALS_Format.md_S: Specific'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h6 {name: 'SMART_GOALS_Format.md_SPECIFIC'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'SMART_GOALS_Format.md_S: Specific'}), (b:File {name: 'SMART_GOALS_Format.md_SPECIFIC'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h2 {name: 'SMART_GOALS_Format.md_M: Measurable'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'SMART_GOALS_Format.md_SPECIFIC'}), (b:File {name: 'SMART_GOALS_Format.md_M: Measurable'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h6 {name: 'SMART_GOALS_Format.md_MEASURABLE'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'SMART_GOALS_Format.md_M: Measurable'}), (b:File {name: 'SMART_GOALS_Format.md_MEASURABLE'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h2 {name: 'SMART_GOALS_Format.md_A: Achievable'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'SMART_GOALS_Format.md_MEASURABLE'}), (b:File {name: 'SMART_GOALS_Format.md_A: Achievable'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h6 {name: 'SMART_GOALS_Format.md_ACHIEVABLE'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'SMART_GOALS_Format.md_A: Achievable'}), (b:File {name: 'SMART_GOALS_Format.md_ACHIEVABLE'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h2 {name: 'SMART_GOALS_Format.md_R: Relevant'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'SMART_GOALS_Format.md_ACHIEVABLE'}), (b:File {name: 'SMART_GOALS_Format.md_R: Relevant'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h6 {name: 'SMART_GOALS_Format.md_RELEVANT'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'SMART_GOALS_Format.md_R: Relevant'}), (b:File {name: 'SMART_GOALS_Format.md_RELEVANT'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h2 {name: 'SMART_GOALS_Format.md_T: Time-bound'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'SMART_GOALS_Format.md_RELEVANT'}), (b:File {name: 'SMART_GOALS_Format.md_T: Time-bound'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'SMART_GOALS_Format.md'}), (b:File {name: 'brand-4069-90-day-plan-template-blog-illustration-1120x545-@2x-v2-600x480.png'})
#         CREATE (a)-[r:LINKS_TO]->(b)
#
# Query executed successfully.
# Processing file: /Users/dcarmocan/Projects/mind-cave/Cap_planning_notes.md
# Executing query: CREATE (n:File {name: 'Cap_planning_notes.md'})
# Query executed successfully.
# Executing query: CREATE (n:hr {name: 'Cap_planning_notes.md_None'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Cap_planning_notes.md'}), (b:File {name: 'Cap_planning_notes.md_None'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:hr {name: 'Cap_planning_notes.md_None'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Cap_planning_notes.md_None'}), (b:File {name: 'Cap_planning_notes.md_None'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h1 {name: 'Cap_planning_notes.md_process-docs'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Cap_planning_notes.md_None'}), (b:File {name: 'Cap_planning_notes.md_process-docs'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Cap_planning_notes.md'}), (b:File {name: '%3e'})
#         CREATE (a)-[r:LINKS_TO]->(b)
#
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Cap_planning_notes.md'}), (b:File {name: 'image?url=https%3A%2F%2Flh3.googleusercontent.com%2Fa%2FAGNmyxYCaUfhW6asHZK6aGbE4KLSHPU82W5EUnBZe7M3%3Ds96-c&w=64&q=75'})
#         CREATE (a)-[r:LINKS_TO]->(b)
#
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Cap_planning_notes.md'}), (b:File {name: '%3e'})
#         CREATE (a)-[r:LINKS_TO]->(b)
#
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Cap_planning_notes.md'}), (b:File {name: 'image?url=https%3A%2F%2Flh3.googleusercontent.com%2Fa%2FAGNmyxYCaUfhW6asHZK6aGbE4KLSHPU82W5EUnBZe7M3%3Ds96-c&w=64&q=75'})
#         CREATE (a)-[r:LINKS_TO]->(b)
#
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Cap_planning_notes.md'}), (b:File {name: '%3e'})
#         CREATE (a)-[r:LINKS_TO]->(b)
#
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Cap_planning_notes.md'}), (b:File {name: 'image?url=https%3A%2F%2Flh3.googleusercontent.com%2Fa%2FAGNmyxYCaUfhW6asHZK6aGbE4KLSHPU82W5EUnBZe7M3%3Ds96-c&w=64&q=75'})
#         CREATE (a)-[r:LINKS_TO]->(b)
#
# Query executed successfully.
# Processing file: /Users/dcarmocan/Projects/mind-cave/slack_tasks.md
# Executing query: CREATE (n:File {name: 'slack_tasks.md'})
# Query executed successfully.
# Executing query: CREATE (n:hr {name: 'slack_tasks.md_None'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'slack_tasks.md'}), (b:File {name: 'slack_tasks.md_None'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:hr {name: 'slack_tasks.md_None'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'slack_tasks.md_None'}), (b:File {name: 'slack_tasks.md_None'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h1 {name: 'slack_tasks.md_'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'slack_tasks.md_None'}), (b:File {name: 'slack_tasks.md_'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Processing file: /Users/dcarmocan/Projects/mind-cave/DISP_Discussion.md
# Executing query: CREATE (n:File {name: 'DISP_Discussion.md'})
# Query executed successfully.
# Executing query: CREATE (n:hr {name: 'DISP_Discussion.md_None'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'DISP_Discussion.md'}), (b:File {name: 'DISP_Discussion.md_None'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:hr {name: 'DISP_Discussion.md_None'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'DISP_Discussion.md_None'}), (b:File {name: 'DISP_Discussion.md_None'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h1 {name: 'DISP_Discussion.md_DISP Project Discussion'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'DISP_Discussion.md_None'}), (b:File {name: 'DISP_Discussion.md_DISP Project Discussion'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'DISP_Discussion.md'}), (b:File {name: 'p1698185838579289'})
#         CREATE (a)-[r:LINKS_TO]->(b)
#
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'DISP_Discussion.md'}), (b:File {name: 'U05ND2K0BBR'})
#         CREATE (a)-[r:LINKS_TO]->(b)
#
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'DISP_Discussion.md'}), (b:File {name: 'W01918HTJHW'})
#         CREATE (a)-[r:LINKS_TO]->(b)
#
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'DISP_Discussion.md'}), (b:File {name: 'p1698197733807279'})
#         CREATE (a)-[r:LINKS_TO]->(b)
#
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'DISP_Discussion.md'}), (b:File {name: 'p1698199096522449'})
#         CREATE (a)-[r:LINKS_TO]->(b)
#
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'DISP_Discussion.md'}), (b:File {name: 'W01918HTJHW'})
#         CREATE (a)-[r:LINKS_TO]->(b)
#
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'DISP_Discussion.md'}), (b:File {name: 'U05ND2K0BBR'})
#         CREATE (a)-[r:LINKS_TO]->(b)
#
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'DISP_Discussion.md'}), (b:File {name: 'U05ND2K0BBR'})
#         CREATE (a)-[r:LINKS_TO]->(b)
#
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'DISP_Discussion.md'}), (b:File {name: 'p1698200655753679'})
#         CREATE (a)-[r:LINKS_TO]->(b)
#
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'DISP_Discussion.md'}), (b:File {name: 'p1698200959452739'})
#         CREATE (a)-[r:LINKS_TO]->(b)
#
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'DISP_Discussion.md'}), (b:File {name: 'U05ND2K0BBR'})
#         CREATE (a)-[r:LINKS_TO]->(b)
#
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'DISP_Discussion.md'}), (b:File {name: 'p1698201714016489'})
#         CREATE (a)-[r:LINKS_TO]->(b)
#
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'DISP_Discussion.md'}), (b:File {name: 'p1698251558809229'})
#         CREATE (a)-[r:LINKS_TO]->(b)
#
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'DISP_Discussion.md'}), (b:File {name: 'p1698251941675909'})
#         CREATE (a)-[r:LINKS_TO]->(b)
#
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'DISP_Discussion.md'}), (b:File {name: 'edit#slide=id.p1'})
#         CREATE (a)-[r:LINKS_TO]->(b)
#
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'DISP_Discussion.md'}), (b:File {name: 'Splunk+Australian+M365+Tenant+Project'})
#         CREATE (a)-[r:LINKS_TO]->(b)
#
# Query executed successfully.
# Processing file: /Users/dcarmocan/Projects/mind-cave/GCP_Data_Engineer_Exam_Prep_Notes.md
# Executing query: CREATE (n:File {name: 'GCP_Data_Engineer_Exam_Prep_Notes.md'})
# Query executed successfully.
# Executing query: CREATE (n:hr {name: 'GCP_Data_Engineer_Exam_Prep_Notes.md_None'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'GCP_Data_Engineer_Exam_Prep_Notes.md'}), (b:File {name: 'GCP_Data_Engineer_Exam_Prep_Notes.md_None'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:hr {name: 'GCP_Data_Engineer_Exam_Prep_Notes.md_None'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'GCP_Data_Engineer_Exam_Prep_Notes.md_None'}), (b:File {name: 'GCP_Data_Engineer_Exam_Prep_Notes.md_None'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'GCP_Data_Engineer_Exam_Prep_Notes.md'}), (b:File {name: 'store-query-data'})
#         CREATE (a)-[r:LINKS_TO]->(b)
#
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'GCP_Data_Engineer_Exam_Prep_Notes.md'}), (b:File {name: 'store-query-data'})
#         CREATE (a)-[r:LINKS_TO]->(b)
#
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'GCP_Data_Engineer_Exam_Prep_Notes.md'}), (b:File {name: 'create-database-server-client-library'})
#         CREATE (a)-[r:LINKS_TO]->(b)
#
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'GCP_Data_Engineer_Exam_Prep_Notes.md'}), (b:File {name: 'create-instance-gcloud'})
#         CREATE (a)-[r:LINKS_TO]->(b)
#
# Query executed successfully.
# Processing file: /Users/dcarmocan/Projects/mind-cave/2023-07-20_CD-CD-Status.md
# Executing query: CREATE (n:File {name: '2023-07-20_CD-CD-Status.md'})
# Query executed successfully.
# Executing query: CREATE (n:hr {name: '2023-07-20_CD-CD-Status.md_None'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: '2023-07-20_CD-CD-Status.md'}), (b:File {name: '2023-07-20_CD-CD-Status.md_None'})
#         CREATE (a)-[r:CONTAINS]->(b)
# ...
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h4 {name: 'AdminTasks_App_Documentation.md_Bot User Configuration'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'AdminTasks_App_Documentation.md_App User Configuration'}), (b:File {name: 'AdminTasks_App_Documentation.md_Bot User Configuration'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h4 {name: 'AdminTasks_App_Documentation.md_Token Configuration and Storage'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'AdminTasks_App_Documentation.md_Bot User Configuration'}), (b:File {name: 'AdminTasks_App_Documentation.md_Token Configuration and Storage'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h2 {name: 'AdminTasks_App_Documentation.md_Authorized Use and Applications'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'AdminTasks_App_Documentation.md_Token Configuration and Storage'}), (b:File {name: 'AdminTasks_App_Documentation.md_Authorized Use and Applications'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h3 {name: 'AdminTasks_App_Documentation.md_Slack Channel Convert'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'AdminTasks_App_Documentation.md_Authorized Use and Applications'}), (b:File {name: 'AdminTasks_App_Documentation.md_Slack Channel Convert'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h3 {name: 'AdminTasks_App_Documentation.md_Slack Channel Archive'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'AdminTasks_App_Documentation.md_Slack Channel Convert'}), (b:File {name: 'AdminTasks_App_Documentation.md_Slack Channel Archive'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'AdminTasks_App_Documentation.md'}), (b:File {name: '#admintasks-app-documentation'})
#         CREATE (a)-[r:LINKS_TO]->(b)
#
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'AdminTasks_App_Documentation.md'}), (b:File {name: '#introduction'})
#         CREATE (a)-[r:LINKS_TO]->(b)
#
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'AdminTasks_App_Documentation.md'}), (b:File {name: '#objective'})
#         CREATE (a)-[r:LINKS_TO]->(b)
#
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'AdminTasks_App_Documentation.md'}), (b:File {name: '#configuration'})
#         CREATE (a)-[r:LINKS_TO]->(b)
#
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'AdminTasks_App_Documentation.md'}), (b:File {name: '#app-user-configuration'})
#         CREATE (a)-[r:LINKS_TO]->(b)
#
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'AdminTasks_App_Documentation.md'}), (b:File {name: '#bot-user-configuration'})
#         CREATE (a)-[r:LINKS_TO]->(b)
#
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'AdminTasks_App_Documentation.md'}), (b:File {name: '#token-configuration-and-storage'})
#         CREATE (a)-[r:LINKS_TO]->(b)
#
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'AdminTasks_App_Documentation.md'}), (b:File {name: '#authorized-use-and-applications'})
#         CREATE (a)-[r:LINKS_TO]->(b)
#
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'AdminTasks_App_Documentation.md'}), (b:File {name: '#slack-channel-convert'})
#         CREATE (a)-[r:LINKS_TO]->(b)
#
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'AdminTasks_App_Documentation.md'}), (b:File {name: '#slack-channel-archive'})
#         CREATE (a)-[r:LINKS_TO]->(b)
#
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'AdminTasks_App_Documentation.md'}), (b:File {name: 'A019F103RQQ'})
#         CREATE (a)-[r:LINKS_TO]->(b)
#
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'AdminTasks_App_Documentation.md'}), (b:File {name: ''})
#         CREATE (a)-[r:LINKS_TO]->(b)
#
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'AdminTasks_App_Documentation.md'}), (b:File {name: 'secure-env'})
#         CREATE (a)-[r:LINKS_TO]->(b)
#
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'AdminTasks_App_Documentation.md'}), (b:File {name: 'edit'})
#         CREATE (a)-[r:LINKS_TO]->(b)
#
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'AdminTasks_App_Documentation.md'}), (b:File {name: 'edit'})
#         CREATE (a)-[r:LINKS_TO]->(b)
#
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'AdminTasks_App_Documentation.md'}), (b:File {name: 'conversations.archive'})
#         CREATE (a)-[r:LINKS_TO]->(b)
#
# Query executed successfully.
# Processing file: /Users/dcarmocan/Projects/mind-cave/Services/Harshicorp/Hashicorp_Vault_Docs.md
# Executing query: CREATE (n:File {name: 'Hashicorp_Vault_Docs.md'})
# Query executed successfully.
# Executing query: CREATE (n:hr {name: 'Hashicorp_Vault_Docs.md_None'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Hashicorp_Vault_Docs.md'}), (b:File {name: 'Hashicorp_Vault_Docs.md_None'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:hr {name: 'Hashicorp_Vault_Docs.md_None'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Hashicorp_Vault_Docs.md_None'}), (b:File {name: 'Hashicorp_Vault_Docs.md_None'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h1 {name: 'Hashicorp_Vault_Docs.md_vault process-docs'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Hashicorp_Vault_Docs.md_None'}), (b:File {name: 'Hashicorp_Vault_Docs.md_vault process-docs'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h1 {name: 'Hashicorp_Vault_Docs.md_Vault Docs'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Hashicorp_Vault_Docs.md_vault process-docs'}), (b:File {name: 'Hashicorp_Vault_Docs.md_Vault Docs'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h2 {name: 'Hashicorp_Vault_Docs.md_Login'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Hashicorp_Vault_Docs.md_Vault Docs'}), (b:File {name: 'Hashicorp_Vault_Docs.md_Login'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Processing file: /Users/dcarmocan/Projects/mind-cave/Utility/Scripts.md
# Executing query: CREATE (n:File {name: 'Scripts.md'})
# Query executed successfully.
# Executing query: CREATE (n:h1 {name: 'Scripts.md_scripts'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Scripts.md'}), (b:File {name: 'Scripts.md_scripts'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h1 {name: 'Scripts.md_Scripts List'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Scripts.md_scripts'}), (b:File {name: 'Scripts.md_Scripts List'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h2 {name: 'Scripts.md_Excalidraw Scripts'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Scripts.md_Scripts List'}), (b:File {name: 'Scripts.md_Excalidraw Scripts'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h3 {name: 'Scripts.md_Excalidraw SVG Elements'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Scripts.md_Excalidraw Scripts'}), (b:File {name: 'Scripts.md_Excalidraw SVG Elements'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Processing file: /Users/dcarmocan/Projects/mind-cave/Utility/Query_Test.md
# Executing query: CREATE (n:File {name: 'Query_Test.md'})
# Query executed successfully.
# Executing query: CREATE (n:hr {name: 'Query_Test.md_None'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Query_Test.md'}), (b:File {name: 'Query_Test.md_None'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:hr {name: 'Query_Test.md_None'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Query_Test.md_None'}), (b:File {name: 'Query_Test.md_None'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Processing file: /Users/dcarmocan/Projects/mind-cave/Utility/General Blurbs.md
# Executing query: CREATE (n:File {name: 'General Blurbs.md'})
# Query executed successfully.
# Executing query: CREATE (n:hr {name: 'General Blurbs.md_None'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'General Blurbs.md'}), (b:File {name: 'General Blurbs.md_None'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:hr {name: 'General Blurbs.md_None'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'General Blurbs.md_None'}), (b:File {name: 'General Blurbs.md_None'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h3 {name: 'General Blurbs.md_Inactive SNOW'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'General Blurbs.md_None'}), (b:File {name: 'General Blurbs.md_Inactive SNOW'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Processing file: /Users/dcarmocan/Projects/mind-cave/Utility/Slack_App_Blurbs.md
# Executing query: CREATE (n:File {name: 'Slack_App_Blurbs.md'})
# Query executed successfully.
# Executing query: CREATE (n:hr {name: 'Slack_App_Blurbs.md_None'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Slack_App_Blurbs.md'}), (b:File {name: 'Slack_App_Blurbs.md_None'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:hr {name: 'Slack_App_Blurbs.md_None'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Slack_App_Blurbs.md_None'}), (b:File {name: 'Slack_App_Blurbs.md_None'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h1 {name: 'Slack_App_Blurbs.md_slack blurbs'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Slack_App_Blurbs.md_None'}), (b:File {name: 'Slack_App_Blurbs.md_slack blurbs'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h1 {name: 'Slack_App_Blurbs.md_Slack App Blurbs'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Slack_App_Blurbs.md_slack blurbs'}), (b:File {name: 'Slack_App_Blurbs.md_Slack App Blurbs'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h2 {name: 'Slack_App_Blurbs.md_When Someone Asks for the Onboarding Process'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Slack_App_Blurbs.md_Slack App Blurbs'}), (b:File {name: 'Slack_App_Blurbs.md_When Someone Asks for the Onboarding Process'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h2 {name: 'Slack_App_Blurbs.md_When someone has questions about developing their own app:'})
# Query executed successfully.
# Executing query:
#         MATCH (a:File {name: 'Slack_App_Blurbs.md_When Someone Asks for the Onboarding Process'}), (b:File {name: 'Slack_App_Blurbs.md_When someone has questions about developing their own app:'})
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query:
#         MATCH (n:File)
#         WITH n.name AS name, COUNT(n) AS count
#         WHERE count > 1
#         RETURN name, count
#
# Query executed successfully.
# Executing query:
#         MATCH (n:File {name: 'Slack.md'})
#         WITH COLLECT(n) AS nodes
#         CALL {
#             WITH nodes
#             UNWIND nodes AS n
#             WITH n LIMIT 1
#             RETURN n
#         }
#         WITH nodes, n AS to_keep
#         UNWIND nodes AS n
#         WITH n, to_keep WHERE n <> to_keep
#         OPTIONAL MATCH (n)-[r]-()
#         DELETE r
#         DETACH DELETE n
#         RETURN to_keep
#
# Query executed successfully.
# Executing query:
#         MATCH (n:File {name: 'GCP.md'})
#         WITH COLLECT(n) AS nodes
#         CALL {
#             WITH nodes
#             UNWIND nodes AS n
#             WITH n LIMIT 1
#             RETURN n
#         }
#         WITH nodes, n AS to_keep
#         UNWIND nodes AS n
#         WITH n, to_keep WHERE n <> to_keep
#         OPTIONAL MATCH (n)-[r]-()
#         DELETE r
#         DETACH DELETE n
#         RETURN to_keep
#
# Query executed successfully.
# Executing query:
#         MATCH (n:File {name: 'Untitled.md'})
#         WITH COLLECT(n) AS nodes
#         CALL {
#             WITH nodes
#             UNWIND nodes AS n
#             WITH n LIMIT 1
#             RETURN n
#         }
#         WITH nodes, n AS to_keep
#         UNWIND nodes AS n
#         WITH n, to_keep WHERE n <> to_keep
#         OPTIONAL MATCH (n)-[r]-()
#         DELETE r
#         DETACH DELETE n
#         RETURN to_keep
#
# Query executed successfully.
# Executing query:
#         MATCH (n:File {name: 'GitLab.md'})
#         WITH COLLECT(n) AS nodes
#         CALL {
#             WITH nodes
#             UNWIND nodes AS n
#             WITH n LIMIT 1
#             RETURN n
#         }
#         WITH nodes, n AS to_keep
#         UNWIND nodes AS n
#         WITH n, to_keep WHERE n <> to_keep
#         OPTIONAL MATCH (n)-[r]-()
#         DELETE r
#         DETACH DELETE n
#         RETURN to_keep
#
# Query executed successfully.
# Executing query:
#         MATCH (n:File {name: 'Home.md'})
#         WITH COLLECT(n) AS nodes
#         CALL {
#             WITH nodes
#             UNWIND nodes AS n
#             WITH n LIMIT 1
#             RETURN n
#         }
#         WITH nodes, n AS to_keep
#         UNWIND nodes AS n
#         WITH n, to_keep WHERE n <> to_keep
#         OPTIONAL MATCH (n)-[r]-()
#         DELETE r
#         DETACH DELETE n
#         RETURN to_keep
#
# Query executed successfully.
# Executing query:
#         MATCH (n:File {name: '.md'})
#         WITH COLLECT(n) AS nodes
#         CALL {
#             WITH nodes
#             UNWIND nodes AS n
#             WITH n LIMIT 1
#             RETURN n
#         }
#         WITH nodes, n AS to_keep
#         UNWIND nodes AS n
#         WITH n, to_keep WHERE n <> to_keep
#         OPTIONAL MATCH (n)-[r]-()
#         DELETE r
#         DETACH DELETE n
#         RETURN to_keep
#
# Query executed successfully.
# Executing query:
#         MATCH (n:File {name: 'Daily Notes.md'})
#         WITH COLLECT(n) AS nodes
#         CALL {
#             WITH nodes
#             UNWIND nodes AS n
#             WITH n LIMIT 1
#             RETURN n
#         }
#         WITH nodes, n AS to_keep
#         UNWIND nodes AS n
#         WITH n, to_keep WHERE n <> to_keep
#         OPTIONAL MATCH (n)-[r]-()
#         DELETE r
#         DETACH DELETE n
#         RETURN to_keep
#
# Query executed successfully.
# Executing query: CREATE INDEX ON :File(name)
# Query executed successfully.
# Executing query:
#         MATCH (n:File)
#         WITH n.name AS name, COUNT(n) AS count
#         WHERE count > 1
#         RETURN name, count
#
# Query executed successfully.
# Executing query: CREATE CONSTRAINT ON (f:File) ASSERT f.name IS UNIQUE
# Query executed successfully.

# %% [markdown]
# #### Memgraph Validation

# %%
import os
import mgclient
from markdown import Markdown
from markdown.treeprocessors import Treeprocessor
from markdown.extensions import Extension
import re
import datetime
from mgclient import DatabaseError

class MemgraphManager:
    def __init__(self):
        try:
            self.connection = mgclient.connect(host='localhost', port=7687, lazy=False)
            self.connection.autocommit = True
        except Exception as e:
            print(f"Failed to connect to Memgraph: {e}")
            raise

    def execute_query(self, query: str):
        print(f"Executing query: {query}")
        try:
            cursor = self.connection.cursor()
            cursor.execute(query)
            results = cursor.fetchall()
            cursor.close()
            print("Query executed successfully.")
            return results
        except Exception as e:
            print(f"Failed to execute query: {e}")
            if cursor:
                cursor.close()
            raise

    def find_duplicates(self):
        query = """
        MATCH (n:File)
        WITH n.name AS name, COUNT(n) AS count
        WHERE count > 1
        RETURN name, count
        """
        return self.execute_query(query)

    def merge_nodes(self, name):
        merge_query = f"""
        MATCH (n:File {{name: '{name}'}})
        WITH COLLECT(n) AS nodes
        CALL {{
            WITH nodes
            UNWIND nodes AS n
            WITH n LIMIT 1
            RETURN n
        }} AS kept_node
        WITH nodes, kept_node.n AS to_keep
        UNWIND nodes AS n
        WITH n, to_keep WHERE n <> to_keep
        OPTIONAL MATCH (n)-[r]-()
        DELETE r
        DETACH DELETE n
        RETURN to_keep
        """
        self.execute_query(merge_query)

    def merge_duplicates(self):
        duplicates = self.find_duplicates()
        for name, _ in duplicates:
            self.merge_nodes(name)

    def create_node(self, label: str, properties: dict):
        props = ", ".join([f"{k}: '{v}'" for k, v in properties.items()])
        query = f"CREATE (n:{label} {{{props}}})"
        try:
            self.execute_query(query)
        except DatabaseError as e:
            if "unique constraint violation" in str(e):
                print(f"Node {label} with properties {properties} already exists. Skipping creation.")
            else:
                raise

    def create_edge(self, from_node: str, to_node: str, relationship: str):
        query = f"""
        MATCH (a), (b)
        WHERE a.name = '{from_node}' AND b.name = '{to_node}'
        CREATE (a)-[r:{relationship}]->(b)
        """
        self.execute_query(query)

class HeadingExtractor(Treeprocessor):
    def __init__(self, md):
        super().__init__(md)
        self.headings = []

    def run(self, root):
        for element in root:
            if element.tag.startswith('h'):
                self.headings.append((element.tag, element.text))
        return root

class ExtractHeadings(Extension):
    def extendMarkdown(self, md):
        heading_extractor = HeadingExtractor(md)
        md.treeprocessors.register(heading_extractor, 'extract_headings', 10)
        md.heading_extractor = heading_extractor

def parse_markdown(file_path):
    md = Markdown(extensions=[ExtractHeadings()])
    with open(file_path, 'r', encoding='utf-8') as f:
        content = f.read()
    md.convert(content)
    links = re.findall(r'\[.*?\]\((.*?)\)', content)
    return md.heading_extractor.headings, links

def sanitize_text(text):
    if text is None:
        return "None"
    sanitized = text.replace("'", "\\'").replace("#", "").replace("?", "")
    return sanitized

def add_indexes_and_constraints(mg_manager):
    index_query = "CREATE INDEX ON :File(name)"
    mg_manager.execute_query(index_query)

    mg_manager.merge_duplicates()

    constraint_query = "CREATE CONSTRAINT ON (f:File) ASSERT f.name IS UNIQUE"
    mg_manager.execute_query(constraint_query)

# Path to the directory containing markdown files (Obsidian vault)
notes_dir = '/Users/dcarmocan/Projects/mind-cave'

# Initialize the MemgraphManager
mg_manager = MemgraphManager()

# Add indexes and constraints
add_indexes_and_constraints(mg_manager)

# Process each markdown file in the directory
for root, dirs, files in os.walk(notes_dir):
    for file in files:
        if file.endswith('.md'):
            file_path = os.path.join(root, file)
            print(f"Processing file: {file_path}")
            
            # Extract headings and links
            headings, links = parse_markdown(file_path)
            file_name = os.path.basename(file_path)
            
            # Create a node for the file
            mg_manager.create_node('File', {'name': file_name})
            
            # Create nodes and edges for each heading
            previous_heading = file_name
            for tag, heading in headings:
                sanitized_heading = sanitize_text(heading)
                if tag == 'hr':
                    print(f"Skipping creation of 'hr' node for heading: {heading}")
                    continue
                heading_node = f"{file_name}_{sanitized_heading}"
                mg_manager.create_node(tag, {'name': heading_node})
                mg_manager.create_edge(previous_heading, heading_node, 'CONTAINS')
                previous_heading = heading_node

            # Create edges for links to other files
            for link in links:
                link_file_name = os.path.basename(link)
                mg_manager.create_edge(file_name, link_file_name, 'LINKS_TO')

# Queries to validate the relationships
print("Validating relationships between File to File and File to h1")
mg_manager.execute_query("MATCH (n:File)-[r]->(m:File) RETURN n, r, m LIMIT 100;")
mg_manager.execute_query("MATCH (n:File)-[r]->(m:h1) RETURN n, r, m LIMIT 100;")
mg_manager.execute_query("MATCH (n:File)-[r]->(m) WHERE m:File OR m:h1 RETURN n, r, m LIMIT 100;")
mg_manager.execute_query("MATCH (n:File)-[r]->(m) RETURN n, r, m LIMIT 100;")
# Out:
# Executing query: CREATE INDEX ON :File(name)
# Query executed successfully.
# Executing query:
#         MATCH (n:File)
#         WITH n.name AS name, COUNT(n) AS count
#         WHERE count > 1
#         RETURN name, count
#
# Query executed successfully.
# Executing query: CREATE CONSTRAINT ON (f:File) ASSERT f.name IS UNIQUE
# Query executed successfully.
# Processing file: /Users/dcarmocan/Projects/mind-cave/SPOG.md
# Executing query: CREATE (n:File {name: 'SPOG.md'})
# Failed to execute query: Unable to commit due to unique constraint violation on :File(name)
# Node File with properties {'name': 'SPOG.md'} already exists. Skipping creation.
# Skipping creation of 'hr' node for heading: None
# Skipping creation of 'hr' node for heading: None
# Executing query: CREATE (n:h3 {name: 'SPOG.md_SPOG'})
# Query executed successfully.
# Executing query:
#         MATCH (a), (b)
#         WHERE a.name = 'SPOG.md' AND b.name = 'SPOG.md_SPOG'
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h4 {name: 'SPOG.md_Zoom SPOG'})
# Query executed successfully.
# Executing query:
#         MATCH (a), (b)
#         WHERE a.name = 'SPOG.md_SPOG' AND b.name = 'SPOG.md_Zoom SPOG'
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h2 {name: 'SPOG.md_- Carmine asked for a couple of things for the SPOG on [[2023-03-16]] .  I need to look and see if I can get these items completed in time for the meeting today.'})
# Query executed successfully.
# Executing query:
#         MATCH (a), (b)
#         WHERE a.name = 'SPOG.md_Zoom SPOG' AND b.name = 'SPOG.md_- Carmine asked for a couple of things for the SPOG on [[2023-03-16]] .  I need to look and see if I can get these items completed in time for the meeting today.'
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h4 {name: 'SPOG.md_VDI SPOG'})
# Query executed successfully.
# Executing query:
#         MATCH (a), (b)
#         WHERE a.name = 'SPOG.md_- Carmine asked for a couple of things for the SPOG on [[2023-03-16]] .  I need to look and see if I can get these items completed in time for the meeting today.' AND b.name = 'SPOG.md_VDI SPOG'
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Processing file: /Users/dcarmocan/Projects/mind-cave/Zoom Dashboard Documentation.md
# Executing query: CREATE (n:File {name: 'Zoom Dashboard Documentation.md'})
# Failed to execute query: Unable to commit due to unique constraint violation on :File(name)
# Node File with properties {'name': 'Zoom Dashboard Documentation.md'} already exists. Skipping creation.
# Skipping creation of 'hr' node for heading: None
# Skipping creation of 'hr' node for heading: None
# Executing query: CREATE (n:h1 {name: 'Zoom Dashboard Documentation.md_kb'})
# Query executed successfully.
# Executing query:
#         MATCH (a), (b)
#         WHERE a.name = 'Zoom Dashboard Documentation.md' AND b.name = 'Zoom Dashboard Documentation.md_kb'
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h1 {name: 'Zoom Dashboard Documentation.md_Zoom API Integration Documentation'})
# Query executed successfully.
# Executing query:
#         MATCH (a), (b)
#         WHERE a.name = 'Zoom Dashboard Documentation.md_kb' AND b.name = 'Zoom Dashboard Documentation.md_Zoom API Integration Documentation'
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h2 {name: 'Zoom Dashboard Documentation.md_Table of Contents'})
# Query executed successfully.
# Executing query:
#         MATCH (a), (b)
#         WHERE a.name = 'Zoom Dashboard Documentation.md_Zoom API Integration Documentation' AND b.name = 'Zoom Dashboard Documentation.md_Table of Contents'
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h2 {name: 'Zoom Dashboard Documentation.md_1. Introduction'})
# Query executed successfully.
# Executing query:
#         MATCH (a), (b)
#         WHERE a.name = 'Zoom Dashboard Documentation.md_Table of Contents' AND b.name = 'Zoom Dashboard Documentation.md_1. Introduction'
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h2 {name: 'Zoom Dashboard Documentation.md_2. Prerequisites'})
# Query executed successfully.
# Executing query:
#         MATCH (a), (b)
#         WHERE a.name = 'Zoom Dashboard Documentation.md_1. Introduction' AND b.name = 'Zoom Dashboard Documentation.md_2. Prerequisites'
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h2 {name: 'Zoom Dashboard Documentation.md_3. Authentication'})
# Query executed successfully.
# Executing query:
#         MATCH (a), (b)
#         WHERE a.name = 'Zoom Dashboard Documentation.md_2. Prerequisites' AND b.name = 'Zoom Dashboard Documentation.md_3. Authentication'
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h2 {name: 'Zoom Dashboard Documentation.md_4. Gathering Data from Zoom Meetings'})
# Query executed successfully.
# Executing query:
#         MATCH (a), (b)
#         WHERE a.name = 'Zoom Dashboard Documentation.md_3. Authentication' AND b.name = 'Zoom Dashboard Documentation.md_4. Gathering Data from Zoom Meetings'
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h2 {name: 'Zoom Dashboard Documentation.md_5. Gathering Data from Zoom Webinars'})
# Query executed successfully.
# Executing query:
#         MATCH (a), (b)
#         WHERE a.name = 'Zoom Dashboard Documentation.md_4. Gathering Data from Zoom Meetings' AND b.name = 'Zoom Dashboard Documentation.md_5. Gathering Data from Zoom Webinars'
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h2 {name: 'Zoom Dashboard Documentation.md_6. Generating Insights'})
# Query executed successfully.
# Executing query:
#         MATCH (a), (b)
#         WHERE a.name = 'Zoom Dashboard Documentation.md_5. Gathering Data from Zoom Webinars' AND b.name = 'Zoom Dashboard Documentation.md_6. Generating Insights'
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h2 {name: 'Zoom Dashboard Documentation.md_7. High-Level Overview'})
# Query executed successfully.
# Executing query:
#         MATCH (a), (b)
#         WHERE a.name = 'Zoom Dashboard Documentation.md_6. Generating Insights' AND b.name = 'Zoom Dashboard Documentation.md_7. High-Level Overview'
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h2 {name: 'Zoom Dashboard Documentation.md_8. Conclusion'})
# Query executed successfully.
# Executing query:
#         MATCH (a), (b)
#         WHERE a.name = 'Zoom Dashboard Documentation.md_7. High-Level Overview' AND b.name = 'Zoom Dashboard Documentation.md_8. Conclusion'
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Processing file: /Users/dcarmocan/Projects/mind-cave/Summary Week - 20230915.md
# Executing query: CREATE (n:File {name: 'Summary Week - 20230915.md'})
# Failed to execute query: Unable to commit due to unique constraint violation on :File(name)
# Node File with properties {'name': 'Summary Week - 20230915.md'} already exists. Skipping creation.
# Skipping creation of 'hr' node for heading: None
# Skipping creation of 'hr' node for heading: None
# Executing query: CREATE (n:h1 {name: 'Summary Week - 20230915.md_weekly-status'})
# Query executed successfully.
# Executing query:
#         MATCH (a), (b)
#         WHERE a.name = 'Summary Week - 20230915.md' AND b.name = 'Summary Week - 20230915.md_weekly-status'
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h1 {name: 'Summary Week - 20230915.md_Status Update'})
# Query executed successfully.
# Executing query:
#         MATCH (a), (b)
#         WHERE a.name = 'Summary Week - 20230915.md_weekly-status' AND b.name = 'Summary Week - 20230915.md_Status Update'
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Processing file: /Users/dcarmocan/Projects/mind-cave/Project Plan Template.md
# Executing query: CREATE (n:File {name: 'Project Plan Template.md'})
# Failed to execute query: Unable to commit due to unique constraint violation on :File(name)
# Node File with properties {'name': 'Project Plan Template.md'} already exists. Skipping creation.
# Skipping creation of 'hr' node for heading: None
# Skipping creation of 'hr' node for heading: None
# Executing query: CREATE (n:h1 {name: 'Project Plan Template.md_templates'})
# Query executed successfully.
# Executing query:
#         MATCH (a), (b)
#         WHERE a.name = 'Project Plan Template.md' AND b.name = 'Project Plan Template.md_templates'
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h1 {name: 'Project Plan Template.md_Project Summary'})
# Query executed successfully.
# Executing query:
#         MATCH (a), (b)
#         WHERE a.name = 'Project Plan Template.md_templates' AND b.name = 'Project Plan Template.md_Project Summary'
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h1 {name: 'Project Plan Template.md_Project Team'})
# Query executed successfully.
# Executing query:
#         MATCH (a), (b)
#         WHERE a.name = 'Project Plan Template.md_Project Summary' AND b.name = 'Project Plan Template.md_Project Team'
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h1 {name: 'Project Plan Template.md_In Scope'})
# Query executed successfully.
# Executing query:
#         MATCH (a), (b)
#         WHERE a.name = 'Project Plan Template.md_Project Team' AND b.name = 'Project Plan Template.md_In Scope'
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h1 {name: 'Project Plan Template.md_Out-of-Scope'})
# Query executed successfully.
# Executing query:
#         MATCH (a), (b)
#         WHERE a.name = 'Project Plan Template.md_In Scope' AND b.name = 'Project Plan Template.md_Out-of-Scope'
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h1 {name: 'Project Plan Template.md_Project Requirements'})
# Query executed successfully.
# Executing query:
#         MATCH (a), (b)
#         WHERE a.name = 'Project Plan Template.md_Out-of-Scope' AND b.name = 'Project Plan Template.md_Project Requirements'
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h2 {name: 'Project Plan Template.md_Objectives'})
# Query executed successfully.
# Executing query:
#         MATCH (a), (b)
#         WHERE a.name = 'Project Plan Template.md_Project Requirements' AND b.name = 'Project Plan Template.md_Objectives'
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h2 {name: 'Project Plan Template.md_Scopes'})
# Query executed successfully.
# Executing query:
#         MATCH (a), (b)
#         WHERE a.name = 'Project Plan Template.md_Objectives' AND b.name = 'Project Plan Template.md_Scopes'
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h2 {name: 'Project Plan Template.md_Assumptions'})
# Query executed successfully.
# Executing query:
#         MATCH (a), (b)
#         WHERE a.name = 'Project Plan Template.md_Scopes' AND b.name = 'Project Plan Template.md_Assumptions'
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h1 {name: 'Project Plan Template.md_Impact Analysis'})
# Query executed successfully.
# Executing query:
#         MATCH (a), (b)
#         WHERE a.name = 'Project Plan Template.md_Assumptions' AND b.name = 'Project Plan Template.md_Impact Analysis'
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h2 {name: 'Project Plan Template.md_Key Business Areas'})
# Query executed successfully.
# Executing query:
#         MATCH (a), (b)
#         WHERE a.name = 'Project Plan Template.md_Impact Analysis' AND b.name = 'Project Plan Template.md_Key Business Areas'
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h2 {name: 'Project Plan Template.md_Critical Functions'})
# Query executed successfully.
# Executing query:
#         MATCH (a), (b)
#         WHERE a.name = 'Project Plan Template.md_Key Business Areas' AND b.name = 'Project Plan Template.md_Critical Functions'
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h2 {name: 'Project Plan Template.md_Dependencies'})
# Query executed successfully.
# Executing query:
#         MATCH (a), (b)
#         WHERE a.name = 'Project Plan Template.md_Critical Functions' AND b.name = 'Project Plan Template.md_Dependencies'
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h2 {name: 'Project Plan Template.md_Determine Acceptable Downtime'})
# Query executed successfully.
# Executing query:
#         MATCH (a), (b)
#         WHERE a.name = 'Project Plan Template.md_Dependencies' AND b.name = 'Project Plan Template.md_Determine Acceptable Downtime'
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h2 {name: 'Project Plan Template.md_Priority'})
# Query executed successfully.
# Executing query:
#         MATCH (a), (b)
#         WHERE a.name = 'Project Plan Template.md_Determine Acceptable Downtime' AND b.name = 'Project Plan Template.md_Priority'
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h2 {name: 'Project Plan Template.md_Critical Applications & Downtime'})
# Query executed successfully.
# Executing query:
#         MATCH (a), (b)
#         WHERE a.name = 'Project Plan Template.md_Priority' AND b.name = 'Project Plan Template.md_Critical Applications & Downtime'
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h1 {name: 'Project Plan Template.md_Test Plan'})
# Query executed successfully.
# Executing query:
#         MATCH (a), (b)
#         WHERE a.name = 'Project Plan Template.md_Critical Applications & Downtime' AND b.name = 'Project Plan Template.md_Test Plan'
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h1 {name: 'Project Plan Template.md_Execution'})
# Query executed successfully.
# Executing query:
#         MATCH (a), (b)
#         WHERE a.name = 'Project Plan Template.md_Test Plan' AND b.name = 'Project Plan Template.md_Execution'
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h2 {name: 'Project Plan Template.md_Execution Team'})
# Query executed successfully.
# Executing query:
#         MATCH (a), (b)
#         WHERE a.name = 'Project Plan Template.md_Execution' AND b.name = 'Project Plan Template.md_Execution Team'
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h2 {name: 'Project Plan Template.md_Continuity Plan'})
# Query executed successfully.
# Executing query:
#         MATCH (a), (b)
#         WHERE a.name = 'Project Plan Template.md_Execution Team' AND b.name = 'Project Plan Template.md_Continuity Plan'
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h3 {name: 'Project Plan Template.md_Checklist:'})
# Query executed successfully.
# Executing query:
#         MATCH (a), (b)
#         WHERE a.name = 'Project Plan Template.md_Continuity Plan' AND b.name = 'Project Plan Template.md_Checklist:'
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h2 {name: 'Project Plan Template.md_Maintainer Plan'})
# Query executed successfully.
# Executing query:
#         MATCH (a), (b)
#         WHERE a.name = 'Project Plan Template.md_Checklist:' AND b.name = 'Project Plan Template.md_Maintainer Plan'
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h2 {name: 'Project Plan Template.md_Communications Plan'})
# Query executed successfully.
# Executing query:
#         MATCH (a), (b)
#         WHERE a.name = 'Project Plan Template.md_Maintainer Plan' AND b.name = 'Project Plan Template.md_Communications Plan'
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h1 {name: 'Project Plan Template.md_Training And Research'})
# Query executed successfully.
# Executing query:
#         MATCH (a), (b)
#         WHERE a.name = 'Project Plan Template.md_Communications Plan' AND b.name = 'Project Plan Template.md_Training And Research'
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h1 {name: 'Project Plan Template.md_References'})
# Query executed successfully.
# Executing query:
#         MATCH (a), (b)
#         WHERE a.name = 'Project Plan Template.md_Training And Research' AND b.name = 'Project Plan Template.md_References'
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Processing file: /Users/dcarmocan/Projects/mind-cave/Cap_Planning_Article.md
# Executing query: CREATE (n:File {name: 'Cap_Planning_Article.md'})
# Failed to execute query: Unable to commit due to unique constraint violation on :File(name)
# Node File with properties {'name': 'Cap_Planning_Article.md'} already exists. Skipping creation.
# Skipping creation of 'hr' node for heading: None
# Skipping creation of 'hr' node for heading: None
# Executing query: CREATE (n:h1 {name: 'Cap_Planning_Article.md_process-docs'})
# Query executed successfully.
# Executing query:
#         MATCH (a), (b)
#         WHERE a.name = 'Cap_Planning_Article.md' AND b.name = 'Cap_Planning_Article.md_process-docs'
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h1 {name: 'Cap_Planning_Article.md_Mastering Work Prioritization: Overcoming the Challenges of High-Priority Task Overload in Business and Technology Systems'})
# Query executed successfully.
# Executing query:
#         MATCH (a), (b)
#         WHERE a.name = 'Cap_Planning_Article.md_process-docs' AND b.name = 'Cap_Planning_Article.md_Mastering Work Prioritization: Overcoming the Challenges of High-Priority Task Overload in Business and Technology Systems'
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h2 {name: 'Cap_Planning_Article.md_Navigating the Perils of Resource Saturation in Agile Sprints'})
# Query executed successfully.
# Executing query:
#         MATCH (a), (b)
#         WHERE a.name = 'Cap_Planning_Article.md_Mastering Work Prioritization: Overcoming the Challenges of High-Priority Task Overload in Business and Technology Systems' AND b.name = 'Cap_Planning_Article.md_Navigating the Perils of Resource Saturation in Agile Sprints'
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h1 {name: 'Cap_Planning_Article.md_The Importance of Meaningful Prioritization in Agile Sprints'})
# Query executed successfully.
# Executing query:
#         MATCH (a), (b)
#         WHERE a.name = 'Cap_Planning_Article.md_Navigating the Perils of Resource Saturation in Agile Sprints' AND b.name = 'Cap_Planning_Article.md_The Importance of Meaningful Prioritization in Agile Sprints'
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h3 {name: 'Cap_Planning_Article.md_None'})
# Query executed successfully.
# Executing query:
#         MATCH (a), (b)
#         WHERE a.name = 'Cap_Planning_Article.md_The Importance of Meaningful Prioritization in Agile Sprints' AND b.name = 'Cap_Planning_Article.md_None'
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h3 {name: 'Cap_Planning_Article.md_None'})
# Query executed successfully.
# Executing query:
#         MATCH (a), (b)
#         WHERE a.name = 'Cap_Planning_Article.md_None' AND b.name = 'Cap_Planning_Article.md_None'
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h1 {name: 'Cap_Planning_Article.md_Addressing the Impact of Stress on Decision-Making and Teamwork in Agile Environments'})
# Query executed successfully.
# Executing query:
#         MATCH (a), (b)
#         WHERE a.name = 'Cap_Planning_Article.md_None' AND b.name = 'Cap_Planning_Article.md_Addressing the Impact of Stress on Decision-Making and Teamwork in Agile Environments'
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h2 {name: 'Cap_Planning_Article.md_None'})
# Query executed successfully.
# Executing query:
#         MATCH (a), (b)
#         WHERE a.name = 'Cap_Planning_Article.md_Addressing the Impact of Stress on Decision-Making and Teamwork in Agile Environments' AND b.name = 'Cap_Planning_Article.md_None'
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h2 {name: 'Cap_Planning_Article.md_None'})
# Query executed successfully.
# Executing query:
#         MATCH (a), (b)
#         WHERE a.name = 'Cap_Planning_Article.md_None' AND b.name = 'Cap_Planning_Article.md_None'
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h1 {name: 'Cap_Planning_Article.md_None'})
# Query executed successfully.
# Executing query:
#         MATCH (a), (b)
#         WHERE a.name = 'Cap_Planning_Article.md_None' AND b.name = 'Cap_Planning_Article.md_None'
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Processing file: /Users/dcarmocan/Projects/mind-cave/Terminator_Doc.md
# Executing query: CREATE (n:File {name: 'Terminator_Doc.md'})
# Failed to execute query: Unable to commit due to unique constraint violation on :File(name)
# Node File with properties {'name': 'Terminator_Doc.md'} already exists. Skipping creation.
# Skipping creation of 'hr' node for heading: None
# Skipping creation of 'hr' node for heading: None
# Executing query: CREATE (n:h1 {name: 'Terminator_Doc.md_process-docs'})
# Query executed successfully.
# Executing query:
#         MATCH (a), (b)
#         WHERE a.name = 'Terminator_Doc.md' AND b.name = 'Terminator_Doc.md_process-docs'
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h2 {name: 'Terminator_Doc.md_Introduction'})
# Query executed successfully.
# Executing query:
#         MATCH (a), (b)
#         WHERE a.name = 'Terminator_Doc.md_process-docs' AND b.name = 'Terminator_Doc.md_Introduction'
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h2 {name: 'Terminator_Doc.md_Addressing Off-boarding Needs'})
# Query executed successfully.
# Executing query:
#         MATCH (a), (b)
#         WHERE a.name = 'Terminator_Doc.md_Introduction' AND b.name = 'Terminator_Doc.md_Addressing Off-boarding Needs'
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h3 {name: 'Terminator_Doc.md_Event-Driven Automation Through Google Workspace Admin'})
# Query executed successfully.
# Executing query:
#         MATCH (a), (b)
#         WHERE a.name = 'Terminator_Doc.md_Addressing Off-boarding Needs' AND b.name = 'Terminator_Doc.md_Event-Driven Automation Through Google Workspace Admin'
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h4 {name: 'Terminator_Doc.md_Google Admin SDK and Cloud Logging Integration'})
# Query executed successfully.
# Executing query:
#         MATCH (a), (b)
#         WHERE a.name = 'Terminator_Doc.md_Event-Driven Automation Through Google Workspace Admin' AND b.name = 'Terminator_Doc.md_Google Admin SDK and Cloud Logging Integration'
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h4 {name: 'Terminator_Doc.md_Event Filtering'})
# Query executed successfully.
# Executing query:
#         MATCH (a), (b)
#         WHERE a.name = 'Terminator_Doc.md_Google Admin SDK and Cloud Logging Integration' AND b.name = 'Terminator_Doc.md_Event Filtering'
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h4 {name: 'Terminator_Doc.md_Domain-Wide Delegation and Service Account'})
# Query executed successfully.
# Executing query:
#         MATCH (a), (b)
#         WHERE a.name = 'Terminator_Doc.md_Event Filtering' AND b.name = 'Terminator_Doc.md_Domain-Wide Delegation and Service Account'
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h2 {name: 'Terminator_Doc.md_The Tech Stack'})
# Query executed successfully.
# Executing query:
#         MATCH (a), (b)
#         WHERE a.name = 'Terminator_Doc.md_Domain-Wide Delegation and Service Account' AND b.name = 'Terminator_Doc.md_The Tech Stack'
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h3 {name: 'Terminator_Doc.md_Google Admin SDK'})
# Query executed successfully.
# Executing query:
#         MATCH (a), (b)
#         WHERE a.name = 'Terminator_Doc.md_The Tech Stack' AND b.name = 'Terminator_Doc.md_Google Admin SDK'
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h3 {name: 'Terminator_Doc.md_Google Cloud Logging'})
# Query executed successfully.
# Executing query:
#         MATCH (a), (b)
#         WHERE a.name = 'Terminator_Doc.md_Google Admin SDK' AND b.name = 'Terminator_Doc.md_Google Cloud Logging'
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h3 {name: 'Terminator_Doc.md_Google Pub/Sub'})
# Query executed successfully.
# Executing query:
#         MATCH (a), (b)
#         WHERE a.name = 'Terminator_Doc.md_Google Cloud Logging' AND b.name = 'Terminator_Doc.md_Google Pub/Sub'
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h3 {name: 'Terminator_Doc.md_Google Cloud Functions'})
# Query executed successfully.
# Executing query:
#         MATCH (a), (b)
#         WHERE a.name = 'Terminator_Doc.md_Google Pub/Sub' AND b.name = 'Terminator_Doc.md_Google Cloud Functions'
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h3 {name: 'Terminator_Doc.md_Google Cloud Run'})
# Query executed successfully.
# Executing query:
#         MATCH (a), (b)
#         WHERE a.name = 'Terminator_Doc.md_Google Cloud Functions' AND b.name = 'Terminator_Doc.md_Google Cloud Run'
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h3 {name: 'Terminator_Doc.md_Google Eventarc'})
# Query executed successfully.
# Executing query:
#         MATCH (a), (b)
#         WHERE a.name = 'Terminator_Doc.md_Google Cloud Run' AND b.name = 'Terminator_Doc.md_Google Eventarc'
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h2 {name: 'Terminator_Doc.md_Benefits and Cost Savings of the Terminator Project'})
# Query executed successfully.
# Executing query:
#         MATCH (a), (b)
#         WHERE a.name = 'Terminator_Doc.md_Google Eventarc' AND b.name = 'Terminator_Doc.md_Benefits and Cost Savings of the Terminator Project'
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h3 {name: 'Terminator_Doc.md_Financial Savings'})
# Query executed successfully.
# Executing query:
#         MATCH (a), (b)
#         WHERE a.name = 'Terminator_Doc.md_Benefits and Cost Savings of the Terminator Project' AND b.name = 'Terminator_Doc.md_Financial Savings'
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h3 {name: 'Terminator_Doc.md_Customization and Flexibility'})
# Query executed successfully.
# Executing query:
#         MATCH (a), (b)
#         WHERE a.name = 'Terminator_Doc.md_Financial Savings' AND b.name = 'Terminator_Doc.md_Customization and Flexibility'
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h3 {name: 'Terminator_Doc.md_Improved Security and Compliance'})
# Query executed successfully.
# Executing query:
#         MATCH (a), (b)
#         WHERE a.name = 'Terminator_Doc.md_Customization and Flexibility' AND b.name = 'Terminator_Doc.md_Improved Security and Compliance'
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h3 {name: 'Terminator_Doc.md_Enhanced Integration'})
# Query executed successfully.
# Executing query:
#         MATCH (a), (b)
#         WHERE a.name = 'Terminator_Doc.md_Improved Security and Compliance' AND b.name = 'Terminator_Doc.md_Enhanced Integration'
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h3 {name: 'Terminator_Doc.md_Scalability and Performance'})
# Query executed successfully.
# Executing query:
#         MATCH (a), (b)
#         WHERE a.name = 'Terminator_Doc.md_Enhanced Integration' AND b.name = 'Terminator_Doc.md_Scalability and Performance'
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h3 {name: 'Terminator_Doc.md_Increased Control and Visibility'})
# Query executed successfully.
# Executing query:
#         MATCH (a), (b)
#         WHERE a.name = 'Terminator_Doc.md_Scalability and Performance' AND b.name = 'Terminator_Doc.md_Increased Control and Visibility'
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h2 {name: 'Terminator_Doc.md_Integrating Google Workspace Admin with GCP Using Log Sinks: A High-Level Overview'})
# Query executed successfully.
# Executing query:
#         MATCH (a), (b)
#         WHERE a.name = 'Terminator_Doc.md_Increased Control and Visibility' AND b.name = 'Terminator_Doc.md_Integrating Google Workspace Admin with GCP Using Log Sinks: A High-Level Overview'
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h3 {name: 'Terminator_Doc.md_What are Log Sinks'})
# Query executed successfully.
# Executing query:
#         MATCH (a), (b)
#         WHERE a.name = 'Terminator_Doc.md_Integrating Google Workspace Admin with GCP Using Log Sinks: A High-Level Overview' AND b.name = 'Terminator_Doc.md_What are Log Sinks'
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h3 {name: 'Terminator_Doc.md_How do Log Sinks work with Google Workspace Admin'})
# Query executed successfully.
# Executing query:
#         MATCH (a), (b)
#         WHERE a.name = 'Terminator_Doc.md_What are Log Sinks' AND b.name = 'Terminator_Doc.md_How do Log Sinks work with Google Workspace Admin'
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h3 {name: 'Terminator_Doc.md_Why use Log Sinks for off-boarding automation'})
# Query executed successfully.
# Executing query:
#         MATCH (a), (b)
#         WHERE a.name = 'Terminator_Doc.md_How do Log Sinks work with Google Workspace Admin' AND b.name = 'Terminator_Doc.md_Why use Log Sinks for off-boarding automation'
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h1 {name: 'Terminator_Doc.md_!/bin/bash'})
# Query executed successfully.
# Executing query:
#         MATCH (a), (b)
#         WHERE a.name = 'Terminator_Doc.md_Why use Log Sinks for off-boarding automation' AND b.name = 'Terminator_Doc.md_!/bin/bash'
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h1 {name: 'Terminator_Doc.md_Get the hostname'})
# Query executed successfully.
# Executing query:
#         MATCH (a), (b)
#         WHERE a.name = 'Terminator_Doc.md_!/bin/bash' AND b.name = 'Terminator_Doc.md_Get the hostname'
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h1 {name: 'Terminator_Doc.md_Get the memory usage'})
# Query executed successfully.
# Executing query:
#         MATCH (a), (b)
#         WHERE a.name = 'Terminator_Doc.md_Get the hostname' AND b.name = 'Terminator_Doc.md_Get the memory usage'
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h1 {name: 'Terminator_Doc.md_Get the CPU usage'})
# Query executed successfully.
# Executing query:
#         MATCH (a), (b)
#         WHERE a.name = 'Terminator_Doc.md_Get the memory usage' AND b.name = 'Terminator_Doc.md_Get the CPU usage'
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Processing file: /Users/dcarmocan/Projects/mind-cave/SMART_GOALS_Format.md
# Executing query: CREATE (n:File {name: 'SMART_GOALS_Format.md'})
# Failed to execute query: Unable to commit due to unique constraint violation on :File(name)
# Node File with properties {'name': 'SMART_GOALS_Format.md'} already exists. Skipping creation.
# Skipping creation of 'hr' node for heading: None
# Skipping creation of 'hr' node for heading: None
# Executing query: CREATE (n:h1 {name: 'SMART_GOALS_Format.md_process-docs'})
# Query executed successfully.
# Executing query:
#         MATCH (a), (b)
#         WHERE a.name = 'SMART_GOALS_Format.md' AND b.name = 'SMART_GOALS_Format.md_process-docs'
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h2 {name: 'SMART_GOALS_Format.md_What are SMART goals'})
# Query executed successfully.
# Executing query:
#         MATCH (a), (b)
#         WHERE a.name = 'SMART_GOALS_Format.md_process-docs' AND b.name = 'SMART_GOALS_Format.md_What are SMART goals'
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h2 {name: 'SMART_GOALS_Format.md_How to write SMART goals'})
# Query executed successfully.
# Executing query:
#         MATCH (a), (b)
#         WHERE a.name = 'SMART_GOALS_Format.md_What are SMART goals' AND b.name = 'SMART_GOALS_Format.md_How to write SMART goals'
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h2 {name: 'SMART_GOALS_Format.md_S: Specific'})
# Query executed successfully.
# Executing query:
#         MATCH (a), (b)
#         WHERE a.name = 'SMART_GOALS_Format.md_How to write SMART goals' AND b.name = 'SMART_GOALS_Format.md_S: Specific'
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h6 {name: 'SMART_GOALS_Format.md_SPECIFIC'})
# Query executed successfully.
# Executing query:
#         MATCH (a), (b)
#         WHERE a.name = 'SMART_GOALS_Format.md_S: Specific' AND b.name = 'SMART_GOALS_Format.md_SPECIFIC'
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h2 {name: 'SMART_GOALS_Format.md_M: Measurable'})
# Query executed successfully.
# Executing query:
#         MATCH (a), (b)
#         WHERE a.name = 'SMART_GOALS_Format.md_SPECIFIC' AND b.name = 'SMART_GOALS_Format.md_M: Measurable'
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h6 {name: 'SMART_GOALS_Format.md_MEASURABLE'})
# Query executed successfully.
# Executing query:
#         MATCH (a), (b)
#         WHERE a.name = 'SMART_GOALS_Format.md_M: Measurable' AND b.name = 'SMART_GOALS_Format.md_MEASURABLE'
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h2 {name: 'SMART_GOALS_Format.md_A: Achievable'})
# Query executed successfully.
# Executing query:
#         MATCH (a), (b)
#         WHERE a.name = 'SMART_GOALS_Format.md_MEASURABLE' AND b.name = 'SMART_GOALS_Format.md_A: Achievable'
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h6 {name: 'SMART_GOALS_Format.md_ACHIEVABLE'})
# Query executed successfully.
# Executing query:
#         MATCH (a), (b)
#         WHERE a.name = 'SMART_GOALS_Format.md_A: Achievable' AND b.name = 'SMART_GOALS_Format.md_ACHIEVABLE'
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h2 {name: 'SMART_GOALS_Format.md_R: Relevant'})
# Query executed successfully.
# Executing query:
#         MATCH (a), (b)
#         WHERE a.name = 'SMART_GOALS_Format.md_ACHIEVABLE' AND b.name = 'SMART_GOALS_Format.md_R: Relevant'
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h6 {name: 'SMART_GOALS_Format.md_RELEVANT'})
# Query executed successfully.
# Executing query:
#         MATCH (a), (b)
#         WHERE a.name = 'SMART_GOALS_Format.md_R: Relevant' AND b.name = 'SMART_GOALS_Format.md_RELEVANT'
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h2 {name: 'SMART_GOALS_Format.md_T: Time-bound'})
# Query executed successfully.
# Executing query:
#         MATCH (a), (b)
#         WHERE a.name = 'SMART_GOALS_Format.md_RELEVANT' AND b.name = 'SMART_GOALS_Format.md_T: Time-bound'
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query:
#         MATCH (a), (b)
#         WHERE a.name = 'SMART_GOALS_Format.md' AND b.name = 'brand-4069-90-day-plan-template-blog-illustration-1120x545-@2x-v2-600x480.png'
#         CREATE (a)-[r:LINKS_TO]->(b)
#
# Query executed successfully.
# Processing file: /Users/dcarmocan/Projects/mind-cave/Cap_planning_notes.md
# Executing query: CREATE (n:File {name: 'Cap_planning_notes.md'})
# Failed to execute query: Unable to commit due to unique constraint violation on :File(name)
# Node File with properties {'name': 'Cap_planning_notes.md'} already exists. Skipping creation.
# Skipping creation of 'hr' node for heading: None
# Skipping creation of 'hr' node for heading: None
# Executing query: CREATE (n:h1 {name: 'Cap_planning_notes.md_process-docs'})
# Query executed successfully.
# Executing query:
#         MATCH (a), (b)
#         WHERE a.name = 'Cap_planning_notes.md' AND b.name = 'Cap_planning_notes.md_process-docs'
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query:
#         MATCH (a), (b)
#         WHERE a.name = 'Cap_planning_notes.md' AND b.name = '%3e'
#         CREATE (a)-[r:LINKS_TO]->(b)
#
# Query executed successfully.
# Executing query:
#         MATCH (a), (b)
#         WHERE a.name = 'Cap_planning_notes.md' AND b.name = 'image?url=https%3A%2F%2Flh3.googleusercontent.com%2Fa%2FAGNmyxYCaUfhW6asHZK6aGbE4KLSHPU82W5EUnBZe7M3%3Ds96-c&w=64&q=75'
#         CREATE (a)-[r:LINKS_TO]->(b)
#
# Query executed successfully.
# Executing query:
#         MATCH (a), (b)
#         WHERE a.name = 'Cap_planning_notes.md' AND b.name = '%3e'
#         CREATE (a)-[r:LINKS_TO]->(b)
#
# Query executed successfully.
# Executing query:
#         MATCH (a), (b)
#         WHERE a.name = 'Cap_planning_notes.md' AND b.name = 'image?url=https%3A%2F%2Flh3.googleusercontent.com%2Fa%2FAGNmyxYCaUfhW6asHZK6aGbE4KLSHPU82W5EUnBZe7M3%3Ds96-c&w=64&q=75'
#         CREATE (a)-[r:LINKS_TO]->(b)
#
# Query executed successfully.
# Executing query:
#         MATCH (a), (b)
#         WHERE a.name = 'Cap_planning_notes.md' AND b.name = '%3e'
#         CREATE (a)-[r:LINKS_TO]->(b)
#
# Query executed successfully.
# Executing query:
#         MATCH (a), (b)
#         WHERE a.name = 'Cap_planning_notes.md' AND b.name = 'image?url=https%3A%2F%2Flh3.googleusercontent.com%2Fa%2FAGNmyxYCaUfhW6asHZK6aGbE4KLSHPU82W5EUnBZe7M3%3Ds96-c&w=64&q=75'
#         CREATE (a)-[r:LINKS_TO]->(b)
#
# Query executed successfully.
# Processing file: /Users/dcarmocan/Projects/mind-cave/slack_tasks.md
# Executing query: CREATE (n:File {name: 'slack_tasks.md'})
# Failed to execute query: Unable to commit due to unique constraint violation on :File(name)
# Node File with properties {'name': 'slack_tasks.md'} already exists. Skipping creation.
# Skipping creation of 'hr' node for heading: None
# Skipping creation of 'hr' node for heading: None
# Executing query: CREATE (n:h1 {name: 'slack_tasks.md_'})
# Query executed successfully.
# Executing query:
#         MATCH (a), (b)
#         WHERE a.name = 'slack_tasks.md' AND b.name = 'slack_tasks.md_'
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Processing file: /Users/dcarmocan/Projects/mind-cave/DISP_Discussion.md
# Executing query: CREATE (n:File {name: 'DISP_Discussion.md'})
# Failed to execute query: Unable to commit due to unique constraint violation on :File(name)
# Node File with properties {'name': 'DISP_Discussion.md'} already exists. Skipping creation.
# Skipping creation of 'hr' node for heading: None
# Skipping creation of 'hr' node for heading: None
# Executing query: CREATE (n:h1 {name: 'DISP_Discussion.md_DISP Project Discussion'})
# Query executed successfully.
# Executing query:
#         MATCH (a), (b)
#         WHERE a.name = 'DISP_Discussion.md' AND b.name = 'DISP_Discussion.md_DISP Project Discussion'
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query:
#         MATCH (a), (b)
#         WHERE a.name = 'DISP_Discussion.md' AND b.name = 'p1698185838579289'
#         CREATE (a)-[r:LINKS_TO]->(b)
#
# Query executed successfully.
# Executing query:
#         MATCH (a), (b)
#         WHERE a.name = 'DISP_Discussion.md' AND b.name = 'U05ND2K0BBR'
#         CREATE (a)-[r:LINKS_TO]->(b)
#
# Query executed successfully.
# Executing query:
#         MATCH (a), (b)
#         WHERE a.name = 'DISP_Discussion.md' AND b.name = 'W01918HTJHW'
#         CREATE (a)-[r:LINKS_TO]->(b)
#
# Query executed successfully.
# Executing query:
#         MATCH (a), (b)
#         WHERE a.name = 'DISP_Discussion.md' AND b.name = 'p1698197733807279'
#         CREATE (a)-[r:LINKS_TO]->(b)
#
# Query executed successfully.
# Executing query:
#         MATCH (a), (b)
#         WHERE a.name = 'DISP_Discussion.md' AND b.name = 'p1698199096522449'
#         CREATE (a)-[r:LINKS_TO]->(b)
#
# Query executed successfully.
# Executing query:
#         MATCH (a), (b)
#         WHERE a.name = 'DISP_Discussion.md' AND b.name = 'W01918HTJHW'
#         CREATE (a)-[r:LINKS_TO]->(b)
#
# Query executed successfully.
# Executing query:
#         MATCH (a), (b)
#         WHERE a.name = 'DISP_Discussion.md' AND b.name = 'U05ND2K0BBR'
#         CREATE (a)-[r:LINKS_TO]->(b)
#
# Query executed successfully.
# Executing query:
#         MATCH (a), (b)
#         WHERE a.name = 'DISP_Discussion.md' AND b.name = 'U05ND2K0BBR'
#         CREATE (a)-[r:LINKS_TO]->(b)
#
# Query executed successfully.
# Executing query:
#         MATCH (a), (b)
#         WHERE a.name = 'DISP_Discussion.md' AND b.name = 'p1698200655753679'
#         CREATE (a)-[r:LINKS_TO]->(b)
#
# Query executed successfully.
# Executing query:
#         MATCH (a), (b)
#         WHERE a.name = 'DISP_Discussion.md' AND b.name = 'p1698200959452739'
#         CREATE (a)-[r:LINKS_TO]->(b)
#
# Query executed successfully.
# Executing query:
#         MATCH (a), (b)
#         WHERE a.name = 'DISP_Discussion.md' AND b.name = 'U05ND2K0BBR'
#         CREATE (a)-[r:LINKS_TO]->(b)
#
# Query executed successfully.
# Executing query:
#         MATCH (a), (b)
#         WHERE a.name = 'DISP_Discussion.md' AND b.name = 'p1698201714016489'
#         CREATE (a)-[r:LINKS_TO]->(b)
#
# Query executed successfully.
# Executing query:
#         MATCH (a), (b)
#         WHERE a.name = 'DISP_Discussion.md' AND b.name = 'p1698251558809229'
#         CREATE (a)-[r:LINKS_TO]->(b)
#
# Query executed successfully.
# Executing query:
#         MATCH (a), (b)
#         WHERE a.name = 'DISP_Discussion.md' AND b.name = 'p1698251941675909'
#         CREATE (a)-[r:LINKS_TO]->(b)
#
# Query executed successfully.
# Executing query:
#         MATCH (a), (b)
#         WHERE a.name = 'DISP_Discussion.md' AND b.name = 'edit#slide=id.p1'
#         CREATE (a)-[r:LINKS_TO]->(b)
#
# Query executed successfully.
# Executing query:
#         MATCH (a), (b)
#         WHERE a.name = 'DISP_Discussion.md' AND b.name = 'Splunk+Australian+M365+Tenant+Project'
#         CREATE (a)-[r:LINKS_TO]->(b)
#
# Query executed successfully.
# Processing file: /Users/dcarmocan/Projects/mind-cave/GCP_Data_Engineer_Exam_Prep_Notes.md
# Executing query: CREATE (n:File {name: 'GCP_Data_Engineer_Exam_Prep_Notes.md'})
# Failed to execute query: Unable to commit due to unique constraint violation on :File(name)
# Node File with properties {'name': 'GCP_Data_Engineer_Exam_Prep_Notes.md'} already exists. Skipping creation.
# Skipping creation of 'hr' node for heading: None
# Skipping creation of 'hr' node for heading: None
# Executing query:
#         MATCH (a), (b)
#         WHERE a.name = 'GCP_Data_Engineer_Exam_Prep_Notes.md' AND b.name = 'store-query-data'
#         CREATE (a)-[r:LINKS_TO]->(b)
#
# Query executed successfully.
# Executing query:
#         MATCH (a), (b)
#         WHERE a.name = 'GCP_Data_Engineer_Exam_Prep_Notes.md' AND b.name = 'store-query-data'
#         CREATE (a)-[r:LINKS_TO]->(b)
#
# Query executed successfully.
# Executing query:
#         MATCH (a), (b)
#         WHERE a.name = 'GCP_Data_Engineer_Exam_Prep_Notes.md' AND b.name = 'create-database-server-client-library'
#         CREATE (a)-[r:LINKS_TO]->(b)
#
# Query executed successfully.
# Executing query:
#         MATCH (a), (b)
#         WHERE a.name = 'GCP_Data_Engineer_Exam_Prep_Notes.md' AND b.name = 'create-instance-gcloud'
#         CREATE (a)-[r:LINKS_TO]->(b)
#
# Query executed successfully.
# Processing file: /Users/dcarmocan/Projects/mind-cave/2023-07-20_CD-CD-Status.md
# Executing query: CREATE (n:File {name: '2023-07-20_CD-CD-Status.md'})
# Failed to execute query: Unable to commit due to unique constraint violation on :File(name)
# Node File with properties {'name': '2023-07-20_CD-CD-Status.md'} already exists. Skipping creation.
# Skipping creation of 'hr' node for heading: None
# Skipping creation of 'hr' node for heading: None
# Skipping creation of 'hr' node for heading: None
# Executing query: CREATE (n:h1 {name: '2023-07-20_CD-CD-Status.md_status cd-ci'})
# Query executed successfully.
# Executing query:
#         MATCH (a), (b)
#         WHERE a.name = '2023-07-20_CD-CD-Status.md' AND b.name = '2023-07-20_CD-CD-Status.md_status cd-ci'
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h1 {name: '2023-07-20_CD-CD-Status.md_Status Update'})
# Query executed successfully.
# Executing query:
#         MATCH (a), (b)
#         WHERE a.name = '2023-07-20_CD-CD-Status.md_status cd-ci' AND b.name = '2023-07-20_CD-CD-Status.md_Status Update'
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Processing file: /Users/dcarmocan/Projects/mind-cave/Dashboard_Studio_Changes.md
# Executing query: CREATE (n:File {name: 'Dashboard_Studio_Changes.md'})
# Failed to execute query: Unable to commit due to unique constraint violation on :File(name)
# Node File with properties {'name': 'Dashboard_Studio_Changes.md'} already exists. Skipping creation.
# Skipping creation of 'hr' node for heading: None
# Skipping creation of 'hr' node for heading: None
# Executing query: CREATE (n:h1 {name: 'Dashboard_Studio_Changes.md_process-docs'})
# Query executed successfully.
# Executing query:
#         MATCH (a), (b)
#         WHERE a.name = 'Dashboard_Studio_Changes.md' AND b.name = 'Dashboard_Studio_Changes.md_process-docs'
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h1 {name: 'Dashboard_Studio_Changes.md_New Changes'})
# Query executed successfully.
# Executing query:
#         MATCH (a), (b)
#         WHERE a.name = 'Dashboard_Studio_Changes.md_process-docs' AND b.name = 'Dashboard_Studio_Changes.md_New Changes'
#         CREATE (a)-[r:CONTAINS]->(b)
#
# Query executed successfully.
# Executing query: CREATE (n:h2 {name: 'Dashboard_Studio_Changes.md_- More interactions added'})
# Query executed successfully.
# Executing query:
#         MATCH (a), (b)
#         WHERE a.name = 'Dashboard_Studio_Changes.md_New Changes' AND b.name = 'Dashboard_Studio_Changes.md_- More interactions added'
# ...
#   <mgclient.Node(id=26503, labels={'h1'}, properties={'name': 'Cap_planning_notes.md_process-docs'}) at 0x109365170>),
#  (<mgclient.Node(id=21854, labels={'File'}, properties={'name': 'slack_tasks.md'}) at 0x109367ab0>,
#   <mgclient.Relationship(start_id=21854, end_id=21855, type='CONTAINS', properties={}) at 0x160643cf0>,
#   <mgclient.Node(id=21855, labels={'hr'}, properties={'name': 'slack_tasks.md_None'}) at 0x109365c50>),
#  (<mgclient.Node(id=21854, labels={'File'}, properties={'name': 'slack_tasks.md'}) at 0x1093651d0>,
#   <mgclient.Relationship(start_id=21854, end_id=21856, type='CONTAINS', properties={}) at 0x160643630>,
#   <mgclient.Node(id=21856, labels={'hr'}, properties={'name': 'slack_tasks.md_None'}) at 0x1093655f0>),
#  (<mgclient.Node(id=21854, labels={'File'}, properties={'name': 'slack_tasks.md'}) at 0x109365f20>,
#   <mgclient.Relationship(start_id=21854, end_id=24189, type='CONTAINS', properties={}) at 0x160640970>,
#   <mgclient.Node(id=24189, labels={'hr'}, properties={'name': 'slack_tasks.md_None'}) at 0x109367810>),
#  (<mgclient.Node(id=21854, labels={'File'}, properties={'name': 'slack_tasks.md'}) at 0x1093655c0>,
#   <mgclient.Relationship(start_id=21854, end_id=21857, type='CONTAINS', properties={}) at 0x1606404b0>,
#   <mgclient.Node(id=21857, labels={'h1'}, properties={'name': 'slack_tasks.md_'}) at 0x1093654d0>),
#  (<mgclient.Node(id=21854, labels={'File'}, properties={'name': 'slack_tasks.md'}) at 0x109365d40>,
#   <mgclient.Relationship(start_id=21854, end_id=24191, type='CONTAINS', properties={}) at 0x160641e70>,
#   <mgclient.Node(id=24191, labels={'h1'}, properties={'name': 'slack_tasks.md_'}) at 0x109367f90>),
#  (<mgclient.Node(id=21854, labels={'File'}, properties={'name': 'slack_tasks.md'}) at 0x109365e90>,
#   <mgclient.Relationship(start_id=21854, end_id=26505, type='CONTAINS', properties={}) at 0x108878530>,
#   <mgclient.Node(id=26505, labels={'h1'}, properties={'name': 'slack_tasks.md_'}) at 0x109367780>),
#  (<mgclient.Node(id=21858, labels={'File'}, properties={'name': 'DISP_Discussion.md'}) at 0x1093675d0>,
#   <mgclient.Relationship(start_id=21858, end_id=21859, type='CONTAINS', properties={}) at 0x108879270>,
#   <mgclient.Node(id=21859, labels={'hr'}, properties={'name': 'DISP_Discussion.md_None'}) at 0x109367c00>),
#  (<mgclient.Node(id=21858, labels={'File'}, properties={'name': 'DISP_Discussion.md'}) at 0x109365110>,
#   <mgclient.Relationship(start_id=21858, end_id=21860, type='CONTAINS', properties={}) at 0x10887a070>,
#   <mgclient.Node(id=21860, labels={'hr'}, properties={'name': 'DISP_Discussion.md_None'}) at 0x109367ea0>),
#  (<mgclient.Node(id=21858, labels={'File'}, properties={'name': 'DISP_Discussion.md'}) at 0x109365560>,
#   <mgclient.Relationship(start_id=21858, end_id=24193, type='CONTAINS', properties={}) at 0x160626ab0>,
#   <mgclient.Node(id=24193, labels={'hr'}, properties={'name': 'DISP_Discussion.md_None'}) at 0x109365e00>),
#  (<mgclient.Node(id=21858, labels={'File'}, properties={'name': 'DISP_Discussion.md'}) at 0x1093678d0>,
#   <mgclient.Relationship(start_id=21858, end_id=21861, type='CONTAINS', properties={}) at 0x160626e30>,
#   <mgclient.Node(id=21861, labels={'h1'}, properties={'name': 'DISP_Discussion.md_DISP Project Discussion'}) at 0x109367270>),
#  (<mgclient.Node(id=21858, labels={'File'}, properties={'name': 'DISP_Discussion.md'}) at 0x109367c60>,
#   <mgclient.Relationship(start_id=21858, end_id=24195, type='CONTAINS', properties={}) at 0x160626af0>,
#   <mgclient.Node(id=24195, labels={'h1'}, properties={'name': 'DISP_Discussion.md_DISP Project Discussion'}) at 0x109365da0>),
#  (<mgclient.Node(id=21858, labels={'File'}, properties={'name': 'DISP_Discussion.md'}) at 0x109367150>,
#   <mgclient.Relationship(start_id=21858, end_id=26507, type='CONTAINS', properties={}) at 0x1612089b0>,
#   <mgclient.Node(id=26507, labels={'h1'}, properties={'name': 'DISP_Discussion.md_DISP Project Discussion'}) at 0x109367900>),
#  (<mgclient.Node(id=21862, labels={'File'}, properties={'name': 'GCP_Data_Engineer_Exam_Prep_Notes.md'}) at 0x109365fe0>,
#   <mgclient.Relationship(start_id=21862, end_id=21863, type='CONTAINS', properties={}) at 0x177acbbf0>,
#   <mgclient.Node(id=21863, labels={'hr'}, properties={'name': 'GCP_Data_Engineer_Exam_Prep_Notes.md_None'}) at 0x109365050>),
#  (<mgclient.Node(id=21862, labels={'File'}, properties={'name': 'GCP_Data_Engineer_Exam_Prep_Notes.md'}) at 0x1093650e0>,
#   <mgclient.Relationship(start_id=21862, end_id=21864, type='CONTAINS', properties={}) at 0x177b7f8b0>,
#   <mgclient.Node(id=21864, labels={'hr'}, properties={'name': 'GCP_Data_Engineer_Exam_Prep_Notes.md_None'}) at 0x109367360>),
#  (<mgclient.Node(id=21862, labels={'File'}, properties={'name': 'GCP_Data_Engineer_Exam_Prep_Notes.md'}) at 0x109367fc0>,
#   <mgclient.Relationship(start_id=21862, end_id=24197, type='CONTAINS', properties={}) at 0x177b7c730>,
#   <mgclient.Node(id=24197, labels={'hr'}, properties={'name': 'GCP_Data_Engineer_Exam_Prep_Notes.md_None'}) at 0x109367f60>),
#  (<mgclient.Node(id=21865, labels={'File'}, properties={'name': '2023-07-20_CD-CD-Status.md'}) at 0x109367720>,
#   <mgclient.Relationship(start_id=21865, end_id=21866, type='CONTAINS', properties={}) at 0x177b7c9b0>,
#   <mgclient.Node(id=21866, labels={'hr'}, properties={'name': '2023-07-20_CD-CD-Status.md_None'}) at 0x109365e30>),
#  (<mgclient.Node(id=21865, labels={'File'}, properties={'name': '2023-07-20_CD-CD-Status.md'}) at 0x109364780>,
#   <mgclient.Relationship(start_id=21865, end_id=21867, type='CONTAINS', properties={}) at 0x177b7f2b0>,
#   <mgclient.Node(id=21867, labels={'hr'}, properties={'name': '2023-07-20_CD-CD-Status.md_None'}) at 0x109367870>),
#  (<mgclient.Node(id=21865, labels={'File'}, properties={'name': '2023-07-20_CD-CD-Status.md'}) at 0x109365890>,
#   <mgclient.Relationship(start_id=21865, end_id=21868, type='CONTAINS', properties={}) at 0x177b7ddb0>,
#   <mgclient.Node(id=21868, labels={'hr'}, properties={'name': '2023-07-20_CD-CD-Status.md_None'}) at 0x109365530>),
#  (<mgclient.Node(id=21865, labels={'File'}, properties={'name': '2023-07-20_CD-CD-Status.md'}) at 0x1093647e0>,
#   <mgclient.Relationship(start_id=21865, end_id=24200, type='CONTAINS', properties={}) at 0x177b7fa70>,
#   <mgclient.Node(id=24200, labels={'hr'}, properties={'name': '2023-07-20_CD-CD-Status.md_None'}) at 0x109365f50>),
#  (<mgclient.Node(id=21865, labels={'File'}, properties={'name': '2023-07-20_CD-CD-Status.md'}) at 0x1093657a0>,
#   <mgclient.Relationship(start_id=21865, end_id=21869, type='CONTAINS', properties={}) at 0x177b7c2b0>,
#   <mgclient.Node(id=21869, labels={'h1'}, properties={'name': '2023-07-20_CD-CD-Status.md_status cd-ci'}) at 0x1093656b0>),
#  (<mgclient.Node(id=21865, labels={'File'}, properties={'name': '2023-07-20_CD-CD-Status.md'}) at 0x109365290>,
#   <mgclient.Relationship(start_id=21865, end_id=24203, type='CONTAINS', properties={}) at 0x1713c4a70>,
#   <mgclient.Node(id=24203, labels={'h1'}, properties={'name': '2023-07-20_CD-CD-Status.md_status cd-ci'}) at 0x1093660a0>),
#  (<mgclient.Node(id=21865, labels={'File'}, properties={'name': '2023-07-20_CD-CD-Status.md'}) at 0x1093657d0>,
#   <mgclient.Relationship(start_id=21865, end_id=26510, type='CONTAINS', properties={}) at 0x1713c6630>,
#   <mgclient.Node(id=26510, labels={'h1'}, properties={'name': '2023-07-20_CD-CD-Status.md_status cd-ci'}) at 0x109367b40>),
#  (<mgclient.Node(id=21871, labels={'File'}, properties={'name': 'Dashboard_Studio_Changes.md'}) at 0x109367e10>,
#   <mgclient.Relationship(start_id=21871, end_id=21872, type='CONTAINS', properties={}) at 0x17159c170>,
#   <mgclient.Node(id=21872, labels={'hr'}, properties={'name': 'Dashboard_Studio_Changes.md_None'}) at 0x109367e40>),
#  (<mgclient.Node(id=21871, labels={'File'}, properties={'name': 'Dashboard_Studio_Changes.md'}) at 0x109364ff0>,
#   <mgclient.Relationship(start_id=21871, end_id=21873, type='CONTAINS', properties={}) at 0x17159d7b0>,
#   <mgclient.Node(id=21873, labels={'hr'}, properties={'name': 'Dashboard_Studio_Changes.md_None'}) at 0x109367990>),
#  (<mgclient.Node(id=21871, labels={'File'}, properties={'name': 'Dashboard_Studio_Changes.md'}) at 0x109367de0>,
#   <mgclient.Relationship(start_id=21871, end_id=24206, type='CONTAINS', properties={}) at 0x17159feb0>,
#   <mgclient.Node(id=24206, labels={'hr'}, properties={'name': 'Dashboard_Studio_Changes.md_None'}) at 0x109367cf0>),
#  (<mgclient.Node(id=21871, labels={'File'}, properties={'name': 'Dashboard_Studio_Changes.md'}) at 0x109367f00>,
#   <mgclient.Relationship(start_id=21871, end_id=21874, type='CONTAINS', properties={}) at 0x17159cdf0>,
#   <mgclient.Node(id=21874, labels={'h1'}, properties={'name': 'Dashboard_Studio_Changes.md_process-docs'}) at 0x109367f30>),
#  (<mgclient.Node(id=21871, labels={'File'}, properties={'name': 'Dashboard_Studio_Changes.md'}) at 0x1093650b0>,
#   <mgclient.Relationship(start_id=21871, end_id=24208, type='CONTAINS', properties={}) at 0x17159cab0>,
#   <mgclient.Node(id=24208, labels={'h1'}, properties={'name': 'Dashboard_Studio_Changes.md_process-docs'}) at 0x109367d80>),
#  (<mgclient.Node(id=21871, labels={'File'}, properties={'name': 'Dashboard_Studio_Changes.md'}) at 0x1093678a0>,
#   <mgclient.Relationship(start_id=21871, end_id=26513, type='CONTAINS', properties={}) at 0x17159ee70>,
#   <mgclient.Node(id=26513, labels={'h1'}, properties={'name': 'Dashboard_Studio_Changes.md_process-docs'}) at 0x1093660d0>),
#  (<mgclient.Node(id=21877, labels={'File'}, properties={'name': 'osquery_internal_documentation.md'}) at 0x109365080>,
#   <mgclient.Relationship(start_id=21877, end_id=21878, type='CONTAINS', properties={}) at 0x17159fe30>,
#   <mgclient.Node(id=21878, labels={'hr'}, properties={'name': 'osquery_internal_documentation.md_None'}) at 0x1093674e0>),
#  (<mgclient.Node(id=21877, labels={'File'}, properties={'name': 'osquery_internal_documentation.md'}) at 0x109367b10>,
#   <mgclient.Relationship(start_id=21877, end_id=21879, type='CONTAINS', properties={}) at 0x1715cc7f0>,
#   <mgclient.Node(id=21879, labels={'hr'}, properties={'name': 'osquery_internal_documentation.md_None'}) at 0x109365800>),
#  (<mgclient.Node(id=21877, labels={'File'}, properties={'name': 'osquery_internal_documentation.md'}) at 0x109364f90>,
#   <mgclient.Relationship(start_id=21877, end_id=24212, type='CONTAINS', properties={}) at 0x160648b30>,
#   <mgclient.Node(id=24212, labels={'hr'}, properties={'name': 'osquery_internal_documentation.md_None'}) at 0x1093670c0>),
#  (<mgclient.Node(id=21877, labels={'File'}, properties={'name': 'osquery_internal_documentation.md'}) at 0x109364f30>,
#   <mgclient.Relationship(start_id=21877, end_id=21880, type='CONTAINS', properties={}) at 0x160648e70>,
#   <mgclient.Node(id=21880, labels={'h1'}, properties={'name': 'osquery_internal_documentation.md_process-docs'}) at 0x109364180>),
#  (<mgclient.Node(id=21877, labels={'File'}, properties={'name': 'osquery_internal_documentation.md'}) at 0x109365e60>,
#   <mgclient.Relationship(start_id=21877, end_id=24214, type='CONTAINS', properties={}) at 0x16064b470>,
#   <mgclient.Node(id=24214, labels={'h1'}, properties={'name': 'osquery_internal_documentation.md_process-docs'}) at 0x109367570>),
#  (<mgclient.Node(id=21877, labels={'File'}, properties={'name': 'osquery_internal_documentation.md'}) at 0x109365410>,
#   <mgclient.Relationship(start_id=21877, end_id=26517, type='CONTAINS', properties={}) at 0x160649cb0>,
#   <mgclient.Node(id=26517, labels={'h1'}, properties={'name': 'osquery_internal_documentation.md_process-docs'}) at 0x109367ae0>),
#  (<mgclient.Node(id=21887, labels={'File'}, properties={'name': 'Zoom Executive Summary Report.md'}) at 0x109365f80>,
#   <mgclient.Relationship(start_id=21887, end_id=21888, type='CONTAINS', properties={}) at 0x160648e30>,
#   <mgclient.Node(id=21888, labels={'hr'}, properties={'name': 'Zoom Executive Summary Report.md_None'}) at 0x1093656e0>),
#  (<mgclient.Node(id=21887, labels={'File'}, properties={'name': 'Zoom Executive Summary Report.md'}) at 0x109366130>,
#   <mgclient.Relationship(start_id=21887, end_id=21889, type='CONTAINS', properties={}) at 0x16064ba30>,
#   <mgclient.Node(id=21889, labels={'hr'}, properties={'name': 'Zoom Executive Summary Report.md_None'}) at 0x109365710>),
#  (<mgclient.Node(id=21887, labels={'File'}, properties={'name': 'Zoom Executive Summary Report.md'}) at 0x109365fb0>,
#   <mgclient.Relationship(start_id=21887, end_id=24222, type='CONTAINS', properties={}) at 0x16064a770>,
#   <mgclient.Node(id=24222, labels={'hr'}, properties={'name': 'Zoom Executive Summary Report.md_None'}) at 0x1093672d0>),
#  (<mgclient.Node(id=21887, labels={'File'}, properties={'name': 'Zoom Executive Summary Report.md'}) at 0x109367390>,
#   <mgclient.Relationship(start_id=21887, end_id=21890, type='CONTAINS', properties={}) at 0x160648570>,
#   <mgclient.Node(id=21890, labels={'h1'}, properties={'name': 'Zoom Executive Summary Report.md_Creating Zoom Summary Report'}) at 0x1716f9140>),
#  (<mgclient.Node(id=21887, labels={'File'}, properties={'name': 'Zoom Executive Summary Report.md'}) at 0x1716fbe40>,
#   <mgclient.Relationship(start_id=21887, end_id=24224, type='CONTAINS', properties={}) at 0x16064ad70>,
#   <mgclient.Node(id=24224, labels={'h1'}, properties={'name': 'Zoom Executive Summary Report.md_Creating Zoom Summary Report'}) at 0x1716fb0f0>),
#  (<mgclient.Node(id=21887, labels={'File'}, properties={'name': 'Zoom Executive Summary Report.md'}) at 0x1716fb300>,
#   <mgclient.Relationship(start_id=21887, end_id=26525, type='CONTAINS', properties={}) at 0x160649830>,
#   <mgclient.Node(id=26525, labels={'h1'}, properties={'name': 'Zoom Executive Summary Report.md_Creating Zoom Summary Report'}) at 0x1606a7f30>),
#  (<mgclient.Node(id=21895, labels={'File'}, properties={'name': 'Zoom- Splunk RZ Lookup List.md'}) at 0x1606a4240>,
#   <mgclient.Relationship(start_id=21895, end_id=21896, type='CONTAINS', properties={}) at 0x161192eb0>,
#   <mgclient.Node(id=21896, labels={'hr'}, properties={'name': 'Zoom- Splunk RZ Lookup List.md_None'}) at 0x1606a5710>),
#  (<mgclient.Node(id=21895, labels={'File'}, properties={'name': 'Zoom- Splunk RZ Lookup List.md'}) at 0x1606a4810>,
#   <mgclient.Relationship(start_id=21895, end_id=21897, type='CONTAINS', properties={}) at 0x1611d1530>,
#   <mgclient.Node(id=21897, labels={'hr'}, properties={'name': 'Zoom- Splunk RZ Lookup List.md_None'}) at 0x1606a5ef0>),
#  (<mgclient.Node(id=21895, labels={'File'}, properties={'name': 'Zoom- Splunk RZ Lookup List.md'}) at 0x1606a6040>,
#   <mgclient.Relationship(start_id=21895, end_id=24230, type='CONTAINS', properties={}) at 0x177c5d9f0>,
#   <mgclient.Node(id=24230, labels={'hr'}, properties={'name': 'Zoom- Splunk RZ Lookup List.md_None'}) at 0x1606a46c0>),
#  (<mgclient.Node(id=21898, labels={'File'}, properties={'name': 'Terminator Tests.md'}) at 0x1606a51a0>,
#   <mgclient.Relationship(start_id=21898, end_id=21899, type='CONTAINS', properties={}) at 0x177c5fbb0>,
#   <mgclient.Node(id=21899, labels={'h1'}, properties={'name': 'Terminator Tests.md_GitLab Issues'}) at 0x1606a7870>),
#  (<mgclient.Node(id=21898, labels={'File'}, properties={'name': 'Terminator Tests.md'}) at 0x1606a5230>,
#   <mgclient.Relationship(start_id=21898, end_id=24233, type='CONTAINS', properties={}) at 0x177d963f0>,
#   <mgclient.Node(id=24233, labels={'h1'}, properties={'name': 'Terminator Tests.md_GitLab Issues'}) at 0x1606a4f60>),
#  (<mgclient.Node(id=21898, labels={'File'}, properties={'name': 'Terminator Tests.md'}) at 0x1606a4cc0>,
#   <mgclient.Relationship(start_id=21898, end_id=21899, type='CONTAINS', properties={}) at 0x177d96230>,
#   <mgclient.Node(id=21899, labels={'h1'}, properties={'name': 'Terminator Tests.md_GitLab Issues'}) at 0x1606a7540>),
#  (<mgclient.Node(id=21898, labels={'File'}, properties={'name': 'Terminator Tests.md'}) at 0x1606a7720>,
#   <mgclient.Relationship(start_id=21898, end_id=24233, type='CONTAINS', properties={}) at 0x177d973b0>,
#   <mgclient.Node(id=24233, labels={'h1'}, properties={'name': 'Terminator Tests.md_GitLab Issues'}) at 0x1606a7f60>)]

# %%
import memgraph

class MemgraphManager:
    def __init__(self, host='127.0.0.1', port=7687):
        self.connection = memgraph.connect(host=host, port=port)

    def execute_query(self, query):
        try:
            cursor = self.connection.cursor()
            cursor.execute(query)
            results = cursor.fetchall()
            cursor.close()
            return results
        except memgraph.DatabaseError as e:
            print(f"Failed to execute query: {e}")
            raise e

    def execute_and_fetch(self, query, params=None):
        try:
            cursor = self.connection.cursor()
            cursor.execute(query, params)
            results = cursor.fetchall()
            cursor.close()
            return results
        except memgraph.DatabaseError as e:
            print(f"Failed to execute query: {e}")
            raise e

    def find_duplicates(self):
        query = """
        MATCH (n:File)
        WITH n.name AS name, COUNT(n) AS count
        WHERE count > 1
        RETURN name, count
        """
        return self.execute_query(query)

    def merge_nodes(self, name):
        merge_query = f"""
        MATCH (n:File {{name: '{name}'}})
        WITH COLLECT(n) AS nodes
        CALL {{
            WITH nodes
            UNWIND nodes AS n
            WITH n LIMIT 1
            RETURN n
        }} AS kept_node
        WITH nodes, kept_node.n AS to_keep
        UNWIND nodes AS n
        WITH n, to_keep WHERE n <> to_keep
        OPTIONAL MATCH (n)-[r]-()
        DELETE r
        DETACH DELETE n
        RETURN to_keep
        """
        self.execute_query(merge_query)

    def merge_duplicates(self):
        duplicates = self.find_duplicates()
        for name, _ in duplicates:
            self.merge_nodes(name)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[130], line 1
# ----> 1 import memgraph
#       3 class MemgraphManager:
#       4     def __init__(self, host='127.0.0.1', port=7687):
#
# ModuleNotFoundError: No module named 'memgraph'

# %% [markdown]
# ### The `Constants` Class

# %%
# Load environment variables from .env file
from dotenv import load_dotenv
load_dotenv()

# Set constants for LangChain from environment variables
class Constants:
    LLM_MODEL_TEMPERATURE = float(os.getenv("LLM_MODEL_TEMPERATURE"))
    OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")
    LLM_MODEL_NAME = os.getenv("LLM_MODEL_NAME")


constants = Constants()

# %% [markdown]
# ### The `CollectionManager` Class

# %%
class CollectionManager:
    def __init__(self, directory, memgraph):
        self.directory = directory
        self.memgraph = memgraph
        self.query_handler = CypherQueryHandler()

    def extract_links(self, content):
        """Extracts links from the content of a Markdown file."""
        links = re.findall(r'\[\[([^\]]+)\]\]', content)  # Matches [[Link]]
        return links

    def parse_markdown(self, content):
        """Parses Markdown content to extract headings and their hierarchy."""
        headings = []
        lines = content.split('\n')
        for line in lines:
            match = re.match(r'^(#+)\s+(.*)', line)
            if match:
                level = len(match.group(1))
                text = match.group(2)
                headings.append((level, text))
        return headings

    def create_nodes_and_edges(self, file_name, content):
        """Creates nodes and edges in MemGraph based on the Markdown content."""
        headings = self.parse_markdown(content)
        links = self.extract_links(content)

        # Create a top-level node for the file
        query = """
        MERGE (n:File {name: $name})
        ON CREATE SET n.content = $content
        """
        params = {"name": file_name, "content": content}
        self.memgraph.execute_and_fetch(query, params)

        last_nodes = {0: file_name}  # To keep track of last nodes at each heading level
        for level, text in headings:
            node_name = f"{file_name}::{text}"
            query = """
            MERGE (n:Heading {name: $name, level: $level, text: $text})
            """
            params = {"name": node_name, "level": level, "text": text}
            self.memgraph.execute_and_fetch(query, params)

            # Create an edge from the last node of the previous level to this node
            parent_node = last_nodes[level - 1]
            query = """
            MATCH (p {name: $parent_name}), (c {name: $child_name})
            MERGE (p)-[:CONTAINS]->(c)
            """
            params = {"parent_name": parent_node, "child_name": node_name}
            self.memgraph.execute_and_fetch(query, params)

            last_nodes[level] = node_name

        # Create edges to linked files
        for link in links:
            query = """
            MATCH (a:File {name: $file_name}), (b:File {name: $link_name})
            MERGE (a)-[:LINKS_TO]->(b)
            """
            params = {"file_name": file_name, "link_name": link}
            self.memgraph.execute_and_fetch(query, params)

    def process_file(self, file_path):
        """Process a single Markdown file and store in MemGraph."""
        try:
            with open(file_path, 'r', encoding='utf-8') as md_file:
                content = md_file.read()
                file_name = os.path.basename(file_path).replace('.md', '')
                print(f"Processing file: {file_path}")
                self.create_nodes_and_edges(file_name, content)
        except Exception as e:
            print(f"Error reading {file_path}: {e}")

    def process_directory(self):
        """Walk through the directory and process each Markdown file."""
        for root, _, files in os.walk(self.directory):
            for file in files:
                if file.endswith('.md'):
                    file_path = os.path.join(root, file)
                    self.process_file(file_path)
    
    def merge_duplicates(self):
        queries = [
            """
            MATCH (n)
            WITH n.name AS name, collect(n) AS nodes
            WHERE size(nodes) > 1
            CALL apoc.refactor.mergeNodes(nodes) YIELD node
            RETURN node
            """,
            """
            MATCH (n)-[r]->(m)
            WHERE n IS NULL OR m IS NULL
            DELETE r
            """
        ]

        for query in queries:
            self.execute_query(query)

# %% [markdown]
# ### The `CypherQueryHandler` Class

# %%
from typing import List

class CypherQueryHandler:

    @staticmethod
    def get_check_if_db_empty_query() -> str:
        return ("MATCH (n) "
                "RETURN count(n) AS nodes")

    @staticmethod
    def get_export_for_repo_path_query(repo_path: str) -> str:
        return (f"MATCH p=(n {{ repo_path: '{repo_path}' }})-[r]->(m {{ repo_path: '{repo_path}' }}) "
                "WITH project(p) AS repo_specific_subgraph "
                "RETURN repo_specific_subgraph")

    @staticmethod
    def get_export_for_file_path_query(file_path: str) -> str:
        return (f"MATCH p=(n {{ file_path: '{file_path}' }})-[r]->(m {{ file_path: '{file_path}' }}) "
                "WITH project(p) AS file_specific_subgraph "
                "RETURN file_specific_subgraph")

    @staticmethod
    def get_delete_all_query() -> str:
        return ("MATCH (n) "
                "DETACH DELETE n")

    @staticmethod
    def get_delete_all_for_repo_query(repo_path: str) -> str:
        return (f"MATCH (n) "
                f"WHERE n.repo_path = '{repo_path}' "
                "DETACH DELETE n")

    @staticmethod
    def get_delete_graph_for_file_query(file_path: str) -> str:
        return (f"MATCH (n) "
                f"WHERE n.file_path = '{file_path}' "
                "DETACH DELETE n")

    @staticmethod
    def get_rename_file_query(old_file_path: str, new_file_path: str) -> str:
        return (f"MATCH (n) "
                f"WHERE n.file_path = '{old_file_path}' "
                f"SET n.file_path = '{new_file_path}'")

    @staticmethod
    def get_strings_to_embed_query(file_path: str) -> str:
        return (f"MATCH (n) "
                f"OPTIONAL MATCH (n)-[r]->(m) "
                f"WHERE n.file_path = '{file_path}' "
                "RETURN ID(n) as Node_ID, "
                "n.name as Node_Name, "
                "labels(n)[0] as Node_Type, "
                "collect({Neighbour_Name: m.name, Neighbour_Type: labels(m)[0], Relationship_Type: type(r)}) as Connections")

    @staticmethod
    def get_node_description_query(node_id: int) -> str:
        return (f"MATCH (n) "
                f"WHERE ID(n) = {node_id} "
                "OPTIONAL MATCH (n)-[r1]->(m) "
                "OPTIONAL MATCH (p)-[r2]->(n) "
                "RETURN ID(n) as Node_ID, "
                "n.name as Node_Name, "
                "labels(n)[0] as Node_Type, "
                "collect({ Neighbour_Name: m.name, Neighbour_Type: labels(m)[0], Relationship_Type: type(r1) }) as In_Connections, "
                "collect({ Neighbour_Name: p.name, Neighbour_Type: labels(p)[0], Relationship_Type: type(r2) }) as Out_Connections")

    @staticmethod
    def get_set_embeddings_query(node_id: int, embeddings: List[float]) -> str:
        return (f"MATCH (n) "
                f"WHERE ID(n) = {node_id} "
                f"SET n.embeddings = {embeddings}")

    @staticmethod
    def get_tmp_create_query(embeddings: List[float]) -> str:
        return (f"MATCH (n) "
                "WITH count(n) as N "
                "UNWIND range(1, N) as id "
                f"CREATE (:Temp {{name: 'temp_'+id, embeddings: {embeddings}}})")

    @staticmethod
    def get_tmp_delete_query() -> str:
        return ("MATCH (n:Temp) "
                "DETACH DELETE n")

    @staticmethod
    def get_schema_for_repo_query(repo_path: str) -> str:
        return (f"MATCH p=(n {{ repo_path: '{repo_path}' }})-[r]->(m {{ repo_path: '{repo_path}' }}) "
                "WITH project(p) AS repo_specific_subgraph "
                "CALL llm_util.schema(repo_specific_subgraph, 'prompt_ready') "
                "YIELD schema "
                "RETURN schema")

    @staticmethod
    def get_vector_search_query() -> str:
        return ("MATCH (m) "
                "WHERE (NOT m.name STARTS WITH 'temp') OR (m.name IS NULL) "
                "WITH COLLECT(m) as nodes "
                "MATCH (tmp) "
                "WHERE tmp.name STARTS WITH 'temp' "
                "WITH COLLECT(tmp) as temps, nodes "
                "CALL node_similarity.cosine_pairwise('embeddings', nodes, temps) YIELD node1, node2, similarity as cosine_similarity "
                "RETURN ID(node1), cosine_similarity "
                "ORDER BY cosine_similarity DESC "
                "LIMIT 3")

    @staticmethod
    def get_embeddings_for_node_query(node_id: int) -> str:
        return (f"MATCH (m) "
                f"WHERE ID(m) = {node_id} "
                "RETURN m.embeddings as embeddings")

# %% [markdown]
# ### The `VaultManager` Class

# %%
class VaultManager:
    def __init__(self, directory: str, memgraph):
        self.collection_manager = CollectionManager(directory, memgraph)
        self.memgraph = memgraph
        self.query_handler = CypherQueryHandler()

    def update_vault(self):
        """Updates the entire vault by processing all Markdown files."""
        print("Updating vault...")
        self.collection_manager.process_directory()
        print("Vault update complete.")

    def clear_repo(self, repo_path: str):
        """Clears all data related to a specific repository."""
        print(f"Clearing repository: {repo_path}...")
        query = self.query_handler.get_delete_all_for_repo_query(repo_path)
        self.memgraph.execute(query)
        print(f"Repository {repo_path} cleared.")

    def clear_file(self, file_path: str):
        """Clears all data related to a specific file."""
        print(f"Clearing file: {file_path}...")
        query = self.query_handler.get_delete_graph_for_file_query(file_path)
        self.memgraph.execute(query)
        print(f"File {file_path} cleared.")

    def rename_file(self, old_file_path: str, new_file_path: str):
        """Renames a file in the vault."""
        print(f"Renaming file from {old_file_path} to {new_file_path}...")
        query = self.query_handler.get_rename_file_query(old_file_path, new_file_path)
        self.memgraph.execute(query)
        print(f"File renamed from {old_file_path} to {new_file_path}.")

    def export_repo(self, repo_path: str):
        """Exports the data for a specific repository."""
        print(f"Exporting repository: {repo_path}...")
        query = self.query_handler.get_export_for_repo_path_query(repo_path)
        result = self.memgraph.execute(query)
        print(f"Repository {repo_path} exported.")
        return result

    def export_file(self, file_path: str):
        """Exports the data for a specific file."""
        print(f"Exporting file: {file_path}...")
        query = self.query_handler.get_export_for_file_path_query(file_path)
        result = self.memgraph.execute(query)
        print(f"File {file_path} exported.")
        return result

    def get_schema_for_repo(self, repo_path: str):
        """Gets the schema for a specific repository."""
        print(f"Getting schema for repository: {repo_path}...")
        query = self.query_handler.get_schema_for_repo_query(repo_path)
        result = self.memgraph.execute(query)
        print(f"Schema for repository {repo_path} obtained.")
        return result

# %% [markdown]
# ### The `GeneralQueryAgent` Class

# %%
class GeneralQueryAgent:
    def __init__(self, repo_path: str, tools: List[Tool]) -> None:
        self.repo_path = repo_path
        self.system_message = ''
        self._init_system_message()

        self.llm = ChatOpenAI(
            temperature=constants.LLM_MODEL_TEMPERATURE,
            openai_api_key=constants.OPENAI_API_KEY,
            model_name=constants.LLM_MODEL_NAME
        )

        self.agent_kwargs = {
            "extra_prompt_messages": [MessagesPlaceholder(variable_name="memory")],
            "system_message": self.system_message,
        }

        self.memory = ConversationBufferMemory(memory_key="memory", return_messages=True)

        self.run_cypher_query = Tool.from_function(
            func=MemgraphManager.select_query_tool,
            name="run_cypher_query",
            description="""Useful when you want to run Cypher queries on the knowledge graph. 
                            Note that the input has to be valid Cypher. Consult the graph schema in order to know how to write correct queries. 
                            Pay attention to the repo_path attribute.
                            Returns results of executing the query."""
        )

        self.tools = tools + [self.run_cypher_query]
        self._init_agent(self.tools)

    def _init_agent(self, tools: List[Tool]) -> None:
        self.agent = initialize_agent(
            tools,
            self.llm,
            agent=AgentType.OPENAI_FUNCTIONS,
            verbose=True,
            agent_kwargs=self.agent_kwargs,
            memory=self.memory
        )

    def _init_system_message(self) -> None:
        # Define the path to your prompt file explicitly
        prompt_name = 'system_message_query'
        prompt_path = Path('./core/knowledgebase/prompts') / prompt_name
        prompt_text = prompt_path.read_text()
        prompt_template = PromptTemplate.from_template(prompt_text)

        mm = MemgraphManager()
        schema = mm.get_schema_for_repo(self.repo_path)
        self.system_message = SystemMessage(
            content=prompt_template.format(schema=schema, repo_path=self.repo_path)
        )

    def ask(self, question: str) -> str:
        return self.agent.run(question)

# %% [markdown]
# # Testing Our Config

# %% [markdown]
# Now that we have all our components in place, we can test our configuration.

# %%
import os

# Assuming the following imports from previous code:
# from your_module import MemgraphManager, CollectionManager

# Define the directory path to your Obsidian vault for testing
test_vault_directory = '/Users/dcarmocan/Projects/mind-cave'

# Initialize MemgraphManager
memgraph_manager = MemgraphManager()

# Initialize CollectionManager with the test directory and MemgraphManager
collection_manager = CollectionManager(test_vault_directory, memgraph_manager)

# Perform a test by processing the directory
print("Processing the test Obsidian vault directory...")
collection_manager.process_directory()
print("Processing complete.")

# Optionally, you can run additional checks or queries to validate the results
# For example, you can print some nodes and relationships from the database to verify

# Print some nodes
print("Some nodes in the database:")
nodes_query = "MATCH (n) RETURN n LIMIT 10"
nodes_result = memgraph_manager.execute_query(nodes_query)
for node in nodes_result:
    print(node)

# Print some relationships
print("Some relationships in the database:")
relationships_query = "MATCH (n)-[r]->(m) RETURN n, r, m LIMIT 10"
relationships_result = memgraph_manager.execute_query(relationships_query)
for relationship in relationships_result:
    print(relationship)
# Out:
# Processing the test Obsidian vault directory...
# Processing file: /Users/dcarmocan/Projects/mind-cave/SPOG.md
# Error reading /Users/dcarmocan/Projects/mind-cave/SPOG.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Zoom Dashboard Documentation.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Zoom Dashboard Documentation.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Summary Week - 20230915.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Summary Week - 20230915.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Project Plan Template.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Project Plan Template.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Cap_Planning_Article.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Cap_Planning_Article.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Terminator_Doc.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Terminator_Doc.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/SMART_GOALS_Format.md
# Error reading /Users/dcarmocan/Projects/mind-cave/SMART_GOALS_Format.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Cap_planning_notes.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Cap_planning_notes.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/slack_tasks.md
# Error reading /Users/dcarmocan/Projects/mind-cave/slack_tasks.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/DISP_Discussion.md
# Error reading /Users/dcarmocan/Projects/mind-cave/DISP_Discussion.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/GCP_Data_Engineer_Exam_Prep_Notes.md
# Error reading /Users/dcarmocan/Projects/mind-cave/GCP_Data_Engineer_Exam_Prep_Notes.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/2023-07-20_CD-CD-Status.md
# Error reading /Users/dcarmocan/Projects/mind-cave/2023-07-20_CD-CD-Status.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Dashboard_Studio_Changes.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Dashboard_Studio_Changes.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/osquery_internal_documentation.md
# Error reading /Users/dcarmocan/Projects/mind-cave/osquery_internal_documentation.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Zoom Executive Summary Report.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Zoom Executive Summary Report.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Untitled.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Untitled.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Slack_RZ_Requests.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Slack_RZ_Requests.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Zoom- Splunk RZ Lookup List.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Zoom- Splunk RZ Lookup List.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Terminator Tests.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Terminator Tests.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Zoom_API_Access.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Zoom_API_Access.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/SPL Queries.md
# Error reading /Users/dcarmocan/Projects/mind-cave/SPL Queries.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Splunk DataViz.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Splunk DataViz.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/status_report_20230717.md
# Error reading /Users/dcarmocan/Projects/mind-cave/status_report_20230717.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/DISP Tasks - Create Shared Mailbox.md
# Error reading /Users/dcarmocan/Projects/mind-cave/DISP Tasks - Create Shared Mailbox.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/SPOG_Gmail.md
# Error reading /Users/dcarmocan/Projects/mind-cave/SPOG_Gmail.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/SignalFX_RC_App_Manifrest.md
# Error reading /Users/dcarmocan/Projects/mind-cave/SignalFX_RC_App_Manifrest.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Blurbs.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Blurbs.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Home.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Home.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/GCP_VS_AWS.md
# Error reading /Users/dcarmocan/Projects/mind-cave/GCP_VS_AWS.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Design Plans.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Design Plans.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Valimail_Subdomain_Request.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Valimail_Subdomain_Request.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Templating.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Templating.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Splunk_Dashboards_References.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Splunk_Dashboards_References.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Zoom.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Zoom.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/fix_slack_channel_mapping.md
# Error reading /Users/dcarmocan/Projects/mind-cave/fix_slack_channel_mapping.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/SPL_Conditional_Chart.md
# Error reading /Users/dcarmocan/Projects/mind-cave/SPL_Conditional_Chart.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Cisco_ESA_Settings_Mapping.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Cisco_ESA_Settings_Mapping.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/kb_template.md
# Error reading /Users/dcarmocan/Projects/mind-cave/kb_template.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/GitLab_Terminator_Template.md
# Error reading /Users/dcarmocan/Projects/mind-cave/GitLab_Terminator_Template.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/SPL_makeresults.md
# Error reading /Users/dcarmocan/Projects/mind-cave/SPL_makeresults.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/BRAT-log.md
# Error reading /Users/dcarmocan/Projects/mind-cave/BRAT-log.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/OSQUERY.md
# Error reading /Users/dcarmocan/Projects/mind-cave/OSQUERY.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/New Sprint Story Points.md
# Error reading /Users/dcarmocan/Projects/mind-cave/New Sprint Story Points.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/GitLab_Pipelines.md
# Error reading /Users/dcarmocan/Projects/mind-cave/GitLab_Pipelines.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Coding_exercises.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Coding_exercises.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/.md
# Error reading /Users/dcarmocan/Projects/mind-cave/.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Summ-Test.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Summ-Test.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Collaboration_Services_Documentation.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Collaboration_Services_Documentation.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/SplunkDev.md
# Error reading /Users/dcarmocan/Projects/mind-cave/SplunkDev.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/GitLab Templates V2.md
# Error reading /Users/dcarmocan/Projects/mind-cave/GitLab Templates V2.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Terminator_Tasks.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Terminator_Tasks.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/SNOW Blurbs.md
# Error reading /Users/dcarmocan/Projects/mind-cave/SNOW Blurbs.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Zoom Dasboard Links.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Zoom Dasboard Links.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/SPOG_Brainstorming.md
# Error reading /Users/dcarmocan/Projects/mind-cave/SPOG_Brainstorming.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Personal/Tasks/SNOW_API_Gateway_Documentation.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Personal/Tasks/SNOW_API_Gateway_Documentation.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Personal/Tasks/Tasks.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Personal/Tasks/Tasks.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Personal/Tasks/JiraREST_mapping.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Personal/Tasks/JiraREST_mapping.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Personal/Tasks/Postfix.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Personal/Tasks/Postfix.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Personal/Tasks/Kiteworks_Form.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Personal/Tasks/Kiteworks_Form.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Personal/Training/Career Dev - Job Family Matrix.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Personal/Training/Career Dev - Job Family Matrix.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Personal/Training/docker_training.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Personal/Training/docker_training.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Tasks/osquery_project.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Tasks/osquery_project.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Tasks/2023-01-30.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Tasks/2023-01-30.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Tasks/2023-10-06.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Tasks/2023-10-06.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Tasks/2023-11-08.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Tasks/2023-11-08.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Tasks/2023-08-18.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Tasks/2023-08-18.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Tasks/2023-03-20.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Tasks/2023-03-20.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Tasks/2023-01-11.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Tasks/2023-01-11.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Tasks/2023-11-09.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Tasks/2023-11-09.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Tasks/Zoom_SPL_Queries.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Tasks/Zoom_SPL_Queries.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Tasks/SPOG_VDI.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Tasks/SPOG_VDI.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Tasks/2023-09-13.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Tasks/2023-09-13.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Tasks/2022-12-12 1.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Tasks/2022-12-12 1.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Tasks/2022-12-07.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Tasks/2022-12-07.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Tasks/2023-01-31.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Tasks/2023-01-31.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Tasks/2023-09-18.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Tasks/2023-09-18.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Tasks/2023-11-06.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Tasks/2023-11-06.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Tasks/2023-06-05.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Tasks/2023-06-05.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Tasks/2023-09-08.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Tasks/2023-09-08.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Tasks/2023-09-28.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Tasks/2023-09-28.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Tasks/2023-02-24.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Tasks/2023-02-24.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Tasks/Zoom_Tasks.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Tasks/Zoom_Tasks.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Tasks/2023-11-13.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Tasks/2023-11-13.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Tasks/2023-03-28.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Tasks/2023-03-28.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Tasks/2023-05-19.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Tasks/2023-05-19.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Tasks/2023-08-14.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Tasks/2023-08-14.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Tasks/2023-02-16.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Tasks/2023-02-16.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Tasks/2023-06-06.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Tasks/2023-06-06.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Tasks/get_project_feedback.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Tasks/get_project_feedback.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Tasks/2023-02-27.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Tasks/2023-02-27.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Tasks/2023-06-02.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Tasks/2023-06-02.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Tasks/2023-10-04.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Tasks/2023-10-04.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Tasks/2023-01-26.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Tasks/2023-01-26.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Tasks/2023-09-14.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Tasks/2023-09-14.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Tasks/2023-09-20.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Tasks/2023-09-20.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Tasks/Slack Requests.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Tasks/Slack Requests.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Tasks/2023-05-23.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Tasks/2023-05-23.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Tasks/2023-04-18.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Tasks/2023-04-18.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Tasks/2023-10-25.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Tasks/2023-10-25.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Tasks/SCP_Investigation.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Tasks/SCP_Investigation.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Tasks/2023-09-15.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Tasks/2023-09-15.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Tasks/Cisco_Tasks.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Tasks/Cisco_Tasks.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Tasks/11/06/2023.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Tasks/11/06/2023.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Sprints/2023-01-27_Status.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Sprints/2023-01-27_Status.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Sprints/2023-01-06 - status.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Sprints/2023-01-06 - status.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Sprints/Agile/SCRUM_Team_Roles_And_Responsibilites.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Sprints/Agile/SCRUM_Team_Roles_And_Responsibilites.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Training/machine_learning.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Training/machine_learning.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Training/JS_Training.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Training/JS_Training.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Training/Adding in Port to macOS.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Training/Adding in Port to macOS.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Training/machine_learning_resources.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Training/machine_learning_resources.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Training/Training.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Training/Training.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Training/Import_vs_Require_in_JS.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Training/Import_vs_Require_in_JS.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Training/Pandas Training.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Training/Pandas Training.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Training/python_modules.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Training/python_modules.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Training/GCP_SkillBoost_Training.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Training/GCP_SkillBoost_Training.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Training/python_training_01092021.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Training/python_training_01092021.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Projects/Linking_Jira_GitLab.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Projects/Linking_Jira_GitLab.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Projects/Heimdall Project.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Projects/Heimdall Project.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Projects/SFDC Slackbot Project.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Projects/SFDC Slackbot Project.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Projects/Terminator_Metrics_Dashboards.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Projects/Terminator_Metrics_Dashboards.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Projects/Slack.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Projects/Slack.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Projects/Puppet Queries.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Projects/Puppet Queries.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Projects/Taskman.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Projects/Taskman.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Projects/Projects.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Projects/Projects.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Projects/deploy_cloud_functions.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Projects/deploy_cloud_functions.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Projects/Terminator_Doc_Index.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Projects/Terminator_Doc_Index.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Projects/adobe_user_management.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Projects/adobe_user_management.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Projects/Terminator_Functions.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Projects/Terminator_Functions.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Projects/Terminator.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Projects/Terminator.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Projects/Zoom_Dashboards.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Projects/Zoom_Dashboards.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Projects/Collab-Automation/Google_Workflows.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Projects/Collab-Automation/Google_Workflows.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Projects/Collab-Automation/Slack_SNOW_Integration.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Projects/Collab-Automation/Slack_SNOW_Integration.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Projects/Collab-Automation/Splunk_GitLab.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Projects/Collab-Automation/Splunk_GitLab.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Projects/Collab-Automation/Barracuda_Migration_File_Gen.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Projects/Collab-Automation/Barracuda_Migration_File_Gen.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Projects/Collab-Automation/GCP_API_Gateway.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Projects/Collab-Automation/GCP_API_Gateway.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Projects/Collab-Automation/Postman_Authentication_Doc.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Projects/Collab-Automation/Postman_Authentication_Doc.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Projects/Collab-Automation/SFDC Slackbot - Training the ML.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Projects/Collab-Automation/SFDC Slackbot - Training the ML.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Projects/Collab-Automation/jira_automation.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Projects/Collab-Automation/jira_automation.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/textgenerator/prompts/default/getTags.md
# Error reading /Users/dcarmocan/Projects/mind-cave/textgenerator/prompts/default/getTags.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/textgenerator/prompts/default/getOutline.md
# Error reading /Users/dcarmocan/Projects/mind-cave/textgenerator/prompts/default/getOutline.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/textgenerator/prompts/default/getIdeas.md
# Error reading /Users/dcarmocan/Projects/mind-cave/textgenerator/prompts/default/getIdeas.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/textgenerator/prompts/default/rewrite.md
# Error reading /Users/dcarmocan/Projects/mind-cave/textgenerator/prompts/default/rewrite.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/textgenerator/prompts/default/getTitles.md
# Error reading /Users/dcarmocan/Projects/mind-cave/textgenerator/prompts/default/getTitles.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/textgenerator/prompts/default/simplify.md
# Error reading /Users/dcarmocan/Projects/mind-cave/textgenerator/prompts/default/simplify.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/textgenerator/prompts/default/getParagraph.md
# Error reading /Users/dcarmocan/Projects/mind-cave/textgenerator/prompts/default/getParagraph.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/textgenerator/prompts/default/getEmailNeg.md
# Error reading /Users/dcarmocan/Projects/mind-cave/textgenerator/prompts/default/getEmailNeg.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/textgenerator/prompts/default/summarize.md
# Error reading /Users/dcarmocan/Projects/mind-cave/textgenerator/prompts/default/summarize.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/textgenerator/prompts/default/getEmailPos.md
# Error reading /Users/dcarmocan/Projects/mind-cave/textgenerator/prompts/default/getEmailPos.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/textgenerator/prompts/huggingface/summarizeBART.md
# Error reading /Users/dcarmocan/Projects/mind-cave/textgenerator/prompts/huggingface/summarizeBART.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/textgenerator/prompts/huggingface/classify-bart-large-mnli.md
# Error reading /Users/dcarmocan/Projects/mind-cave/textgenerator/prompts/huggingface/classify-bart-large-mnli.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/textgenerator/prompts/huggingface/completeTextBloom.md
# Error reading /Users/dcarmocan/Projects/mind-cave/textgenerator/prompts/huggingface/completeTextBloom.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Spaces/Home/Base Index.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Spaces/Home/Base Index.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Spaces/Home/Home.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Spaces/Home/Home.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Spaces/osquery/osquery.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Spaces/osquery/osquery.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Spaces/GitLab/GitLab.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Spaces/GitLab/GitLab.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Spaces/drawings/drawings.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Spaces/drawings/drawings.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Spaces/projects/projects.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Spaces/projects/projects.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Spaces/process_docs/process_docs.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Spaces/process_docs/process_docs.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Spaces/GCP/GCP.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Spaces/GCP/GCP.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Spaces/Daily Notes/Daily Notes.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Spaces/Daily Notes/Daily Notes.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Spaces/M365/M365.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Spaces/M365/M365.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Spaces/Templates/Templates.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Spaces/Templates/Templates.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Spaces/Coding/Coding.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Spaces/Coding/Coding.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Spaces/Meetings/Meetings.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Spaces/Meetings/Meetings.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Barracuda/Barracuda.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Barracuda/Barracuda.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Barracuda/Barracuda_Preflight_Process.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Barracuda/Barracuda_Preflight_Process.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Excalidraw/Drawing 2022-10-20 13.36.08.excalidraw.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Excalidraw/Drawing 2022-10-20 13.36.08.excalidraw.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Excalidraw/Drawing 2023-10-30 11.11.47.excalidraw.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Excalidraw/Drawing 2023-10-30 11.11.47.excalidraw.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Excalidraw/Drawing 2023-07-10 09.33.57.excalidraw.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Excalidraw/Drawing 2023-07-10 09.33.57.excalidraw.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Excalidraw/Drawing 2023-06-22 10.15.46.excalidraw.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Excalidraw/Drawing 2023-06-22 10.15.46.excalidraw.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Excalidraw/AppScript_CSV_Extraction.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Excalidraw/AppScript_CSV_Extraction.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Excalidraw/Drawing 2022-08-25 11.52.19.excalidraw.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Excalidraw/Drawing 2022-08-25 11.52.19.excalidraw.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Excalidraw/Testing Plan Terminator.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Excalidraw/Testing Plan Terminator.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Excalidraw/SNOW_Usergroup_Create.excalidraw.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Excalidraw/SNOW_Usergroup_Create.excalidraw.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Excalidraw/Drawing 2023-09-06 10.43.41.excalidraw.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Excalidraw/Drawing 2023-09-06 10.43.41.excalidraw.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Excalidraw/Drawing 2023-09-26 11.47.09.excalidraw.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Excalidraw/Drawing 2023-09-26 11.47.09.excalidraw.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Excalidraw/Drawing 2023-08-16 14.19.36.excalidraw.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Excalidraw/Drawing 2023-08-16 14.19.36.excalidraw.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Excalidraw/Scripts/Downloaded/Mindmap format.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Excalidraw/Scripts/Downloaded/Mindmap format.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Excalidraw/Scripts/Downloaded/Scribble Helper.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Excalidraw/Scripts/Downloaded/Scribble Helper.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Excalidraw/Scripts/Downloaded/Slideshow.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Excalidraw/Scripts/Downloaded/Slideshow.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Excalidraw/Scripts/Downloaded/Text Arch.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Excalidraw/Scripts/Downloaded/Text Arch.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Excalidraw/Scripts/Downloaded/Convert freedraw to line.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Excalidraw/Scripts/Downloaded/Convert freedraw to line.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Excalidraw/Scripts/Downloaded/Modify background color opacity.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Excalidraw/Scripts/Downloaded/Modify background color opacity.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Excalidraw/Scripts/Downloaded/Reverse arrows.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Excalidraw/Scripts/Downloaded/Reverse arrows.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Excalidraw/Scripts/Downloaded/Uniform size.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Excalidraw/Scripts/Downloaded/Uniform size.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Excalidraw/Scripts/Downloaded/Add Next Step in Process.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Excalidraw/Scripts/Downloaded/Add Next Step in Process.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Excalidraw/Scripts/Downloaded/Text to Sticky Notes.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Excalidraw/Scripts/Downloaded/Text to Sticky Notes.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Excalidraw/Scripts/Downloaded/Add Link to New Page and Open.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Excalidraw/Scripts/Downloaded/Add Link to New Page and Open.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Excalidraw/Scripts/Downloaded/Hardware Eraser Support.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Excalidraw/Scripts/Downloaded/Hardware Eraser Support.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Excalidraw/Scripts/Downloaded/TheBrain-navigation.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Excalidraw/Scripts/Downloaded/TheBrain-navigation.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Excalidraw/Scripts/Downloaded/Add Connector Point.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Excalidraw/Scripts/Downloaded/Add Connector Point.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Excalidraw/Scripts/Downloaded/Expand rectangles horizontally keep text centered.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Excalidraw/Scripts/Downloaded/Expand rectangles horizontally keep text centered.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Excalidraw/Scripts/Downloaded/Fixed spacing.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Excalidraw/Scripts/Downloaded/Fixed spacing.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Excalidraw/Scripts/Downloaded/Invert colors.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Excalidraw/Scripts/Downloaded/Invert colors.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Excalidraw/Scripts/Downloaded/Excalidraw Collaboration Frame.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Excalidraw/Scripts/Downloaded/Excalidraw Collaboration Frame.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Excalidraw/Scripts/Downloaded/Add Link to Existing File and Open.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Excalidraw/Scripts/Downloaded/Add Link to Existing File and Open.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Excalidraw/Scripts/Downloaded/Change shape of selected elements.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Excalidraw/Scripts/Downloaded/Change shape of selected elements.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Excalidraw/Scripts/Downloaded/Expand rectangles vertically.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Excalidraw/Scripts/Downloaded/Expand rectangles vertically.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Excalidraw/Scripts/Downloaded/Fixed horizontal distance between centers.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Excalidraw/Scripts/Downloaded/Fixed horizontal distance between centers.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Excalidraw/Scripts/Downloaded/Split Ellipse.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Excalidraw/Scripts/Downloaded/Split Ellipse.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Excalidraw/Scripts/Downloaded/Rename Image.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Excalidraw/Scripts/Downloaded/Rename Image.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Excalidraw/Scripts/Downloaded/Connect elements.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Excalidraw/Scripts/Downloaded/Connect elements.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Excalidraw/Scripts/Downloaded/Normalize Selected Arrows.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Excalidraw/Scripts/Downloaded/Normalize Selected Arrows.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Excalidraw/Scripts/Downloaded/Create new markdown file and embed into active drawing.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Excalidraw/Scripts/Downloaded/Create new markdown file and embed into active drawing.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Excalidraw/Scripts/Downloaded/Set Stroke Width of Selected Elements.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Excalidraw/Scripts/Downloaded/Set Stroke Width of Selected Elements.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Excalidraw/Scripts/Downloaded/Set Grid.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Excalidraw/Scripts/Downloaded/Set Grid.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Excalidraw/Scripts/Downloaded/Convert selected text elements to sticky notes.md
# ...
# Error reading /Users/dcarmocan/Projects/mind-cave/Services/Collab-Automation/Collab-Automation-Documentation.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Services/SendGrid/SendGrid Staging Guide.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Services/SendGrid/SendGrid Staging Guide.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Services/SendGrid/scopes_sendgrid.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Services/SendGrid/scopes_sendgrid.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Services/Google/Using Docker Compose with Local Cloud Run 8ef8e0895cc442d8b42ea77b14c5dba2.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Services/Google/Using Docker Compose with Local Cloud Run 8ef8e0895cc442d8b42ea77b14c5dba2.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Services/Google/GCP.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Services/Google/GCP.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Services/Google/Google Sheets/sheets_formulas.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Services/Google/Google Sheets/sheets_formulas.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Services/Google/Workflows/Google_Workflow_tech_doc.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Services/Google/Workflows/Google_Workflow_tech_doc.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Services/Google/Terminator/Terminator - Add User Function.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Services/Google/Terminator/Terminator - Add User Function.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Services/Google/Terminator/Terminator_Sailpoint.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Services/Google/Terminator/Terminator_Sailpoint.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Services/Google/Terminator/Terminator Function Docs/terminator_license_revoke_documentation.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Services/Google/Terminator/Terminator Function Docs/terminator_license_revoke_documentation.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Services/Google/Integrations/appscript_config.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Services/Google/Integrations/appscript_config.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Services/Cisco/Cisco_Email_Settings.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Services/Cisco/Cisco_Email_Settings.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Services/Cisco/Agari_API_Docs.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Services/Cisco/Agari_API_Docs.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Services/Cisco/Cisco_Docs.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Services/Cisco/Cisco_Docs.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Services/Cisco/Training_References.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Services/Cisco/Training_References.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Services/Cisco/links.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Services/Cisco/links.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Services/Splunk/Team/team_spl_query.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Services/Splunk/Team/team_spl_query.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Services/Kiteworks/2022-08-19_Kiteworks_Update.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Services/Kiteworks/2022-08-19_Kiteworks_Update.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Services/M365/MS_Teams_Cleanup_PowerShell.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Services/M365/MS_Teams_Cleanup_PowerShell.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Services/M365/Microsoft_Index.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Services/M365/Microsoft_Index.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Services/M365/m365_eop_doc.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Services/M365/m365_eop_doc.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Services/M365/MS_Teams_Cleanup.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Services/M365/MS_Teams_Cleanup.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Services/Governance/Legal.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Services/Governance/Legal.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Services/Slack/Slack App Admin Tasks.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Services/Slack/Slack App Admin Tasks.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Services/Slack/Slack Docs.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Services/Slack/Slack Docs.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Services/Slack/Slack.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Services/Slack/Slack.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Services/Slack/Untitled.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Services/Slack/Untitled.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Services/Slack/Push_Groups.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Services/Slack/Push_Groups.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Services/Slack/Slack Connect App Config.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Services/Slack/Slack Connect App Config.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Services/Slack/Slack Coding Helpers and Snippets.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Services/Slack/Slack Coding Helpers and Snippets.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Services/Slack/Services.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Services/Slack/Services.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Services/Slack/20230210_Slack_Channel_Name_Request.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Services/Slack/20230210_Slack_Channel_Name_Request.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Services/Slack/Slack_Scratchpad.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Services/Slack/Slack_Scratchpad.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Services/Slack/GCP Slack Bot.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Services/Slack/GCP Slack Bot.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Services/Slack/Slack Blurbs.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Services/Slack/Slack Blurbs.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Services/Slack/process_docs/Slack_Anomoly_Events.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Services/Slack/process_docs/Slack_Anomoly_Events.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Services/Slack/process_docs/slack_response_blurbs.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Services/Slack/process_docs/slack_response_blurbs.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Services/Slack/process_docs/App_Creation_Slack.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Services/Slack/process_docs/App_Creation_Slack.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Services/Slack/process_docs/canned_response_templates.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Services/Slack/process_docs/canned_response_templates.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Services/Slack/process_docs/working_with_slack_discovery.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Services/Slack/process_docs/working_with_slack_discovery.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Services/Slack/apps/service_account_request_form.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Services/Slack/apps/service_account_request_form.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Services/Slack/apps/AdminTasks_App_Documentation.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Services/Slack/apps/AdminTasks_App_Documentation.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Services/Harshicorp/Hashicorp_Vault_Docs.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Services/Harshicorp/Hashicorp_Vault_Docs.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Utility/Scripts.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Utility/Scripts.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Utility/Query_Test.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Utility/Query_Test.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Utility/General Blurbs.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Utility/General Blurbs.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing file: /Users/dcarmocan/Projects/mind-cave/Utility/Slack_App_Blurbs.md
# Error reading /Users/dcarmocan/Projects/mind-cave/Utility/Slack_App_Blurbs.md: 'MemgraphManager' object has no attribute 'execute_and_fetch'
# Processing complete.
# Some nodes in the database:
# Executing query: MATCH (n) RETURN n LIMIT 10
# Query executed successfully.
# (<mgclient.Node(id=21736, labels={'File'}, properties={'name': 'SPOG.md'}) at 0x1716fab20>,)
# (<mgclient.Node(id=21737, labels={'hr'}, properties={'name': 'SPOG.md_None'}) at 0x160614360>,)
# (<mgclient.Node(id=21738, labels={'hr'}, properties={'name': 'SPOG.md_None'}) at 0x160615b30>,)
# (<mgclient.Node(id=21739, labels={'h3'}, properties={'name': 'SPOG.md_SPOG'}) at 0x171738fc0>,)
# (<mgclient.Node(id=21740, labels={'h4'}, properties={'name': 'SPOG.md_Zoom SPOG'}) at 0x17173bfc0>,)
# (<mgclient.Node(id=21741, labels={'h2'}, properties={'name': 'SPOG.md_- Carmine asked for a couple of things for the SPOG on [[2023-03-16]] .  I need to look and see if I can get these items completed in time for the meeting today.'}) at 0x17173be70>,)
# (<mgclient.Node(id=21742, labels={'h4'}, properties={'name': 'SPOG.md_VDI SPOG'}) at 0x171738e40>,)
# (<mgclient.Node(id=21743, labels={'File'}, properties={'name': 'Zoom Dashboard Documentation.md'}) at 0x171738f90>,)
# (<mgclient.Node(id=21744, labels={'hr'}, properties={'name': 'Zoom Dashboard Documentation.md_None'}) at 0x11042ca20>,)
# (<mgclient.Node(id=21745, labels={'hr'}, properties={'name': 'Zoom Dashboard Documentation.md_None'}) at 0x177d123a0>,)
# Some relationships in the database:
# Executing query: MATCH (n)-[r]->(m) RETURN n, r, m LIMIT 10
# Query executed successfully.
# (<mgclient.Node(id=21736, labels={'File'}, properties={'name': 'SPOG.md'}) at 0x1092c89f0>, <mgclient.Relationship(start_id=21736, end_id=21737, type='CONTAINS', properties={}) at 0x16122dfb0>, <mgclient.Node(id=21737, labels={'hr'}, properties={'name': 'SPOG.md_None'}) at 0x171739aa0>)
# (<mgclient.Node(id=21737, labels={'hr'}, properties={'name': 'SPOG.md_None'}) at 0x160616040>, <mgclient.Relationship(start_id=21737, end_id=21737, type='CONTAINS', properties={}) at 0x17159db70>, <mgclient.Node(id=21737, labels={'hr'}, properties={'name': 'SPOG.md_None'}) at 0x1606143f0>)
# (<mgclient.Node(id=21738, labels={'hr'}, properties={'name': 'SPOG.md_None'}) at 0x1606140c0>, <mgclient.Relationship(start_id=21738, end_id=21737, type='CONTAINS', properties={}) at 0x1606405f0>, <mgclient.Node(id=21737, labels={'hr'}, properties={'name': 'SPOG.md_None'}) at 0x160614330>)
# (<mgclient.Node(id=24071, labels={'hr'}, properties={'name': 'SPOG.md_None'}) at 0x177d119e0>, <mgclient.Relationship(start_id=24071, end_id=21737, type='CONTAINS', properties={}) at 0x160642730>, <mgclient.Node(id=21737, labels={'hr'}, properties={'name': 'SPOG.md_None'}) at 0x177d10cc0>)
# (<mgclient.Node(id=24072, labels={'hr'}, properties={'name': 'SPOG.md_None'}) at 0x177d13c60>, <mgclient.Relationship(start_id=24072, end_id=21737, type='CONTAINS', properties={}) at 0x1612400b0>, <mgclient.Node(id=21737, labels={'hr'}, properties={'name': 'SPOG.md_None'}) at 0x177d12a60>)
# (<mgclient.Node(id=21736, labels={'File'}, properties={'name': 'SPOG.md'}) at 0x177d10ed0>, <mgclient.Relationship(start_id=21736, end_id=21738, type='CONTAINS', properties={}) at 0x1611ec730>, <mgclient.Node(id=21738, labels={'hr'}, properties={'name': 'SPOG.md_None'}) at 0x177d13c30>)
# (<mgclient.Node(id=21737, labels={'hr'}, properties={'name': 'SPOG.md_None'}) at 0x177d125e0>, <mgclient.Relationship(start_id=21737, end_id=21738, type='CONTAINS', properties={}) at 0x1611ec2b0>, <mgclient.Node(id=21738, labels={'hr'}, properties={'name': 'SPOG.md_None'}) at 0x177d11da0>)
# (<mgclient.Node(id=21738, labels={'hr'}, properties={'name': 'SPOG.md_None'}) at 0x177d12280>, <mgclient.Relationship(start_id=21738, end_id=21738, type='CONTAINS', properties={}) at 0x1611ee270>, <mgclient.Node(id=21738, labels={'hr'}, properties={'name': 'SPOG.md_None'}) at 0x177d11b30>)
# (<mgclient.Node(id=24071, labels={'hr'}, properties={'name': 'SPOG.md_None'}) at 0x177d11200>, <mgclient.Relationship(start_id=24071, end_id=21738, type='CONTAINS', properties={}) at 0x1611ee6b0>, <mgclient.Node(id=21738, labels={'hr'}, properties={'name': 'SPOG.md_None'}) at 0x177d11b90>)
# (<mgclient.Node(id=24072, labels={'hr'}, properties={'name': 'SPOG.md_None'}) at 0x177d11cb0>, <mgclient.Relationship(start_id=24072, end_id=21738, type='CONTAINS', properties={}) at 0x1611ed2f0>, <mgclient.Node(id=21738, labels={'hr'}, properties={'name': 'SPOG.md_None'}) at 0x177d11770>)

# %%
# Example usage:
# Path to the directory containing markdown files (Obsidian vault)
notes_dir = '/Users/dcarmocan/Projects/mind-cave'

# Initialize the VaultManager and update the vault
vault_manager = VaultManager(memgraph=memgraph,directory=notes_dir)
vault_manager.update_vault()

# Initialize a GeneralQueryAgent with any required tools
# For simplicity, no additional tools are added here
agent = GeneralQueryAgent(repo_path=notes_dir, tools=[])

# %%
# Make sure to test the API path
base_url = "http://localhost:8000"

# add_file = "/knowledge_base/notes/add_file"
notes_dir = '/Users/dcarmocan/Projects/mind-cave'
collection = CollectionManager(notes_dir, memgraph)

# %%
import os

# Get the current file path
current_file_path = os.path.abspath("__file__")

# Update the vault
vault_manager = VaultManager(notes_dir, memgraph)
# vault_manager.clear_vault()
vault_manager.update_vault()

# Initialize a GeneralQueryAgent with any required tools
# For simplicity, no additional tools are added here
agent = GeneralQueryAgent(repo_path=notes_dir, tools=[])

# %%
local_repo_init ="/knowledge_base/general/init_local_repo"
local_repo_init_url = base_url + local_repo_init

base_data = {
  "path" : "/Users/dcarmocan/Projects/mind-cave",
  "type": "Notes"
}

repo_req = requests.post(local_repo_init_url, json=base_data)

# %%
repo_req.text
